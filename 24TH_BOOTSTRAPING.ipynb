# %% [markdown]
# # Applications of Deep Neural Networks
# **Module 5: Regularization and Dropout**

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 5.5: Benchmarking Regularization Techniques
#
# Quite a few hyperparameters have been introduced so far.  Tweaking each of these values can have an effect on the score obtained by your neural networks.  Some of the hyperparameters seen so far include:
#
# * Number of layers in the neural network
# * How many neurons in each layer
# * What activation functions to use on each layer
# * Dropout percent on each layer
# * L1 and L2 values on each layer
#
# To try out each of these hyperparameters you will need to run train neural networks with multiple settings for each hyperparameter.  However, you may have noticed that neural networks often produce somewhat different results when trained multiple times.  This is because the neural networks start with random weights.  Because of this it is necessary to fit and evaluate a neural network times to ensure that one set of hyperparameters are actually better than another.  Bootstrapping can be an effective means of benchmarking (comparing) two sets of hyperparameters.
#
# Bootstrapping is similar to cross-validation.  Both go through a number of cycles/folds providing validation and training sets.  However, bootstrapping can have an unlimited number of cycles.  Bootstrapping chooses a new train and validation split each cycle, with replacement.  The fact that each cycle is chosen with replacement means that, unlike cross validation, there will often be repeated rows selected between cycles.  If you run the bootstrap for enough cycles, there will be duplicate cycles.
#
# In this part we will use bootstrapping for hyperparameter benchmarking.  We will train a neural network for a specified number of splits (denoted by the SPLITS constant).  For these examples we use 100.  We will compare the average score at the end of the 100.  By the end of the cycles the mean score will have converged somewhat.  This ending score will be a much better basis of comparison than a single cross-validation.  Additionally, the average number of epochs will be tracked to give an idea of a possible optimal value.  Because the early stopping validation set is also used to evaluate the the neural network as well, it might be slightly inflated.  This is because we are both stopping and evaluating on the same sample.  However, we are using the scores only as relative measures to determine the superiority of one set of hyperparameters to another, so this slight inflation should not present too much of a problem.
#
# Because we are benchmarking, we will display the amount of time taken for each cycle.  The following function can be used to nicely format a time span.

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# ## Bootstrapping for Regression
#
# Regression bootstrapping uses the **ShuffleSplit** object to perform the splits.  This technique is similar to **KFold** for cross-validation; no balancing occurs.  We will attempt to predict the age column for the **jh-simple-dataset**; the following code loads this data.

# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Generate dummies for product
df = pd.concat([df,pd.get_dummies(df['product'],prefix="product")],axis=1)
df.drop('product', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('age').drop('id')
x = df[x_columns].values
y = df['age'].values

# %% [markdown]
# The following code performs the bootstrap.  The architecture of the neural network can be adjusted to compare many different configurations.

# %%
import pandas as pd
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import ShuffleSplit

SPLITS = 50

# Bootstrap
boot = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=5, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    score = np.sqrt(metrics.mean_squared_error(pred,y_test))
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f},"
          f" stdev={mdev:.6f}", 
          f" epochs={epochs}, mean epochs={int(m2)}", 
          f" time={hms_string(time_took)}")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# #1: score=0.838522, mean score=0.838522, stdev=0.000000  epochs=109, mean epochs=109  time=0:00:21.88
# 7/7 [==============================] - 0s 2ms/step
# #2: score=0.911860, mean score=0.875191, stdev=0.036669  epochs=132, mean epochs=120  time=0:00:15.56
# 7/7 [==============================] - 0s 2ms/step
# #3: score=0.735339, mean score=0.828573, stdev=0.072407  epochs=134, mean epochs=125  time=0:00:15.96
# 7/7 [==============================] - 0s 3ms/step
# #4: score=0.712773, mean score=0.799623, stdev=0.080290  epochs=95, mean epochs=117  time=0:00:11.35
# 7/7 [==============================] - 0s 3ms/step
# #5: score=0.811488, mean score=0.801996, stdev=0.071970  epochs=128, mean epochs=119  time=0:00:21.04
# 7/7 [==============================] - 0s 2ms/step
# #6: score=0.979762, mean score=0.831624, stdev=0.093302  epochs=122, mean epochs=120  time=0:00:21.14
# 7/7 [==============================] - 0s 2ms/step
# #7: score=0.541788, mean score=0.790219, stdev=0.133222  epochs=154, mean epochs=124  time=0:00:21.03
# 7/7 [==============================] - 0s 3ms/step
# #8: score=0.595829, mean score=0.765920, stdev=0.140223  epochs=95, mean epochs=121  time=0:00:11.70
# 7/7 [==============================] - 0s 2ms/step
# #9: score=0.616187, mean score=0.749283, stdev=0.140329  epochs=142, mean epochs=123  time=0:00:21.09
# 7/7 [==============================] - 0s 2ms/step
# #10: score=1.217756, mean score=0.796130, stdev=0.193584  epochs=86, mean epochs=119  time=0:00:10.71
# 7/7 [==============================] - 0s 3ms/step
# #11: score=1.010478, mean score=0.815616, stdev=0.194590  epochs=97, mean epochs=117  time=0:00:21.11
# 7/7 [==============================] - 0s 3ms/step
# #12: score=0.820268, mean score=0.816004, stdev=0.186310  epochs=136, mean epochs=119  time=0:00:21.11
# 7/7 [==============================] - 0s 2ms/step
# #13: score=0.669739, mean score=0.804753, stdev=0.183195  epochs=106, mean epochs=118  time=0:00:14.13
# 7/7 [==============================] - 0s 2ms/step
# #14: score=1.166673, mean score=0.830604, stdev=0.199627  epochs=104, mean epochs=117  time=0:00:14.08
# 7/7 [==============================] - 0s 3ms/step
# #15: score=0.554156, mean score=0.812175, stdev=0.204816  epochs=142, mean epochs=118  time=0:00:21.09
# 7/7 [==============================] - 0s 2ms/step
# #16: score=0.922604, mean score=0.819076, stdev=0.200106  epochs=144, mean epochs=120  time=0:00:21.01
# 7/7 [==============================] - 0s 2ms/step
# #17: score=0.718378, mean score=0.813153, stdev=0.195572  epochs=96, mean epochs=118  time=0:00:21.01
# 7/7 [==============================] - 0s 2ms/step
# #18: score=1.084107, mean score=0.828206, stdev=0.199939  epochs=112, mean epochs=118  time=0:00:21.02
# 7/7 [==============================] - 0s 2ms/step
# #19: score=0.625302, mean score=0.817527, stdev=0.199810  epochs=174, mean epochs=121  time=0:00:21.04
# 7/7 [==============================] - 0s 3ms/step
# #20: score=0.725790, mean score=0.812940, stdev=0.195775  epochs=189, mean epochs=124  time=0:00:41.55
# 7/7 [==============================] - 0s 2ms/step
# #21: score=0.781763, mean score=0.811455, stdev=0.191172  epochs=145, mean epochs=125  time=0:00:17.25
# 7/7 [==============================] - 0s 2ms/step
# #22: score=0.574549, mean score=0.800687, stdev=0.193186  epochs=105, mean epochs=124  time=0:00:12.88
# 7/7 [==============================] - 0s 3ms/step
# #23: score=0.691602, mean score=0.795944, stdev=0.190244  epochs=111, mean epochs=124  time=0:00:21.06
# 7/7 [==============================] - 0s 4ms/step
# #24: score=0.598911, mean score=0.787734, stdev=0.190355  epochs=120, mean epochs=124  time=0:00:15.37
# 7/7 [==============================] - 0s 3ms/step
# #25: score=0.804030, mean score=0.788386, stdev=0.186536  epochs=158, mean epochs=125  time=0:00:18.96
# 7/7 [==============================] - 0s 3ms/step
# #26: score=0.728295, mean score=0.786075, stdev=0.183279  epochs=120, mean epochs=125  time=0:00:21.12
# 7/7 [==============================] - 0s 2ms/step
# #27: score=0.693244, mean score=0.782637, stdev=0.180705  epochs=88, mean epochs=123  time=0:00:10.90
# 7/7 [==============================] - 0s 2ms/step
# #28: score=0.824877, mean score=0.784145, stdev=0.177622  epochs=91, mean epochs=122  time=0:00:21.05
# 7/7 [==============================] - 0s 3ms/step
# #29: score=0.692407, mean score=0.780982, stdev=0.175333  epochs=98, mean epochs=121  time=0:00:13.05
# 7/7 [==============================] - 0s 2ms/step
# #30: score=0.551042, mean score=0.773317, stdev=0.177259  epochs=132, mean epochs=122  time=0:00:17.42
# 7/7 [==============================] - 0s 2ms/step
# #31: score=0.739563, mean score=0.772228, stdev=0.174479  epochs=118, mean epochs=122  time=0:00:14.26
# 7/7 [==============================] - 0s 2ms/step
# #32: score=0.638882, mean score=0.768061, stdev=0.173291  epochs=97, mean epochs=121  time=0:00:12.20
# 7/7 [==============================] - 0s 4ms/step
# #33: score=0.743964, mean score=0.767331, stdev=0.170695  epochs=107, mean epochs=120  time=0:00:21.04
# 7/7 [==============================] - 0s 3ms/step
# #34: score=1.192313, mean score=0.779831, stdev=0.182854  epochs=89, mean epochs=119  time=0:00:21.11
# 7/7 [==============================] - 0s 2ms/step
# #35: score=0.616518, mean score=0.775165, stdev=0.182265  epochs=111, mean epochs=119  time=0:00:21.17
# 7/7 [==============================] - 0s 2ms/step
# #36: score=0.655343, mean score=0.771836, stdev=0.180791  epochs=122, mean epochs=119  time=0:00:14.72
# 7/7 [==============================] - 0s 2ms/step
# #37: score=1.029417, mean score=0.778798, stdev=0.183158  epochs=101, mean epochs=119  time=0:00:12.98
# 7/7 [==============================] - 0s 2ms/step
# #38: score=0.659738, mean score=0.775665, stdev=0.181734  epochs=127, mean epochs=119  time=0:00:16.31
# 7/7 [==============================] - 0s 2ms/step
# #39: score=0.565835, mean score=0.770284, stdev=0.182429  epochs=111, mean epochs=119  time=0:00:13.62
# 7/7 [==============================] - 0s 3ms/step
# #40: score=0.725293, mean score=0.769160, stdev=0.180271  epochs=101, mean epochs=118  time=0:00:12.39
# 7/7 [==============================] - 0s 3ms/step
# #41: score=1.274205, mean score=0.781478, stdev=0.194357  epochs=93, mean epochs=118  time=0:00:21.07
# 7/7 [==============================] - 0s 2ms/step
# #42: score=0.570660, mean score=0.776458, stdev=0.194700  epochs=135, mean epochs=118  time=0:00:17.44
# 7/7 [==============================] - 0s 2ms/step
# #43: score=0.665055, mean score=0.773868, stdev=0.193154  epochs=96, mean epochs=117  time=0:00:12.11
# 7/7 [==============================] - 0s 2ms/step
# #44: score=0.514672, mean score=0.767977, stdev=0.194815  epochs=96, mean epochs=117  time=0:00:11.88
# 7/7 [==============================] - 0s 2ms/step
# #45: score=1.252118, mean score=0.778735, stdev=0.205432  epochs=98, mean epochs=117  time=0:00:21.05
# 7/7 [==============================] - 0s 3ms/step
# #46: score=0.750436, mean score=0.778120, stdev=0.203229  epochs=97, mean epochs=116  time=0:00:21.06
# 7/7 [==============================] - 0s 2ms/step
# #47: score=0.626930, mean score=0.774903, stdev=0.202236  epochs=115, mean epochs=116  time=0:00:13.94
# 7/7 [==============================] - 0s 2ms/step
# #48: score=0.605640, mean score=0.771377, stdev=0.201573  epochs=102, mean epochs=116  time=0:00:13.04
# 7/7 [==============================] - 0s 2ms/step
# #49: score=1.279505, mean score=0.781747, stdev=0.212047  epochs=94, mean epochs=115  time=0:00:11.64
# 7/7 [==============================] - 0s 2ms/step
# #50: score=0.739914, mean score=0.780910, stdev=0.209998  epochs=142, mean epochs=116  time=0:00:21.08

# %% [markdown]
# The bootstrapping process for classification is similar, and I present it in the next section.
#
# ## Bootstrapping for Classification
#
# Regression bootstrapping uses the **StratifiedShuffleSplit** class to perform the splits.  This class is similar to **StratifiedKFold** for cross-validation, as the classes are balanced so that the sampling does not affect proportions.  To demonstrate this technique, we will attempt to predict the product column for the **jh-simple-dataset**; the following code loads this data.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %% [markdown]
# We now run this data through a number of splits specified by the SPLITS variable. We track the average error through each of these splits.

# %%
import pandas as pd
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit

SPLITS = 50

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1, 
                                random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
    model.add(Dense(25, activation='relu')) # Hidden 2
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=25, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}," +\
          f"stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}," +\
          f" time={hms_string(time_took)}")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# #1: score=0.664021, mean score=0.664021,stdev=0.000000, epochs=95, mean epochs=95, time=0:00:14.08
# 7/7 [==============================] - 0s 2ms/step
# #2: score=0.633324, mean score=0.648672,stdev=0.015348, epochs=91, mean epochs=93, time=0:00:15.02
# 7/7 [==============================] - 0s 2ms/step
# #3: score=0.660648, mean score=0.652664,stdev=0.013745, epochs=65, mean epochs=83, time=0:00:09.40
# 7/7 [==============================] - 0s 3ms/step
# #4: score=0.653348, mean score=0.652835,stdev=0.011907, epochs=65, mean epochs=79, time=0:00:10.84
# 7/7 [==============================] - 0s 3ms/step
# #5: score=0.669336, mean score=0.656135,stdev=0.012529, epochs=56, mean epochs=74, time=0:00:07.78
# 7/7 [==============================] - 0s 2ms/step
# #6: score=0.681179, mean score=0.660309,stdev=0.014762, epochs=67, mean epochs=73, time=0:00:08.94
# 7/7 [==============================] - 0s 2ms/step
# #7: score=0.713589, mean score=0.667921,stdev=0.023117, epochs=48, mean epochs=69, time=0:00:10.77
# 7/7 [==============================] - 0s 2ms/step
# #8: score=0.758142, mean score=0.679198,stdev=0.036850, epochs=39, mean epochs=65, time=0:00:05.69
# 7/7 [==============================] - 0s 2ms/step
# #9: score=0.641540, mean score=0.675014,stdev=0.036703, epochs=63, mean epochs=65, time=0:00:10.83
# 7/7 [==============================] - 0s 3ms/step
# #10: score=0.640158, mean score=0.671528,stdev=0.036356, epochs=101, mean epochs=69, time=0:00:13.93
# 7/7 [==============================] - 0s 2ms/step
# #11: score=0.674444, mean score=0.671793,stdev=0.034674, epochs=85, mean epochs=70, time=0:00:12.04
# 7/7 [==============================] - 0s 2ms/step
# #12: score=0.732122, mean score=0.676821,stdev=0.037150, epochs=54, mean epochs=69, time=0:00:10.90
# 7/7 [==============================] - 0s 2ms/step
# #13: score=0.691327, mean score=0.677937,stdev=0.035901, epochs=91, mean epochs=70, time=0:00:21.07
# 7/7 [==============================] - 0s 2ms/step
# #14: score=0.726284, mean score=0.681390,stdev=0.036768, epochs=41, mean epochs=68, time=0:00:05.81
# 7/7 [==============================] - 0s 2ms/step
# #15: score=0.660356, mean score=0.679988,stdev=0.035906, epochs=78, mean epochs=69, time=0:00:11.20
# 7/7 [==============================] - 0s 2ms/step
# #16: score=0.737522, mean score=0.683584,stdev=0.037452, epochs=52, mean epochs=68, time=0:00:10.81
# 7/7 [==============================] - 0s 2ms/step
# #17: score=0.662995, mean score=0.682373,stdev=0.036655, epochs=66, mean epochs=68, time=0:00:10.83
# 7/7 [==============================] - 0s 4ms/step
# #18: score=0.671591, mean score=0.681774,stdev=0.035708, epochs=55, mean epochs=67, time=0:00:10.83
# 7/7 [==============================] - 0s 2ms/step
# #19: score=0.609893, mean score=0.677990,stdev=0.038283, epochs=61, mean epochs=67, time=0:00:08.45
# 7/7 [==============================] - 0s 2ms/step
# #20: score=0.685022, mean score=0.678342,stdev=0.037345, epochs=61, mean epochs=66, time=0:00:08.37
# 7/7 [==============================] - 0s 3ms/step
# #21: score=0.646750, mean score=0.676838,stdev=0.037061, epochs=63, mean epochs=66, time=0:00:08.86
# 7/7 [==============================] - 0s 3ms/step
# #22: score=0.713205, mean score=0.678491,stdev=0.036993, epochs=108, mean epochs=68, time=0:00:21.13
# 7/7 [==============================] - 0s 4ms/step
# #23: score=0.603448, mean score=0.675228,stdev=0.039283, epochs=76, mean epochs=68, time=0:00:21.18
# 7/7 [==============================] - 0s 2ms/step
# #24: score=0.735641, mean score=0.677745,stdev=0.040306, epochs=78, mean epochs=69, time=0:00:10.89
# 7/7 [==============================] - 0s 3ms/step
# #25: score=0.572976, mean score=0.673554,stdev=0.044510, epochs=55, mean epochs=68, time=0:00:10.85
# 7/7 [==============================] - 0s 2ms/step
# #26: score=0.689462, mean score=0.674166,stdev=0.043752, epochs=50, mean epochs=67, time=0:00:07.30
# 7/7 [==============================] - 0s 3ms/step
# #27: score=0.702430, mean score=0.675213,stdev=0.043265, epochs=85, mean epochs=68, time=0:00:21.11
# 7/7 [==============================] - 0s 3ms/step
# #28: score=0.723328, mean score=0.676931,stdev=0.043414, epochs=57, mean epochs=68, time=0:00:11.56
# 7/7 [==============================] - 0s 2ms/step
# #29: score=0.660745, mean score=0.676373,stdev=0.042761, epochs=84, mean epochs=68, time=0:00:21.12
# 7/7 [==============================] - 0s 2ms/step
# #30: score=0.744091, mean score=0.678631,stdev=0.043764, epochs=41, mean epochs=67, time=0:00:10.84
# 7/7 [==============================] - 0s 2ms/step
# #31: score=0.693113, mean score=0.679098,stdev=0.043128, epochs=76, mean epochs=67, time=0:00:10.80
# 7/7 [==============================] - 0s 2ms/step
# #32: score=0.661076, mean score=0.678535,stdev=0.042565, epochs=65, mean epochs=67, time=0:00:10.82
# 7/7 [==============================] - 0s 2ms/step
# #33: score=0.597936, mean score=0.676092,stdev=0.044133, epochs=72, mean epochs=68, time=0:00:09.83
# 7/7 [==============================] - 0s 3ms/step
# #34: score=0.597023, mean score=0.673767,stdev=0.045485, epochs=71, mean epochs=68, time=0:00:10.85
# 7/7 [==============================] - 0s 3ms/step
# #35: score=0.537370, mean score=0.669869,stdev=0.050261, epochs=59, mean epochs=67, time=0:00:10.92
# 7/7 [==============================] - 0s 2ms/step
# #36: score=0.645243, mean score=0.669185,stdev=0.049723, epochs=66, mean epochs=67, time=0:00:09.29
# 7/7 [==============================] - 0s 3ms/step
# #37: score=0.649469, mean score=0.668653,stdev=0.049151, epochs=55, mean epochs=67, time=0:00:10.81
# 7/7 [==============================] - 0s 4ms/step
# #38: score=0.666069, mean score=0.668585,stdev=0.048501, epochs=53, mean epochs=67, time=0:00:07.38
# 7/7 [==============================] - 0s 2ms/step
# #39: score=0.756994, mean score=0.670851,stdev=0.049873, epochs=65, mean epochs=67, time=0:00:09.22
# 7/7 [==============================] - 0s 3ms/step
# #40: score=0.709406, mean score=0.671815,stdev=0.049612, epochs=47, mean epochs=66, time=0:00:10.80
# 7/7 [==============================] - 0s 3ms/step
# #41: score=0.723423, mean score=0.673074,stdev=0.049646, epochs=37, mean epochs=65, time=0:00:06.08
# 7/7 [==============================] - 0s 2ms/step
# #42: score=0.652955, mean score=0.672595,stdev=0.049147, epochs=62, mean epochs=65, time=0:00:09.78
# 7/7 [==============================] - 0s 3ms/step
# #43: score=0.682127, mean score=0.672817,stdev=0.048594, epochs=61, mean epochs=65, time=0:00:10.79
# 7/7 [==============================] - 0s 2ms/step
# #44: score=0.763249, mean score=0.674872,stdev=0.049893, epochs=49, mean epochs=65, time=0:00:07.19
# 7/7 [==============================] - 0s 2ms/step
# #45: score=0.658684, mean score=0.674512,stdev=0.049393, epochs=69, mean epochs=65, time=0:00:10.87
# 7/7 [==============================] - 0s 3ms/step
# #46: score=0.676547, mean score=0.674556,stdev=0.048854, epochs=43, mean epochs=64, time=0:00:06.28
# 7/7 [==============================] - 0s 2ms/step
# #47: score=0.692377, mean score=0.674936,stdev=0.048400, epochs=67, mean epochs=64, time=0:00:10.85
# 7/7 [==============================] - 0s 2ms/step
# #48: score=0.746590, mean score=0.676428,stdev=0.048975, epochs=44, mean epochs=64, time=0:00:10.84
# 7/7 [==============================] - 0s 3ms/step
# #49: score=0.659154, mean score=0.676076,stdev=0.048534, epochs=78, mean epochs=64, time=0:00:21.11
# 7/7 [==============================] - 0s 2ms/step
# #50: score=0.674100, mean score=0.676036,stdev=0.048047, epochs=55, mean epochs=64, time=0:00:10.85

# %% [markdown]
# ## Benchmarking
#
# Now that we've seen how to bootstrap with both classification and regression, we can start to try to optimize the hyperparameters for the **jh-simple-dataset** data.  For this example, we will encode for classification of the product column.  Evaluation will be in log loss.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],
               axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %% [markdown]
# I performed some optimization, and the code has the best settings that I could determine. Later in this book, we will see how we can use an automatic process to optimize the hyperparameters.

# %%
import pandas as pd
import os
import numpy as np
import time
import tensorflow.keras.initializers
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import LeakyReLU,PReLU

SPLITS = 100

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(100, input_dim=x.shape[1], activation=PReLU(), \
        kernel_regularizer=regularizers.l2(1e-4))) # Hidden 1
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4))) # Hidden 2
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4)
    )) # Hidden 3
#    model.add(Dropout(0.5)) - Usually better performance 
# without dropout on final layer
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=100, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test), \
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f},"
          f"stdev={mdev:.6f}, epochs={epochs},"
          f"mean epochs={int(m2)}, time={hms_string(time_took)}")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# #1: score=0.578867, mean score=0.578867,stdev=0.000000, epochs=170,mean epochs=170, time=0:00:42.07
# 7/7 [==============================] - 1s 2ms/step
# #2: score=0.538810, mean score=0.558839,stdev=0.020029, epochs=292,mean epochs=231, time=0:00:56.94
# 7/7 [==============================] - 0s 3ms/step
# #3: score=0.729155, mean score=0.615611,stdev=0.081936, epochs=211,mean epochs=224, time=0:00:42.14
# 7/7 [==============================] - 0s 2ms/step
# #4: score=0.681037, mean score=0.631967,stdev=0.076405, epochs=161,mean epochs=208, time=0:00:33.49
# 7/7 [==============================] - 0s 3ms/step
# #5: score=0.699979, mean score=0.645570,stdev=0.073555, epochs=184,mean epochs=203, time=0:00:42.11
# 7/7 [==============================] - 0s 2ms/step
# #6: score=0.612825, mean score=0.640112,stdev=0.068246, epochs=231,mean epochs=208, time=0:00:45.15
# 7/7 [==============================] - 0s 4ms/step
# #7: score=0.623558, mean score=0.637747,stdev=0.063448, epochs=199,mean epochs=206, time=0:00:42.21
# 7/7 [==============================] - 0s 2ms/step
# #8: score=0.677589, mean score=0.642728,stdev=0.060796, epochs=181,mean epochs=203, time=0:00:42.21
# 7/7 [==============================] - 0s 2ms/step
# #9: score=0.775367, mean score=0.657465,stdev=0.070873, epochs=156,mean epochs=198, time=0:00:33.00
# 7/7 [==============================] - 0s 3ms/step
# #10: score=0.607118, mean score=0.652431,stdev=0.068912, epochs=217,mean epochs=200, time=0:01:23.66
# 7/7 [==============================] - 0s 3ms/step
# #11: score=0.688923, mean score=0.655748,stdev=0.066537, epochs=199,mean epochs=200, time=0:00:42.15
# 7/7 [==============================] - 0s 2ms/step
# #12: score=0.634036, mean score=0.653939,stdev=0.063987, epochs=200,mean epochs=200, time=0:00:42.06
# 7/7 [==============================] - 0s 2ms/step
# #13: score=0.681685, mean score=0.656073,stdev=0.061919, epochs=238,mean epochs=203, time=0:01:23.06
# 7/7 [==============================] - 0s 3ms/step
# #14: score=0.707165, mean score=0.659723,stdev=0.061101, epochs=135,mean epochs=198, time=0:00:42.09
# 7/7 [==============================] - 0s 3ms/step
# #15: score=0.674897, mean score=0.660734,stdev=0.059150, epochs=155,mean epochs=195, time=0:00:42.09
# 7/7 [==============================] - 0s 2ms/step
# #16: score=0.609313, mean score=0.657520,stdev=0.058609, epochs=214,mean epochs=196, time=0:00:42.52
# 7/7 [==============================] - 0s 2ms/step
# #17: score=0.737723, mean score=0.662238,stdev=0.059909, epochs=184,mean epochs=195, time=0:00:42.53
# 7/7 [==============================] - 0s 2ms/step
# #18: score=0.652326, mean score=0.661687,stdev=0.058265, epochs=215,mean epochs=196, time=0:00:42.75
# 7/7 [==============================] - 0s 3ms/step
# #19: score=0.626400, mean score=0.659830,stdev=0.057256, epochs=184,mean epochs=196, time=0:00:42.08
# 7/7 [==============================] - 0s 2ms/step
# #20: score=0.649458, mean score=0.659312,stdev=0.055852, epochs=168,mean epochs=194, time=0:00:42.11
# 7/7 [==============================] - 0s 4ms/step
# #21: score=0.693662, mean score=0.660947,stdev=0.054994, epochs=181,mean epochs=194, time=0:00:35.30
# 7/7 [==============================] - 0s 2ms/step
# #22: score=0.683772, mean score=0.661985,stdev=0.053940, epochs=132,mean epochs=191, time=0:00:27.25
# 7/7 [==============================] - 0s 3ms/step
# #23: score=0.601846, mean score=0.659370,stdev=0.054161, epochs=221,mean epochs=192, time=0:01:23.19
# 7/7 [==============================] - 0s 4ms/step
# #24: score=0.633838, mean score=0.658306,stdev=0.053266, epochs=222,mean epochs=193, time=0:01:23.22
# 7/7 [==============================] - 0s 3ms/step
# #25: score=0.679390, mean score=0.659150,stdev=0.052353, epochs=217,mean epochs=194, time=0:01:23.13
# 7/7 [==============================] - 0s 3ms/step
# #26: score=0.601139, mean score=0.656918,stdev=0.052534, epochs=210,mean epochs=195, time=0:00:42.10
# 7/7 [==============================] - 0s 2ms/step
# #27: score=0.624587, mean score=0.655721,stdev=0.051913, epochs=213,mean epochs=195, time=0:00:42.12
# 7/7 [==============================] - 0s 4ms/step
# #28: score=0.656042, mean score=0.655732,stdev=0.050977, epochs=154,mean epochs=194, time=0:00:42.08
# 7/7 [==============================] - 0s 3ms/step
# #29: score=0.641493, mean score=0.655241,stdev=0.050158, epochs=161,mean epochs=193, time=0:00:31.78
# 7/7 [==============================] - 0s 2ms/step
# #30: score=0.677884, mean score=0.655996,stdev=0.049482, epochs=160,mean epochs=192, time=0:00:33.15
# 7/7 [==============================] - 0s 2ms/step
# #31: score=0.630310, mean score=0.655168,stdev=0.048889, epochs=224,mean epochs=193, time=0:00:43.99
# 7/7 [==============================] - 0s 3ms/step
# #32: score=0.631041, mean score=0.654414,stdev=0.048301, epochs=174,mean epochs=192, time=0:00:36.58
# 7/7 [==============================] - 0s 2ms/step
# #33: score=0.699050, mean score=0.655766,stdev=0.048175, epochs=175,mean epochs=192, time=0:00:36.56
# 7/7 [==============================] - 0s 3ms/step
# #34: score=0.663419, mean score=0.655991,stdev=0.047479, epochs=201,mean epochs=192, time=0:00:39.65
# 7/7 [==============================] - 0s 2ms/step
# #35: score=0.609689, mean score=0.654668,stdev=0.047428, epochs=243,mean epochs=193, time=0:00:50.03
# 7/7 [==============================] - 0s 2ms/step
# #36: score=0.661570, mean score=0.654860,stdev=0.046778, epochs=167,mean epochs=193, time=0:00:33.20
# 7/7 [==============================] - 0s 3ms/step
# #37: score=0.702049, mean score=0.656135,stdev=0.046772, epochs=171,mean epochs=192, time=0:00:42.15
# 7/7 [==============================] - 0s 4ms/step
# #38: score=0.670784, mean score=0.656521,stdev=0.046212, epochs=178,mean epochs=192, time=0:00:34.95
# 7/7 [==============================] - 0s 3ms/step
# #39: score=0.608041, mean score=0.655278,stdev=0.046255, epochs=229,mean epochs=193, time=0:01:23.58
# 7/7 [==============================] - 0s 4ms/step
# #40: score=0.667063, mean score=0.655572,stdev=0.045710, epochs=150,mean epochs=191, time=0:00:42.23
# 7/7 [==============================] - 0s 3ms/step
# #41: score=0.771497, mean score=0.658400,stdev=0.048561, epochs=145,mean epochs=190, time=0:00:42.17
# 7/7 [==============================] - 0s 2ms/step
# #42: score=0.606904, mean score=0.657174,stdev=0.048618, epochs=172,mean epochs=190, time=0:00:35.29
# 7/7 [==============================] - 0s 3ms/step
# #43: score=0.713130, mean score=0.658475,stdev=0.048784, epochs=160,mean epochs=189, time=0:00:42.12
# 7/7 [==============================] - 0s 2ms/step
# #44: score=0.614135, mean score=0.657467,stdev=0.048677, epochs=230,mean epochs=190, time=0:00:44.50
# 7/7 [==============================] - 0s 2ms/step
# #45: score=0.599313, mean score=0.656175,stdev=0.048890, epochs=223,mean epochs=191, time=0:01:23.02
# 7/7 [==============================] - 1s 2ms/step
# #46: score=0.641818, mean score=0.655863,stdev=0.048401, epochs=200,mean epochs=191, time=0:00:42.56
# 7/7 [==============================] - 0s 4ms/step
# #47: score=0.658420, mean score=0.655917,stdev=0.047885, epochs=170,mean epochs=191, time=0:00:42.13
# 7/7 [==============================] - 0s 2ms/step
# #48: score=0.584719, mean score=0.654434,stdev=0.048462, epochs=303,mean epochs=193, time=0:01:01.24
# 7/7 [==============================] - 0s 3ms/step
# #49: score=0.665316, mean score=0.654656,stdev=0.047990, epochs=181,mean epochs=193, time=0:00:42.11
# 7/7 [==============================] - 0s 3ms/step
# #50: score=0.710048, mean score=0.655764,stdev=0.048136, epochs=152,mean epochs=192, time=0:00:30.87
# 7/7 [==============================] - 0s 3ms/step
# #51: score=0.580838, mean score=0.654295,stdev=0.048781, epochs=192,mean epochs=192, time=0:00:42.10
# 7/7 [==============================] - 0s 2ms/step
# #52: score=0.646553, mean score=0.654146,stdev=0.048322, epochs=164,mean epochs=191, time=0:00:33.18
# 7/7 [==============================] - 0s 3ms/step
# #53: score=0.720720, mean score=0.655402,stdev=0.048713, epochs=157,mean epochs=191, time=0:00:31.87
# 7/7 [==============================] - 0s 2ms/step
# #54: score=0.681554, mean score=0.655886,stdev=0.048388, epochs=251,mean epochs=192, time=0:00:50.11
# 7/7 [==============================] - 0s 2ms/step
# #55: score=0.613926, mean score=0.655123,stdev=0.048273, epochs=252,mean epochs=193, time=0:00:50.48
# 7/7 [==============================] - 0s 2ms/step
# #56: score=0.725405, mean score=0.656378,stdev=0.048737, epochs=130,mean epochs=192, time=0:00:42.06
# 7/7 [==============================] - 0s 2ms/step
# #57: score=0.735735, mean score=0.657771,stdev=0.049419, epochs=147,mean epochs=191, time=0:00:28.94
# 7/7 [==============================] - 0s 2ms/step
# #58: score=0.573730, mean score=0.656322,stdev=0.050197, epochs=251,mean epochs=192, time=0:00:48.37
# 7/7 [==============================] - 0s 3ms/step
# #59: score=0.637363, mean score=0.656000,stdev=0.049830, epochs=233,mean epochs=193, time=0:01:23.03
# 7/7 [==============================] - 0s 2ms/step
# #60: score=0.715476, mean score=0.656992,stdev=0.049996, epochs=133,mean epochs=192, time=0:00:27.50
# 7/7 [==============================] - 0s 3ms/step
# #61: score=0.738575, mean score=0.658329,stdev=0.050655, epochs=129,mean epochs=191, time=0:00:42.51
# 7/7 [==============================] - 0s 3ms/step
# #62: score=0.649234, mean score=0.658182,stdev=0.050258, epochs=198,mean epochs=191, time=0:00:42.12
# 7/7 [==============================] - 0s 2ms/step
# #63: score=0.672732, mean score=0.658413,stdev=0.049891, epochs=182,mean epochs=190, time=0:00:36.86
# 7/7 [==============================] - 0s 3ms/step
# #64: score=0.668519, mean score=0.658571,stdev=0.049516, epochs=180,mean epochs=190, time=0:00:42.16
# 7/7 [==============================] - 0s 3ms/step
# #65: score=0.689175, mean score=0.659042,stdev=0.049277, epochs=186,mean epochs=190, time=0:00:42.17
# 7/7 [==============================] - 0s 3ms/step
# #66: score=0.692196, mean score=0.659544,stdev=0.049070, epochs=193,mean epochs=190, time=0:00:42.14
# 7/7 [==============================] - 0s 3ms/step
# #67: score=0.733152, mean score=0.660643,stdev=0.049514, epochs=215,mean epochs=191, time=0:00:43.57
# 7/7 [==============================] - 0s 3ms/step
# #68: score=0.733664, mean score=0.661717,stdev=0.049928, epochs=173,mean epochs=190, time=0:00:42.57
# 7/7 [==============================] - 0s 2ms/step
# #69: score=0.693881, mean score=0.662183,stdev=0.049714, epochs=239,mean epochs=191, time=0:00:46.92
# 7/7 [==============================] - 0s 2ms/step
# #70: score=0.600055, mean score=0.661295,stdev=0.049905, epochs=209,mean epochs=191, time=0:00:41.98
# 7/7 [==============================] - 0s 3ms/step
# #71: score=0.742646, mean score=0.662441,stdev=0.050471, epochs=144,mean epochs=191, time=0:00:28.56
# 7/7 [==============================] - 0s 2ms/step
# #72: score=0.644995, mean score=0.662199,stdev=0.050161, epochs=246,mean epochs=191, time=0:00:48.30
# 7/7 [==============================] - 0s 2ms/step
# #73: score=0.606611, mean score=0.661437,stdev=0.050233, epochs=202,mean epochs=192, time=0:00:42.10
# 7/7 [==============================] - 0s 3ms/step
# #74: score=0.587401, mean score=0.660437,stdev=0.050620, epochs=166,mean epochs=191, time=0:00:33.66
# 7/7 [==============================] - 0s 3ms/step
# #75: score=0.687204, mean score=0.660794,stdev=0.050375, epochs=232,mean epochs=192, time=0:00:46.09
# 7/7 [==============================] - 0s 3ms/step
# #76: score=0.751661, mean score=0.661989,stdev=0.051102, epochs=124,mean epochs=191, time=0:00:42.14
# 7/7 [==============================] - 0s 2ms/step
# #77: score=0.605593, mean score=0.661257,stdev=0.051169, epochs=172,mean epochs=191, time=0:00:34.07
# 7/7 [==============================] - 0s 3ms/step
# #78: score=0.681566, mean score=0.661517,stdev=0.050892, epochs=167,mean epochs=190, time=0:00:33.25
# 7/7 [==============================] - 0s 2ms/step
# #79: score=0.740351, mean score=0.662515,stdev=0.051331, epochs=166,mean epochs=190, time=0:00:34.10
# 7/7 [==============================] - 0s 3ms/step
# #80: score=0.616098, mean score=0.661935,stdev=0.051269, epochs=165,mean epochs=190, time=0:00:42.10
# 7/7 [==============================] - 0s 3ms/step
# #81: score=0.649730, mean score=0.661784,stdev=0.050969, epochs=220,mean epochs=190, time=0:00:46.47
# 7/7 [==============================] - 0s 3ms/step
# #82: score=0.656208, mean score=0.661716,stdev=0.050661, epochs=157,mean epochs=190, time=0:00:32.10
# 7/7 [==============================] - 0s 2ms/step
# #83: score=0.622703, mean score=0.661246,stdev=0.050535, epochs=285,mean epochs=191, time=0:00:54.99
# 7/7 [==============================] - 0s 2ms/step
# #84: score=0.585443, mean score=0.660344,stdev=0.050901, epochs=191,mean epochs=191, time=0:00:36.88
# 7/7 [==============================] - 0s 2ms/step
# #85: score=0.580085, mean score=0.659400,stdev=0.051336, epochs=234,mean epochs=191, time=0:01:23.08
# 7/7 [==============================] - 0s 3ms/step
# #86: score=0.677572, mean score=0.659611,stdev=0.051073, epochs=127,mean epochs=190, time=0:00:42.08
# 7/7 [==============================] - 0s 3ms/step
# #87: score=0.612101, mean score=0.659065,stdev=0.051031, epochs=208,mean epochs=191, time=0:00:42.17
# 7/7 [==============================] - 0s 4ms/step
# #88: score=0.541528, mean score=0.657729,stdev=0.052247, epochs=221,mean epochs=191, time=0:01:23.18
# 7/7 [==============================] - 0s 3ms/step
# #89: score=0.669891, mean score=0.657866,stdev=0.051969, epochs=152,mean epochs=191, time=0:00:30.24
# 7/7 [==============================] - 0s 2ms/step
# #90: score=0.605621, mean score=0.657285,stdev=0.051969, epochs=279,mean epochs=192, time=0:00:56.05
# 7/7 [==============================] - 0s 3ms/step
# #91: score=0.653245, mean score=0.657241,stdev=0.051684, epochs=166,mean epochs=191, time=0:00:33.82
# 7/7 [==============================] - 0s 2ms/step
# #92: score=0.688924, mean score=0.657585,stdev=0.051507, epochs=199,mean epochs=191, time=0:00:38.90
# 7/7 [==============================] - 0s 3ms/step
# #93: score=0.650858, mean score=0.657513,stdev=0.051234, epochs=201,mean epochs=191, time=0:00:42.12
# 7/7 [==============================] - 0s 3ms/step
# #94: score=0.686660, mean score=0.657823,stdev=0.051049, epochs=184,mean epochs=191, time=0:00:42.22
# 7/7 [==============================] - 0s 2ms/step
# #95: score=0.593870, mean score=0.657150,stdev=0.051197, epochs=231,mean epochs=192, time=0:01:23.21
# 7/7 [==============================] - 0s 3ms/step
# #96: score=0.686664, mean score=0.657457,stdev=0.051018, epochs=198,mean epochs=192, time=0:00:40.00
# 7/7 [==============================] - 0s 3ms/step
# #97: score=0.585996, mean score=0.656721,stdev=0.051265, epochs=190,mean epochs=192, time=0:00:40.80
# 7/7 [==============================] - 0s 3ms/step
# #98: score=0.689933, mean score=0.657060,stdev=0.051112, epochs=159,mean epochs=191, time=0:00:42.18
# 7/7 [==============================] - 0s 3ms/step
# #99: score=0.637218, mean score=0.656859,stdev=0.050891, epochs=263,mean epochs=192, time=0:00:54.60
# 7/7 [==============================] - 0s 2ms/step
# #100: score=0.654090, mean score=0.656831,stdev=0.050637, epochs=196,mean epochs=192, time=0:00:42.10
