# %% [markdown]
# # Applications of Deep Neural Networks

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 3.4: Early Stopping in Keras to Prevent Overfitting
#
# It can be difficult to determine how many epochs to cycle through to train a neural network. Overfitting will occur if you train the neural network for too many epochs, and the neural network will not perform well on new data, despite attaining a good accuracy on the training set. Overfitting occurs when a neural network is trained to the point that it begins to memorize rather than generalize, as demonstrated in Figure 3.OVER.
#
# **Figure 3.OVER: Training vs. Validation Error for Overfitting**
# ![Training vs. Validation Error for Overfitting](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_3_training_val.png "Training vs. Validation Error for Overfitting")
#
# It is important to segment the original dataset into several datasets:
#
# * **Training Set**
# * **Validation Set**
# * **Holdout Set**
#
# You can construct these sets in several different ways. The following programs demonstrate some of these.
#
# The first method is a training and validation set. We use the training data to train the neural network until the validation set no longer improves. This attempts to stop at a near-optimal training point. This method will only give accurate "out of sample" predictions for the validation set; this is usually 20% of the data. The predictions for the training data will be overly optimistic, as these were the data that we used to train the neural network. Figure 3.VAL demonstrates how we divide the dataset.
#
# **Figure 3.VAL: Training with a Validation Set**
# ![Training with a Validation Set](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_1_train_val.png "Training with a Validation Set")

# %% [markdown]
# ## Early Stopping with Classification
#
# We will now see an example of classification training with early stopping. We will train the neural network until the error no longer improves on the validation set.

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values

# Split into validation and training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build neural network
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor],verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 - 1s - loss: 1.1147 - val_loss: 1.0568 - 894ms/epoch - 223ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 1.0341 - val_loss: 0.9940 - 36ms/epoch - 9ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 0.9808 - val_loss: 0.9280 - 37ms/epoch - 9ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 0.9233 - val_loss: 0.8837 - 39ms/epoch - 10ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 0.8875 - val_loss: 0.8432 - 44ms/epoch - 11ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 0.8492 - val_loss: 0.8041 - 41ms/epoch - 10ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.8132 - val_loss: 0.7690 - 48ms/epoch - 12ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.7808 - val_loss: 0.7336 - 36ms/epoch - 9ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.7498 - val_loss: 0.7001 - 36ms/epoch - 9ms/step
# Epoch 10/1000
# 4/4 - 0s - loss: 0.7183 - val_loss: 0.6694 - 34ms/epoch - 9ms/step
# Epoch 11/1000
# 4/4 - 0s - loss: 0.6898 - val_loss: 0.6378 - 50ms/epoch - 13ms/step
# Epoch 12/1000
# 4/4 - 0s - loss: 0.6627 - val_loss: 0.6050 - 35ms/epoch - 9ms/step
# Epoch 13/1000
# 4/4 - 0s - loss: 0.6344 - val_loss: 0.5763 - 41ms/epoch - 10ms/step
# Epoch 14/1000
# 4/4 - 0s - loss: 0.6086 - val_loss: 0.5500 - 37ms/epoch - 9ms/step
# Epoch 15/1000
# 4/4 - 0s - loss: 0.5845 - val_loss: 0.5262 - 36ms/epoch - 9ms/step
# Epoch 16/1000
# 4/4 - 0s - loss: 0.5647 - val_loss: 0.5041 - 36ms/epoch - 9ms/step
# Epoch 17/1000
# 4/4 - 0s - loss: 0.5389 - val_loss: 0.4785 - 60ms/epoch - 15ms/step
# Epoch 18/1000
# 4/4 - 0s - loss: 0.5144 - val_loss: 0.4589 - 50ms/epoch - 12ms/step
# Epoch 19/1000
# 4/4 - 0s - loss: 0.4939 - val_loss: 0.4407 - 59ms/epoch - 15ms/step
# Epoch 20/1000
# 4/4 - 0s - loss: 0.4749 - val_loss: 0.4237 - 49ms/epoch - 12ms/step
# Epoch 21/1000
# 4/4 - 0s - loss: 0.4581 - val_loss: 0.4080 - 57ms/epoch - 14ms/step
# Epoch 22/1000
# 4/4 - 0s - loss: 0.4417 - val_loss: 0.3913 - 92ms/epoch - 23ms/step
# Epoch 23/1000
# 4/4 - 0s - loss: 0.4272 - val_loss: 0.3769 - 42ms/epoch - 10ms/step
# Epoch 24/1000
# 4/4 - 0s - loss: 0.4110 - val_loss: 0.3634 - 36ms/epoch - 9ms/step
# Epoch 25/1000
# 4/4 - 0s - loss: 0.3977 - val_loss: 0.3505 - 43ms/epoch - 11ms/step
# Epoch 26/1000
# 4/4 - 0s - loss: 0.3854 - val_loss: 0.3382 - 61ms/epoch - 15ms/step
# Epoch 27/1000
# 4/4 - 0s - loss: 0.3734 - val_loss: 0.3275 - 38ms/epoch - 9ms/step
# Epoch 28/1000
# 4/4 - 0s - loss: 0.3644 - val_loss: 0.3179 - 41ms/epoch - 10ms/step
# Epoch 29/1000
# 4/4 - 0s - loss: 0.3491 - val_loss: 0.3068 - 38ms/epoch - 9ms/step
# Epoch 30/1000
# 4/4 - 0s - loss: 0.3454 - val_loss: 0.2997 - 44ms/epoch - 11ms/step
# Epoch 31/1000
# 4/4 - 0s - loss: 0.3357 - val_loss: 0.2890 - 43ms/epoch - 11ms/step
# Epoch 32/1000
# 4/4 - 0s - loss: 0.3235 - val_loss: 0.2817 - 55ms/epoch - 14ms/step
# Epoch 33/1000
# 4/4 - 0s - loss: 0.3178 - val_loss: 0.2728 - 39ms/epoch - 10ms/step
# Epoch 34/1000
# 4/4 - 0s - loss: 0.3056 - val_loss: 0.2665 - 40ms/epoch - 10ms/step
# Epoch 35/1000
# 4/4 - 0s - loss: 0.2984 - val_loss: 0.2613 - 39ms/epoch - 10ms/step
# Epoch 36/1000
# 4/4 - 0s - loss: 0.2878 - val_loss: 0.2514 - 40ms/epoch - 10ms/step
# Epoch 37/1000
# 4/4 - 0s - loss: 0.2835 - val_loss: 0.2453 - 37ms/epoch - 9ms/step
# Epoch 38/1000
# 4/4 - 0s - loss: 0.2774 - val_loss: 0.2380 - 37ms/epoch - 9ms/step
# Epoch 39/1000
# 4/4 - 0s - loss: 0.2669 - val_loss: 0.2320 - 46ms/epoch - 11ms/step
# Epoch 40/1000
# 4/4 - 0s - loss: 0.2598 - val_loss: 0.2272 - 38ms/epoch - 10ms/step
# Epoch 41/1000
# 4/4 - 0s - loss: 0.2526 - val_loss: 0.2195 - 39ms/epoch - 10ms/step
# Epoch 42/1000
# 4/4 - 0s - loss: 0.2472 - val_loss: 0.2141 - 38ms/epoch - 9ms/step
# Epoch 43/1000
# 4/4 - 0s - loss: 0.2439 - val_loss: 0.2144 - 39ms/epoch - 10ms/step
# Epoch 44/1000
# 4/4 - 0s - loss: 0.2366 - val_loss: 0.2069 - 39ms/epoch - 10ms/step
# Epoch 45/1000
# 4/4 - 0s - loss: 0.2298 - val_loss: 0.2012 - 38ms/epoch - 10ms/step
# Epoch 46/1000
# 4/4 - 0s - loss: 0.2233 - val_loss: 0.1950 - 34ms/epoch - 9ms/step
# Epoch 47/1000
# 4/4 - 0s - loss: 0.2235 - val_loss: 0.1905 - 34ms/epoch - 8ms/step
# Epoch 48/1000
# 4/4 - 0s - loss: 0.2139 - val_loss: 0.1890 - 45ms/epoch - 11ms/step
# Epoch 49/1000
# 4/4 - 0s - loss: 0.2118 - val_loss: 0.1901 - 35ms/epoch - 9ms/step
# Epoch 50/1000
# 4/4 - 0s - loss: 0.2063 - val_loss: 0.1798 - 41ms/epoch - 10ms/step
# Epoch 51/1000
# 4/4 - 0s - loss: 0.2002 - val_loss: 0.1746 - 36ms/epoch - 9ms/step
# Epoch 52/1000
# 4/4 - 0s - loss: 0.1985 - val_loss: 0.1709 - 39ms/epoch - 10ms/step
# Epoch 53/1000
# 4/4 - 0s - loss: 0.1939 - val_loss: 0.1677 - 35ms/epoch - 9ms/step
# Epoch 54/1000
# 4/4 - 0s - loss: 0.1882 - val_loss: 0.1675 - 36ms/epoch - 9ms/step
# Epoch 55/1000
# 4/4 - 0s - loss: 0.1885 - val_loss: 0.1645 - 53ms/epoch - 13ms/step
# Epoch 56/1000
# 4/4 - 0s - loss: 0.1799 - val_loss: 0.1571 - 35ms/epoch - 9ms/step
# Epoch 57/1000
# 4/4 - 0s - loss: 0.1813 - val_loss: 0.1540 - 37ms/epoch - 9ms/step
# Epoch 58/1000
# 4/4 - 0s - loss: 0.1758 - val_loss: 0.1522 - 38ms/epoch - 9ms/step
# Epoch 59/1000
# 4/4 - 0s - loss: 0.1721 - val_loss: 0.1584 - 35ms/epoch - 9ms/step
# Epoch 60/1000
# 4/4 - 0s - loss: 0.1698 - val_loss: 0.1493 - 38ms/epoch - 9ms/step
# Epoch 61/1000
# 4/4 - 0s - loss: 0.1660 - val_loss: 0.1423 - 36ms/epoch - 9ms/step
# Epoch 62/1000
# 4/4 - 0s - loss: 0.1630 - val_loss: 0.1407 - 33ms/epoch - 8ms/step
# Epoch 63/1000
# 4/4 - 0s - loss: 0.1583 - val_loss: 0.1430 - 40ms/epoch - 10ms/step
# Epoch 64/1000
# 4/4 - 0s - loss: 0.1560 - val_loss: 0.1371 - 33ms/epoch - 8ms/step
# Epoch 65/1000
# 4/4 - 0s - loss: 0.1536 - val_loss: 0.1358 - 34ms/epoch - 8ms/step
# Epoch 66/1000
# 4/4 - 0s - loss: 0.1489 - val_loss: 0.1308 - 40ms/epoch - 10ms/step
# Epoch 67/1000
# 4/4 - 0s - loss: 0.1481 - val_loss: 0.1278 - 40ms/epoch - 10ms/step
# Epoch 68/1000
# 4/4 - 0s - loss: 0.1450 - val_loss: 0.1310 - 44ms/epoch - 11ms/step
# Epoch 69/1000
# 4/4 - 0s - loss: 0.1435 - val_loss: 0.1272 - 62ms/epoch - 16ms/step
# Epoch 70/1000
# 4/4 - 0s - loss: 0.1395 - val_loss: 0.1208 - 46ms/epoch - 11ms/step
# Epoch 71/1000
# 4/4 - 0s - loss: 0.1493 - val_loss: 0.1191 - 62ms/epoch - 16ms/step
# Epoch 72/1000
# 4/4 - 0s - loss: 0.1380 - val_loss: 0.1304 - 44ms/epoch - 11ms/step
# Epoch 73/1000
# 4/4 - 0s - loss: 0.1414 - val_loss: 0.1316 - 37ms/epoch - 9ms/step
# Epoch 74/1000
# 4/4 - 0s - loss: 0.1344 - val_loss: 0.1164 - 39ms/epoch - 10ms/step
# Epoch 75/1000
# 4/4 - 0s - loss: 0.1282 - val_loss: 0.1118 - 39ms/epoch - 10ms/step
# Epoch 76/1000
# 4/4 - 0s - loss: 0.1307 - val_loss: 0.1101 - 45ms/epoch - 11ms/step
# Epoch 77/1000
# 4/4 - 0s - loss: 0.1282 - val_loss: 0.1155 - 38ms/epoch - 10ms/step
# Epoch 78/1000
# 4/4 - 0s - loss: 0.1284 - val_loss: 0.1155 - 37ms/epoch - 9ms/step
# Epoch 79/1000
# 4/4 - 0s - loss: 0.1221 - val_loss: 0.1054 - 46ms/epoch - 12ms/step
# Epoch 80/1000
# 4/4 - 0s - loss: 0.1258 - val_loss: 0.1040 - 43ms/epoch - 11ms/step
# Epoch 81/1000
# 4/4 - 0s - loss: 0.1180 - val_loss: 0.1155 - 39ms/epoch - 10ms/step
# Epoch 82/1000
# 4/4 - 0s - loss: 0.1254 - val_loss: 0.1184 - 40ms/epoch - 10ms/step
# Epoch 83/1000
# 4/4 - 0s - loss: 0.1159 - val_loss: 0.0998 - 38ms/epoch - 10ms/step
# Epoch 84/1000
# 4/4 - 0s - loss: 0.1229 - val_loss: 0.0988 - 39ms/epoch - 10ms/step
# Epoch 85/1000
# 4/4 - 0s - loss: 0.1182 - val_loss: 0.1067 - 46ms/epoch - 11ms/step
# Epoch 86/1000
# 4/4 - 0s - loss: 0.1148 - val_loss: 0.1085 - 44ms/epoch - 11ms/step
# Epoch 87/1000
# 4/4 - 0s - loss: 0.1131 - val_loss: 0.0996 - 39ms/epoch - 10ms/step
# Epoch 88/1000
# 4/4 - 0s - loss: 0.1117 - val_loss: 0.0975 - 40ms/epoch - 10ms/step
# Epoch 89/1000
# 4/4 - 0s - loss: 0.1090 - val_loss: 0.0956 - 46ms/epoch - 12ms/step
# Epoch 90/1000
# 4/4 - 0s - loss: 0.1080 - val_loss: 0.0940 - 41ms/epoch - 10ms/step
# Epoch 91/1000
# 4/4 - 0s - loss: 0.1072 - val_loss: 0.0936 - 40ms/epoch - 10ms/step
# Epoch 92/1000
# 4/4 - 0s - loss: 0.1081 - val_loss: 0.0925 - 42ms/epoch - 10ms/step
# Epoch 93/1000
# 4/4 - 0s - loss: 0.1051 - val_loss: 0.0935 - 45ms/epoch - 11ms/step
# Epoch 94/1000
# 4/4 - 0s - loss: 0.1035 - val_loss: 0.0960 - 35ms/epoch - 9ms/step
# Epoch 95/1000
# 4/4 - 0s - loss: 0.1036 - val_loss: 0.0980 - 38ms/epoch - 9ms/step
# Epoch 96/1000
# 4/4 - 0s - loss: 0.1026 - val_loss: 0.0925 - 37ms/epoch - 9ms/step
# Epoch 97/1000
# 4/4 - 0s - loss: 0.1024 - val_loss: 0.0877 - 38ms/epoch - 9ms/step
# Epoch 98/1000
# 4/4 - 0s - loss: 0.1030 - val_loss: 0.0923 - 36ms/epoch - 9ms/step
# Epoch 99/1000
# 4/4 - 0s - loss: 0.1019 - val_loss: 0.0858 - 42ms/epoch - 10ms/step
# Epoch 100/1000
# 4/4 - 0s - loss: 0.1001 - val_loss: 0.0863 - 37ms/epoch - 9ms/step
# Epoch 101/1000
# 4/4 - 0s - loss: 0.0974 - val_loss: 0.0928 - 42ms/epoch - 10ms/step
# Epoch 102/1000
# 4/4 - 0s - loss: 0.0991 - val_loss: 0.0923 - 35ms/epoch - 9ms/step
# Epoch 103/1000
# 4/4 - 0s - loss: 0.0985 - val_loss: 0.0918 - 40ms/epoch - 10ms/step
# Epoch 104/1000
# 4/4 - 0s - loss: 0.1010 - val_loss: 0.0823 - 39ms/epoch - 10ms/step
# Epoch 105/1000
# 4/4 - 0s - loss: 0.0981 - val_loss: 0.0897 - 41ms/epoch - 10ms/step
# Epoch 106/1000
# 4/4 - 0s - loss: 0.0947 - val_loss: 0.0823 - 38ms/epoch - 10ms/step
# Epoch 107/1000
# 4/4 - 0s - loss: 0.0941 - val_loss: 0.0826 - 36ms/epoch - 9ms/step
# Epoch 108/1000
# 4/4 - 0s - loss: 0.0936 - val_loss: 0.0813 - 58ms/epoch - 14ms/step
# Epoch 109/1000
# Restoring model weights from the end of the best epoch: 104.
# 4/4 - 0s - loss: 0.0931 - val_loss: 0.0862 - 65ms/epoch - 16ms/step
# Epoch 109: early stopping

# %% [markdown]
# There are a number of parameters that are specified to the **EarlyStopping** object.
#
# * **min_delta** This value should be kept small. It simply means the minimum change in error to be registered as an improvement.  Setting it even smaller will not likely have a great deal of impact.
# * **patience** How long should the training wait for the validation error to improve?
# * **verbose** How much progress information do you want?
# * **mode** In general, always set this to "auto".  This allows you to specify if the error should be minimized or maximized.  Consider accuracy, where higher numbers are desired vs log-loss/RMSE where lower numbers are desired.
# * **restore_best_weights** This should always be set to true.  This restores the weights to the values they were at when the validation set is the highest.  Unless you are manually tracking the weights yourself (we do not use this technique in this course), you should have Keras perform this step for you.
#
# As you can see from above, the entire number of requested epochs were not used.  The neural network training stopped once the validation set no longer improved.

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(x_test)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y_test,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Accuracy: {correct}")
# Out:
# 2/2 [==============================] - 0s 20ms/step
# Accuracy: 1.0

# %% [markdown]
# ## Early Stopping with Regression
#
# The following code demonstrates how we can apply early stopping to a regression problem.  The technique is similar to the early stopping for classification code that we just saw.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Split into validation and training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=5, verbose=1, mode='auto',
        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor], verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 10/10 - 1s - loss: 2675.6570 - val_loss: 889.0382 - 1s/epoch - 108ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 973.3712 - val_loss: 175.4762 - 94ms/epoch - 9ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 213.9860 - val_loss: 340.4580 - 132ms/epoch - 13ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 183.8119 - val_loss: 134.3669 - 109ms/epoch - 11ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 147.5622 - val_loss: 102.4551 - 125ms/epoch - 12ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 117.5072 - val_loss: 107.4524 - 115ms/epoch - 11ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 110.1984 - val_loss: 101.6329 - 136ms/epoch - 14ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 102.0656 - val_loss: 97.8893 - 128ms/epoch - 13ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 97.5584 - val_loss: 93.7600 - 83ms/epoch - 8ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 95.9166 - val_loss: 91.0353 - 81ms/epoch - 8ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 92.3542 - val_loss: 88.3025 - 86ms/epoch - 9ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 91.1115 - val_loss: 85.8284 - 109ms/epoch - 11ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 89.3516 - val_loss: 83.6753 - 84ms/epoch - 8ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 88.4066 - val_loss: 81.3567 - 94ms/epoch - 9ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 86.2147 - val_loss: 79.0874 - 98ms/epoch - 10ms/step
# Epoch 16/1000
# 10/10 - 0s - loss: 85.9919 - val_loss: 77.0861 - 86ms/epoch - 9ms/step
# Epoch 17/1000
# 10/10 - 0s - loss: 81.7698 - val_loss: 74.8850 - 172ms/epoch - 17ms/step
# Epoch 18/1000
# 10/10 - 0s - loss: 79.9961 - val_loss: 73.0708 - 124ms/epoch - 12ms/step
# Epoch 19/1000
# 10/10 - 0s - loss: 77.7321 - val_loss: 70.6921 - 110ms/epoch - 11ms/step
# Epoch 20/1000
# 10/10 - 0s - loss: 75.7204 - val_loss: 68.7048 - 90ms/epoch - 9ms/step
# Epoch 21/1000
# 10/10 - 0s - loss: 74.6666 - val_loss: 66.8900 - 100ms/epoch - 10ms/step
# Epoch 22/1000
# 10/10 - 0s - loss: 72.1103 - val_loss: 65.0810 - 97ms/epoch - 10ms/step
# Epoch 23/1000
# 10/10 - 0s - loss: 69.9494 - val_loss: 63.3548 - 200ms/epoch - 20ms/step
# Epoch 24/1000
# 10/10 - 0s - loss: 68.4375 - val_loss: 61.6938 - 110ms/epoch - 11ms/step
# Epoch 25/1000
# 10/10 - 0s - loss: 67.5552 - val_loss: 60.5857 - 90ms/epoch - 9ms/step
# Epoch 26/1000
# 10/10 - 0s - loss: 66.2414 - val_loss: 58.7038 - 87ms/epoch - 9ms/step
# Epoch 27/1000
# 10/10 - 0s - loss: 64.4145 - val_loss: 57.2696 - 90ms/epoch - 9ms/step
# Epoch 28/1000
# 10/10 - 0s - loss: 62.6838 - val_loss: 55.8453 - 155ms/epoch - 16ms/step
# Epoch 29/1000
# 10/10 - 0s - loss: 61.9870 - val_loss: 55.1239 - 102ms/epoch - 10ms/step
# Epoch 30/1000
# 10/10 - 0s - loss: 61.0151 - val_loss: 53.2314 - 152ms/epoch - 15ms/step
# Epoch 31/1000
# 10/10 - 0s - loss: 60.8838 - val_loss: 52.3899 - 106ms/epoch - 11ms/step
# Epoch 32/1000
# 10/10 - 0s - loss: 58.7733 - val_loss: 52.5688 - 104ms/epoch - 10ms/step
# Epoch 33/1000
# 10/10 - 0s - loss: 56.7664 - val_loss: 51.1847 - 93ms/epoch - 9ms/step
# Epoch 34/1000
# 10/10 - 0s - loss: 57.4273 - val_loss: 52.2302 - 153ms/epoch - 15ms/step
# Epoch 35/1000
# 10/10 - 0s - loss: 56.9959 - val_loss: 47.9519 - 108ms/epoch - 11ms/step
# Epoch 36/1000
# 10/10 - 0s - loss: 55.6857 - val_loss: 47.0315 - 89ms/epoch - 9ms/step
# Epoch 37/1000
# 10/10 - 0s - loss: 54.2782 - val_loss: 46.3567 - 78ms/epoch - 8ms/step
# Epoch 38/1000
# 10/10 - 0s - loss: 53.6164 - val_loss: 45.7295 - 112ms/epoch - 11ms/step
# Epoch 39/1000
# 10/10 - 0s - loss: 52.5435 - val_loss: 44.6300 - 93ms/epoch - 9ms/step
# Epoch 40/1000
# 10/10 - 0s - loss: 51.4085 - val_loss: 48.2945 - 95ms/epoch - 9ms/step
# Epoch 41/1000
# 10/10 - 0s - loss: 50.3168 - val_loss: 45.3627 - 124ms/epoch - 12ms/step
# Epoch 42/1000
# 10/10 - 0s - loss: 51.0491 - val_loss: 48.9668 - 75ms/epoch - 7ms/step
# Epoch 43/1000
# 10/10 - 0s - loss: 51.4856 - val_loss: 42.2208 - 95ms/epoch - 9ms/step
# Epoch 44/1000
# 10/10 - 0s - loss: 47.9958 - val_loss: 41.3023 - 86ms/epoch - 9ms/step
# Epoch 45/1000
# 10/10 - 0s - loss: 47.5743 - val_loss: 40.8029 - 141ms/epoch - 14ms/step
# Epoch 46/1000
# 10/10 - 0s - loss: 47.1777 - val_loss: 40.5195 - 115ms/epoch - 12ms/step
# Epoch 47/1000
# 10/10 - 0s - loss: 47.7888 - val_loss: 39.8403 - 106ms/epoch - 11ms/step
# Epoch 48/1000
# 10/10 - 0s - loss: 47.9500 - val_loss: 39.5348 - 98ms/epoch - 10ms/step
# Epoch 49/1000
# 10/10 - 0s - loss: 45.1245 - val_loss: 38.8349 - 158ms/epoch - 16ms/step
# Epoch 50/1000
# 10/10 - 0s - loss: 45.6249 - val_loss: 39.1171 - 98ms/epoch - 10ms/step
# Epoch 51/1000
# 10/10 - 0s - loss: 44.2972 - val_loss: 37.8504 - 210ms/epoch - 21ms/step
# Epoch 52/1000
# 10/10 - 0s - loss: 43.6461 - val_loss: 38.5895 - 78ms/epoch - 8ms/step
# Epoch 53/1000
# 10/10 - 0s - loss: 43.5024 - val_loss: 36.8279 - 86ms/epoch - 9ms/step
# Epoch 54/1000
# 10/10 - 0s - loss: 42.6841 - val_loss: 38.1642 - 102ms/epoch - 10ms/step
# Epoch 55/1000
# 10/10 - 0s - loss: 43.2484 - val_loss: 37.4451 - 128ms/epoch - 13ms/step
# Epoch 56/1000
# 10/10 - 0s - loss: 42.8207 - val_loss: 35.5335 - 100ms/epoch - 10ms/step
# Epoch 57/1000
# 10/10 - 0s - loss: 41.6445 - val_loss: 35.1580 - 104ms/epoch - 10ms/step
# Epoch 58/1000
# 10/10 - 0s - loss: 41.4370 - val_loss: 36.1549 - 123ms/epoch - 12ms/step
# Epoch 59/1000
# 10/10 - 0s - loss: 42.6061 - val_loss: 34.3799 - 114ms/epoch - 11ms/step
# Epoch 60/1000
# 10/10 - 0s - loss: 41.3161 - val_loss: 37.3578 - 96ms/epoch - 10ms/step
# Epoch 61/1000
# 10/10 - 0s - loss: 40.9351 - val_loss: 33.7590 - 83ms/epoch - 8ms/step
# Epoch 62/1000
# 10/10 - 0s - loss: 39.2449 - val_loss: 34.0498 - 106ms/epoch - 11ms/step
# Epoch 63/1000
# 10/10 - 0s - loss: 38.3595 - val_loss: 33.0404 - 123ms/epoch - 12ms/step
# Epoch 64/1000
# 10/10 - 0s - loss: 38.0321 - val_loss: 32.4720 - 125ms/epoch - 13ms/step
# Epoch 65/1000
# 10/10 - 0s - loss: 38.5461 - val_loss: 32.0561 - 102ms/epoch - 10ms/step
# Epoch 66/1000
# 10/10 - 0s - loss: 37.4699 - val_loss: 31.8293 - 188ms/epoch - 19ms/step
# Epoch 67/1000
# 10/10 - 0s - loss: 36.8970 - val_loss: 31.2644 - 155ms/epoch - 15ms/step
# Epoch 68/1000
# 10/10 - 0s - loss: 36.3348 - val_loss: 31.0163 - 125ms/epoch - 13ms/step
# Epoch 69/1000
# 10/10 - 0s - loss: 35.9693 - val_loss: 31.7794 - 80ms/epoch - 8ms/step
# Epoch 70/1000
# 10/10 - 0s - loss: 36.0471 - val_loss: 31.5437 - 62ms/epoch - 6ms/step
# Epoch 71/1000
# 10/10 - 0s - loss: 35.6740 - val_loss: 31.2222 - 53ms/epoch - 5ms/step
# Epoch 72/1000
# 10/10 - 0s - loss: 35.1594 - val_loss: 30.2441 - 65ms/epoch - 7ms/step
# Epoch 73/1000
# 10/10 - 0s - loss: 34.6797 - val_loss: 29.1054 - 50ms/epoch - 5ms/step
# Epoch 74/1000
# 10/10 - 0s - loss: 34.0668 - val_loss: 29.5605 - 67ms/epoch - 7ms/step
# Epoch 75/1000
# 10/10 - 0s - loss: 34.9431 - val_loss: 34.1287 - 70ms/epoch - 7ms/step
# Epoch 76/1000
# 10/10 - 0s - loss: 35.1734 - val_loss: 31.2055 - 66ms/epoch - 7ms/step
# Epoch 77/1000
# 10/10 - 0s - loss: 34.5768 - val_loss: 27.8081 - 50ms/epoch - 5ms/step
# Epoch 78/1000
# 10/10 - 0s - loss: 35.2815 - val_loss: 33.8048 - 61ms/epoch - 6ms/step
# Epoch 79/1000
# 10/10 - 0s - loss: 35.0108 - val_loss: 31.0518 - 67ms/epoch - 7ms/step
# Epoch 80/1000
# 10/10 - 0s - loss: 33.5228 - val_loss: 27.3532 - 51ms/epoch - 5ms/step
# Epoch 81/1000
# 10/10 - 0s - loss: 31.0119 - val_loss: 26.4602 - 47ms/epoch - 5ms/step
# Epoch 82/1000
# 10/10 - 0s - loss: 31.4990 - val_loss: 28.3847 - 68ms/epoch - 7ms/step
# Epoch 83/1000
# 10/10 - 0s - loss: 38.3838 - val_loss: 26.6367 - 47ms/epoch - 5ms/step
# Epoch 84/1000
# 10/10 - 0s - loss: 32.0386 - val_loss: 25.4650 - 48ms/epoch - 5ms/step
# Epoch 85/1000
# 10/10 - 0s - loss: 31.1017 - val_loss: 26.4722 - 62ms/epoch - 6ms/step
# Epoch 86/1000
# 10/10 - 0s - loss: 30.6693 - val_loss: 32.8618 - 45ms/epoch - 5ms/step
# Epoch 87/1000
# 10/10 - 0s - loss: 32.8570 - val_loss: 31.6601 - 50ms/epoch - 5ms/step
# Epoch 88/1000
# 10/10 - 0s - loss: 31.7397 - val_loss: 24.2347 - 64ms/epoch - 6ms/step
# Epoch 89/1000
# 10/10 - 0s - loss: 28.6453 - val_loss: 24.3474 - 50ms/epoch - 5ms/step
# Epoch 90/1000
# 10/10 - 0s - loss: 28.3175 - val_loss: 24.5678 - 50ms/epoch - 5ms/step
# Epoch 91/1000
# 10/10 - 0s - loss: 28.6700 - val_loss: 25.1285 - 51ms/epoch - 5ms/step
# Epoch 92/1000
# 10/10 - 0s - loss: 27.7550 - val_loss: 24.6880 - 67ms/epoch - 7ms/step
# Epoch 93/1000
# 10/10 - 0s - loss: 27.3618 - val_loss: 22.7898 - 67ms/epoch - 7ms/step
# Epoch 94/1000
# 10/10 - 0s - loss: 26.8891 - val_loss: 22.6756 - 48ms/epoch - 5ms/step
# Epoch 95/1000
# 10/10 - 0s - loss: 26.6854 - val_loss: 23.3964 - 48ms/epoch - 5ms/step
# Epoch 96/1000
# 10/10 - 0s - loss: 25.8461 - val_loss: 23.6755 - 60ms/epoch - 6ms/step
# Epoch 97/1000
# 10/10 - 0s - loss: 26.7644 - val_loss: 22.0987 - 54ms/epoch - 5ms/step
# Epoch 98/1000
# 10/10 - 0s - loss: 26.4326 - val_loss: 21.4910 - 52ms/epoch - 5ms/step
# Epoch 99/1000
# 10/10 - 0s - loss: 26.2483 - val_loss: 21.2766 - 51ms/epoch - 5ms/step
# Epoch 100/1000
# 10/10 - 0s - loss: 25.7722 - val_loss: 21.1803 - 55ms/epoch - 6ms/step
# Epoch 101/1000
# 10/10 - 0s - loss: 24.7115 - val_loss: 21.9230 - 65ms/epoch - 6ms/step
# Epoch 102/1000
# 10/10 - 0s - loss: 26.4357 - val_loss: 21.9057 - 46ms/epoch - 5ms/step
# Epoch 103/1000
# 10/10 - 0s - loss: 26.3133 - val_loss: 23.1220 - 46ms/epoch - 5ms/step
# Epoch 104/1000
# 10/10 - 0s - loss: 25.9018 - val_loss: 20.5624 - 50ms/epoch - 5ms/step
# Epoch 105/1000
# 10/10 - 0s - loss: 23.6629 - val_loss: 19.6744 - 48ms/epoch - 5ms/step
# Epoch 106/1000
# 10/10 - 0s - loss: 23.5446 - val_loss: 20.5809 - 67ms/epoch - 7ms/step
# Epoch 107/1000
# 10/10 - 0s - loss: 25.6447 - val_loss: 20.7895 - 50ms/epoch - 5ms/step
# Epoch 108/1000
# 10/10 - 0s - loss: 23.4104 - val_loss: 19.3759 - 54ms/epoch - 5ms/step
# Epoch 109/1000
# 10/10 - 0s - loss: 22.8556 - val_loss: 19.8543 - 49ms/epoch - 5ms/step
# Epoch 110/1000
# 10/10 - 0s - loss: 22.9845 - val_loss: 19.3813 - 47ms/epoch - 5ms/step
# Epoch 111/1000
# 10/10 - 0s - loss: 23.2529 - val_loss: 22.5741 - 62ms/epoch - 6ms/step
# Epoch 112/1000
# 10/10 - 0s - loss: 23.0098 - val_loss: 18.3188 - 54ms/epoch - 5ms/step
# Epoch 113/1000
# 10/10 - 0s - loss: 22.0689 - val_loss: 20.1961 - 51ms/epoch - 5ms/step
# Epoch 114/1000
# 10/10 - 0s - loss: 22.1417 - val_loss: 20.5025 - 70ms/epoch - 7ms/step
# Epoch 115/1000
# 10/10 - 0s - loss: 22.7715 - val_loss: 19.6071 - 53ms/epoch - 5ms/step
# Epoch 116/1000
# 10/10 - 0s - loss: 23.0250 - val_loss: 19.9825 - 64ms/epoch - 6ms/step
# Epoch 117/1000
# Restoring model weights from the end of the best epoch: 112.
# 10/10 - 0s - loss: 24.2880 - val_loss: 22.3029 - 53ms/epoch - 5ms/step
# Epoch 117: early stopping

# %% [markdown]
# Finally, we evaluate the error.

# %%
# Measure RMSE error.  RMSE is common for regression.
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print(f"Final score (RMSE): {score}")
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Final score (RMSE): 4.28004852394684
