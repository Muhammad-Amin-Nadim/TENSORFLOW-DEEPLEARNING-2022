# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_08_5_kaggle_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Applications of Deep Neural Networks
# **Module 8: Kaggle Data Sets**

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
# Start CoLab
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 8.5: Current Semester's Kaggle
#
# Kaggke competition site for current semester:
# * [Fall 2022 Kaggle Assignment](https://www.kaggle.com/competitions/applications-of-deep-learning-wustlfall-2022)
#
# Previous Kaggle competition sites for this class (NOT this semester's assignment, feel free to use code):
# * [Spring 2022 Kaggle Assignment](https://www.kaggle.com/c/tsp-cv)
# * [Fall 2021 Kaggle Assignment](https://www.kaggle.com/c/applications-of-deep-learning-wustlfall-2021)
# * [Spring 2021 Kaggle Assignment](https://www.kaggle.com/c/applications-of-deep-learning-wustl-spring-2021b)
# * [Fall 2020 Kaggle Assignment](https://www.kaggle.com/c/applications-of-deep-learning-wustl-fall-2020)
# * [Spring 2020 Kaggle Assignment](https://www.kaggle.com/c/applications-of-deep-learningwustl-spring-2020)
# * [Fall 2019 Kaggle Assignment](https://kaggle.com/c/applications-of-deep-learningwustl-fall-2019)
# * [Spring 2019 Kaggle Assignment](https://www.kaggle.com/c/applications-of-deep-learningwustl-spring-2019)
# * [Fall 2018 Kaggle Assignment](https://www.kaggle.com/c/wustl-t81-558-washu-deep-learning-fall-2018)
# * [Spring 2018 Kaggle Assignment](https://www.kaggle.com/c/wustl-t81-558-washu-deep-learning-spring-2018)
# * [Fall 2017 Kaggle Assignment](https://www.kaggle.com/c/wustl-t81-558-washu-deep-learning-fall-2017)
# * [Spring 2017 Kaggle Assignment](https://inclass.kaggle.com/c/applications-of-deep-learning-wustl-spring-2017)
# * [Fall 2016 Kaggle Assignment](https://inclass.kaggle.com/c/wustl-t81-558-washu-deep-learning-fall-2016)

# %% [markdown]
# ## Iris as a Kaggle Competition
#
# If I used the Iris data as a Kaggle, I would give you the following three files:
#
# * [kaggle_iris_test.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_iris_test.csv) - The data that Kaggle will evaluate you on. It contains only input; you must provide answers.  (contains x)
# * [kaggle_iris_train.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_iris_train.csv) - The data that you will use to train. (contains x and y)
# * [kaggle_iris_sample.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_iris_sample.csv) - A sample submission for Kaggle. (contains x and y)
#
# Important features of the Kaggle iris files (that differ from how we've previously seen files):
#
# * The iris species is already index encoded.
# * Your training data is in a separate file.
# * You will load the test data to generate a submission file.
#
# The following program generates a submission file for "Iris Kaggle". You can use it as a starting point for assignment 3.

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

df_train = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/datasets/"+\
    "kaggle_iris_train.csv", na_values=['NA','?'])

# Encode feature vector
df_train.drop('id', axis=1, inplace=True)

num_classes = len(df_train.groupby('species').species.nunique())

print("Number of classes: {}".format(num_classes))

# Convert to numpy - Classification
x = df_train[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df_train['species']) # Classification
species = dummies.columns
y = dummies.values
    
# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=45)

# Train, with early stopping
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu'))
model.add(Dense(25))
model.add(Dense(y.shape[1],activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
                        patience=5, verbose=1, mode='auto',
                       restore_best_weights=True)

model.fit(x_train,y_train,validation_data=(x_test,y_test),
          callbacks=[monitor],verbose=0,epochs=1000)
# Out:
# Number of classes: 3
# Restoring model weights from the end of the best epoch: 81.
# Epoch 86: early stopping

# %% [markdown]
# Now that we've trained the neural network, we can check its log loss.

# %%
from sklearn import metrics

# Calculate multi log loss error
pred = model.predict(x_test)
score = metrics.log_loss(y_test, pred)
print("Log loss score: {}".format(score))
# Out:
# 1/1 [==============================] - 0s 84ms/step
# Log loss score: 0.07583763118833303

# %% [markdown]
# Now we are ready to generate the Kaggle submission file.  We will use the iris test data that does not contain a $y$ target value.  It is our job to predict this value and submit it to Kaggle.

# %%
# Generate Kaggle submit file

# Encode feature vector
df_test = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/datasets/"+\
    "kaggle_iris_test.csv", na_values=['NA','?'])

# Convert to numpy - Classification
ids = df_test['id']
df_test.drop('id', axis=1, inplace=True)
x = df_test[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
y = dummies.values

# Generate predictions
pred = model.predict(x)
#pred

# Create submission data set

df_submit = pd.DataFrame(pred)
df_submit.insert(0,'id',ids)
df_submit.columns = ['id','species-0','species-1','species-2']

# Write submit file locally
df_submit.to_csv("iris_submit.csv", index=False) 

print(df_submit[:5])
# Out:
# 2/2 [==============================] - 0s 7ms/step
#     id  species-0  species-1     species-2
# 0  100   0.008102   0.872571  1.193271e-01
# 1  101   0.000393   0.255185  7.444218e-01
# 2  102   0.000551   0.249530  7.499195e-01
# 3  103   0.976381   0.023617  1.979495e-06
# 4  104   0.986559   0.013441  7.222499e-07

# %% [markdown]
# ## MPG as a Kaggle Competition (Regression)
#
# If the Auto MPG data were used as a Kaggle, you would be given the following three files:
#
# * [kaggle_mpg_test.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_auto_test.csv) - The data that Kaggle will evaluate you on.  Contains only input, you must provide answers.  (contains x)
# * [kaggle_mpg_train.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_auto_test.csv) - The data that you will use to train. (contains x and y)
# * [kaggle_mpg_sample.csv](https://data.heatonresearch.com/data/t81-558/datasets/kaggle_auto_sample.csv) - A sample submission for Kaggle. (contains x and y)
#
# Important features of the Kaggle iris files (that differ from how we've previously seen files):
#
# The following program generates a submission file for "MPG Kaggle".

# %%
# HIDE OUTPUT
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

save_path = "."

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/datasets/"+\
    "kaggle_auto_train.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
                        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
          verbose=2,callbacks=[monitor],epochs=1000)

# Predict
pred = model.predict(x_test)
# Out:
# Epoch 1/1000
# 9/9 - 1s - loss: 1102701.5000 - val_loss: 882436.0625 - 577ms/epoch - 64ms/step
# Epoch 2/1000
# 9/9 - 0s - loss: 822937.8125 - val_loss: 655835.8750 - 58ms/epoch - 6ms/step
# Epoch 3/1000
# 9/9 - 0s - loss: 607509.5625 - val_loss: 477158.6250 - 41ms/epoch - 5ms/step
# Epoch 4/1000
# 9/9 - 0s - loss: 439842.0625 - val_loss: 340266.9062 - 43ms/epoch - 5ms/step
# Epoch 5/1000
# 9/9 - 0s - loss: 310968.6562 - val_loss: 235498.9844 - 63ms/epoch - 7ms/step
# Epoch 6/1000
# 9/9 - 0s - loss: 209825.7656 - val_loss: 156637.0000 - 80ms/epoch - 9ms/step
# Epoch 7/1000
# 9/9 - 0s - loss: 136794.9688 - val_loss: 95928.5938 - 47ms/epoch - 5ms/step
# Epoch 8/1000
# 9/9 - 0s - loss: 81311.2812 - val_loss: 53540.3164 - 60ms/epoch - 7ms/step
# Epoch 9/1000
# 9/9 - 0s - loss: 43613.9102 - val_loss: 26690.3066 - 40ms/epoch - 4ms/step
# Epoch 10/1000
# 9/9 - 0s - loss: 20812.6660 - val_loss: 11496.0283 - 45ms/epoch - 5ms/step
# Epoch 11/1000
# 9/9 - 0s - loss: 8119.2480 - val_loss: 3894.8877 - 46ms/epoch - 5ms/step
# Epoch 12/1000
# 9/9 - 0s - loss: 2548.3987 - val_loss: 958.5414 - 47ms/epoch - 5ms/step
# Epoch 13/1000
# 9/9 - 0s - loss: 572.3571 - val_loss: 208.3362 - 48ms/epoch - 5ms/step
# Epoch 14/1000
# 9/9 - 0s - loss: 160.4433 - val_loss: 139.2382 - 50ms/epoch - 6ms/step
# Epoch 15/1000
# 9/9 - 0s - loss: 153.6234 - val_loss: 163.7253 - 59ms/epoch - 7ms/step
# Epoch 16/1000
# 9/9 - 0s - loss: 172.6854 - val_loss: 164.0977 - 45ms/epoch - 5ms/step
# Epoch 17/1000
# 9/9 - 0s - loss: 163.9009 - val_loss: 148.9773 - 48ms/epoch - 5ms/step
# Epoch 18/1000
# 9/9 - 0s - loss: 149.2769 - val_loss: 138.6520 - 42ms/epoch - 5ms/step
# Epoch 19/1000
# 9/9 - 0s - loss: 141.3311 - val_loss: 134.8309 - 43ms/epoch - 5ms/step
# Epoch 20/1000
# 9/9 - 0s - loss: 138.5709 - val_loss: 134.3047 - 46ms/epoch - 5ms/step
# Epoch 21/1000
# 9/9 - 0s - loss: 138.2638 - val_loss: 134.1017 - 45ms/epoch - 5ms/step
# Epoch 22/1000
# 9/9 - 0s - loss: 138.0031 - val_loss: 133.9205 - 47ms/epoch - 5ms/step
# Epoch 23/1000
# 9/9 - 0s - loss: 138.1062 - val_loss: 133.9079 - 47ms/epoch - 5ms/step
# Epoch 24/1000
# 9/9 - 0s - loss: 137.8140 - val_loss: 133.5167 - 42ms/epoch - 5ms/step
# Epoch 25/1000
# 9/9 - 0s - loss: 137.1047 - val_loss: 132.8330 - 42ms/epoch - 5ms/step
# Epoch 26/1000
# 9/9 - 0s - loss: 136.9757 - val_loss: 132.4561 - 48ms/epoch - 5ms/step
# Epoch 27/1000
# 9/9 - 0s - loss: 136.4413 - val_loss: 132.0944 - 46ms/epoch - 5ms/step
# Epoch 28/1000
# 9/9 - 0s - loss: 136.0820 - val_loss: 131.7956 - 43ms/epoch - 5ms/step
# Epoch 29/1000
# 9/9 - 0s - loss: 135.7232 - val_loss: 131.4292 - 58ms/epoch - 6ms/step
# Epoch 30/1000
# 9/9 - 0s - loss: 135.3962 - val_loss: 131.0637 - 42ms/epoch - 5ms/step
# Epoch 31/1000
# 9/9 - 0s - loss: 135.0421 - val_loss: 130.7060 - 59ms/epoch - 7ms/step
# Epoch 32/1000
# 9/9 - 0s - loss: 134.7013 - val_loss: 130.3452 - 54ms/epoch - 6ms/step
# Epoch 33/1000
# 9/9 - 0s - loss: 134.3665 - val_loss: 129.9975 - 64ms/epoch - 7ms/step
# Epoch 34/1000
# 9/9 - 0s - loss: 134.4394 - val_loss: 129.7076 - 43ms/epoch - 5ms/step
# Epoch 35/1000
# 9/9 - 0s - loss: 133.7505 - val_loss: 129.2836 - 48ms/epoch - 5ms/step
# Epoch 36/1000
# 9/9 - 0s - loss: 133.4149 - val_loss: 128.9062 - 46ms/epoch - 5ms/step
# Epoch 37/1000
# 9/9 - 0s - loss: 133.0482 - val_loss: 128.6319 - 61ms/epoch - 7ms/step
# Epoch 38/1000
# 9/9 - 0s - loss: 132.6782 - val_loss: 128.1475 - 45ms/epoch - 5ms/step
# Epoch 39/1000
# 9/9 - 0s - loss: 132.2415 - val_loss: 127.7352 - 45ms/epoch - 5ms/step
# Epoch 40/1000
# 9/9 - 0s - loss: 131.9042 - val_loss: 127.3679 - 44ms/epoch - 5ms/step
# Epoch 41/1000
# 9/9 - 0s - loss: 131.4485 - val_loss: 126.9706 - 44ms/epoch - 5ms/step
# Epoch 42/1000
# 9/9 - 0s - loss: 131.1394 - val_loss: 126.5811 - 46ms/epoch - 5ms/step
# Epoch 43/1000
# 9/9 - 0s - loss: 130.6297 - val_loss: 126.1711 - 66ms/epoch - 7ms/step
# Epoch 44/1000
# 9/9 - 0s - loss: 130.3061 - val_loss: 125.7561 - 68ms/epoch - 8ms/step
# Epoch 45/1000
# 9/9 - 0s - loss: 129.8668 - val_loss: 125.3614 - 51ms/epoch - 6ms/step
# Epoch 46/1000
# 9/9 - 0s - loss: 129.4667 - val_loss: 124.9181 - 48ms/epoch - 5ms/step
# Epoch 47/1000
# 9/9 - 0s - loss: 128.9640 - val_loss: 124.4876 - 45ms/epoch - 5ms/step
# Epoch 48/1000
# 9/9 - 0s - loss: 128.5283 - val_loss: 124.0878 - 47ms/epoch - 5ms/step
# Epoch 49/1000
# 9/9 - 0s - loss: 128.2083 - val_loss: 123.6628 - 76ms/epoch - 8ms/step
# Epoch 50/1000
# 9/9 - 0s - loss: 127.7888 - val_loss: 123.2155 - 50ms/epoch - 6ms/step
# Epoch 51/1000
# 9/9 - 0s - loss: 127.3393 - val_loss: 122.8189 - 44ms/epoch - 5ms/step
# Epoch 52/1000
# 9/9 - 0s - loss: 126.9621 - val_loss: 122.4441 - 41ms/epoch - 5ms/step
# Epoch 53/1000
# 9/9 - 0s - loss: 126.8759 - val_loss: 122.1474 - 58ms/epoch - 6ms/step
# Epoch 54/1000
# 9/9 - 0s - loss: 126.1086 - val_loss: 121.3973 - 44ms/epoch - 5ms/step
# Epoch 55/1000
# 9/9 - 0s - loss: 125.8546 - val_loss: 121.2592 - 46ms/epoch - 5ms/step
# Epoch 56/1000
# 9/9 - 0s - loss: 125.3738 - val_loss: 120.9254 - 45ms/epoch - 5ms/step
# Epoch 57/1000
# 9/9 - 0s - loss: 124.8102 - val_loss: 120.1032 - 60ms/epoch - 7ms/step
# Epoch 58/1000
# 9/9 - 0s - loss: 124.1464 - val_loss: 119.5232 - 42ms/epoch - 5ms/step
# Epoch 59/1000
# 9/9 - 0s - loss: 123.6629 - val_loss: 119.0500 - 81ms/epoch - 9ms/step
# Epoch 60/1000
# 9/9 - 0s - loss: 123.1144 - val_loss: 118.5411 - 126ms/epoch - 14ms/step
# Epoch 61/1000
# 9/9 - 0s - loss: 122.6434 - val_loss: 118.0123 - 93ms/epoch - 10ms/step
# Epoch 62/1000
# 9/9 - 0s - loss: 122.6284 - val_loss: 117.7366 - 94ms/epoch - 10ms/step
# Epoch 63/1000
# 9/9 - 0s - loss: 121.9017 - val_loss: 117.1618 - 90ms/epoch - 10ms/step
# Epoch 64/1000
# 9/9 - 0s - loss: 121.4809 - val_loss: 116.6358 - 100ms/epoch - 11ms/step
# Epoch 65/1000
# 9/9 - 0s - loss: 120.8814 - val_loss: 116.1287 - 60ms/epoch - 7ms/step
# Epoch 66/1000
# 9/9 - 0s - loss: 120.6336 - val_loss: 115.6498 - 103ms/epoch - 11ms/step
# Epoch 67/1000
# 9/9 - 0s - loss: 119.7605 - val_loss: 115.1759 - 80ms/epoch - 9ms/step
# Epoch 68/1000
# 9/9 - 0s - loss: 119.3306 - val_loss: 114.6699 - 82ms/epoch - 9ms/step
# Epoch 69/1000
# 9/9 - 0s - loss: 118.7615 - val_loss: 114.0731 - 79ms/epoch - 9ms/step
# Epoch 70/1000
# 9/9 - 0s - loss: 118.2537 - val_loss: 113.6528 - 84ms/epoch - 9ms/step
# Epoch 71/1000
# 9/9 - 0s - loss: 118.5385 - val_loss: 113.5417 - 72ms/epoch - 8ms/step
# Epoch 72/1000
# 9/9 - 0s - loss: 117.3911 - val_loss: 112.5237 - 102ms/epoch - 11ms/step
# Epoch 73/1000
# 9/9 - 0s - loss: 116.7372 - val_loss: 112.2810 - 90ms/epoch - 10ms/step
# Epoch 74/1000
# 9/9 - 0s - loss: 116.3517 - val_loss: 111.6005 - 86ms/epoch - 10ms/step
# Epoch 75/1000
# 9/9 - 0s - loss: 115.7200 - val_loss: 111.0799 - 68ms/epoch - 8ms/step
# Epoch 76/1000
# 9/9 - 0s - loss: 115.9310 - val_loss: 110.9883 - 111ms/epoch - 12ms/step
# Epoch 77/1000
# 9/9 - 0s - loss: 115.2702 - val_loss: 110.1329 - 82ms/epoch - 9ms/step
# Epoch 78/1000
# 9/9 - 0s - loss: 114.5789 - val_loss: 109.6518 - 92ms/epoch - 10ms/step
# Epoch 79/1000
# 9/9 - 0s - loss: 113.9513 - val_loss: 109.0211 - 92ms/epoch - 10ms/step
# Epoch 80/1000
# 9/9 - 0s - loss: 113.4221 - val_loss: 108.4759 - 89ms/epoch - 10ms/step
# Epoch 81/1000
# 9/9 - 0s - loss: 112.6811 - val_loss: 107.9714 - 81ms/epoch - 9ms/step
# Epoch 82/1000
# 9/9 - 0s - loss: 112.2808 - val_loss: 107.6390 - 102ms/epoch - 11ms/step
# Epoch 83/1000
# 9/9 - 0s - loss: 111.6984 - val_loss: 106.8595 - 108ms/epoch - 12ms/step
# Epoch 84/1000
# 9/9 - 0s - loss: 111.2734 - val_loss: 106.3981 - 87ms/epoch - 10ms/step
# Epoch 85/1000
# 9/9 - 0s - loss: 110.6872 - val_loss: 105.7863 - 88ms/epoch - 10ms/step
# Epoch 86/1000
# 9/9 - 0s - loss: 110.1199 - val_loss: 105.2478 - 87ms/epoch - 10ms/step
# Epoch 87/1000
# 9/9 - 0s - loss: 109.2939 - val_loss: 104.8601 - 90ms/epoch - 10ms/step
# Epoch 88/1000
# 9/9 - 0s - loss: 109.1792 - val_loss: 104.7164 - 134ms/epoch - 15ms/step
# Epoch 89/1000
# 9/9 - 0s - loss: 109.0907 - val_loss: 104.1778 - 97ms/epoch - 11ms/step
# Epoch 90/1000
# 9/9 - 0s - loss: 108.2203 - val_loss: 103.2702 - 73ms/epoch - 8ms/step
# Epoch 91/1000
# 9/9 - 0s - loss: 107.5105 - val_loss: 102.6508 - 112ms/epoch - 12ms/step
# Epoch 92/1000
# 9/9 - 0s - loss: 107.0669 - val_loss: 102.1755 - 70ms/epoch - 8ms/step
# Epoch 93/1000
# 9/9 - 0s - loss: 106.3996 - val_loss: 101.6022 - 85ms/epoch - 9ms/step
# Epoch 94/1000
# 9/9 - 0s - loss: 106.2099 - val_loss: 101.5500 - 81ms/epoch - 9ms/step
# Epoch 95/1000
# 9/9 - 0s - loss: 105.9442 - val_loss: 101.0889 - 71ms/epoch - 8ms/step
# Epoch 96/1000
# 9/9 - 0s - loss: 105.2771 - val_loss: 100.0401 - 86ms/epoch - 10ms/step
# Epoch 97/1000
# 9/9 - 0s - loss: 104.7482 - val_loss: 99.6931 - 109ms/epoch - 12ms/step
# Epoch 98/1000
# 9/9 - 0s - loss: 104.0233 - val_loss: 98.9837 - 82ms/epoch - 9ms/step
# Epoch 99/1000
# 9/9 - 0s - loss: 103.2905 - val_loss: 98.4541 - 143ms/epoch - 16ms/step
# Epoch 100/1000
# 9/9 - 0s - loss: 103.5817 - val_loss: 98.4567 - 84ms/epoch - 9ms/step
# Epoch 101/1000
# 9/9 - 0s - loss: 102.5452 - val_loss: 97.3845 - 92ms/epoch - 10ms/step
# Epoch 102/1000
# 9/9 - 0s - loss: 101.8071 - val_loss: 96.8624 - 160ms/epoch - 18ms/step
# Epoch 103/1000
# 9/9 - 0s - loss: 101.2355 - val_loss: 96.4270 - 101ms/epoch - 11ms/step
# Epoch 104/1000
# 9/9 - 0s - loss: 100.8989 - val_loss: 95.8341 - 92ms/epoch - 10ms/step
# Epoch 105/1000
# 9/9 - 0s - loss: 100.3842 - val_loss: 95.3817 - 84ms/epoch - 9ms/step
# Epoch 106/1000
# 9/9 - 0s - loss: 99.9369 - val_loss: 94.7445 - 152ms/epoch - 17ms/step
# Epoch 107/1000
# 9/9 - 0s - loss: 99.2787 - val_loss: 95.2862 - 78ms/epoch - 9ms/step
# Epoch 108/1000
# 9/9 - 0s - loss: 99.3638 - val_loss: 94.1018 - 159ms/epoch - 18ms/step
# Epoch 109/1000
# 9/9 - 0s - loss: 98.0710 - val_loss: 93.1048 - 90ms/epoch - 10ms/step
# Epoch 110/1000
# 9/9 - 0s - loss: 97.4594 - val_loss: 92.6856 - 92ms/epoch - 10ms/step
# Epoch 111/1000
# 9/9 - 0s - loss: 97.5123 - val_loss: 92.9024 - 107ms/epoch - 12ms/step
# Epoch 112/1000
# 9/9 - 0s - loss: 97.4891 - val_loss: 91.6733 - 56ms/epoch - 6ms/step
# Epoch 113/1000
# 9/9 - 0s - loss: 95.9658 - val_loss: 91.0249 - 73ms/epoch - 8ms/step
# Epoch 114/1000
# 9/9 - 0s - loss: 95.4842 - val_loss: 90.5412 - 121ms/epoch - 13ms/step
# Epoch 115/1000
# 9/9 - 0s - loss: 94.9255 - val_loss: 89.8620 - 83ms/epoch - 9ms/step
# Epoch 116/1000
# 9/9 - 0s - loss: 94.2861 - val_loss: 89.3760 - 81ms/epoch - 9ms/step
# Epoch 117/1000
# 9/9 - 0s - loss: 94.1593 - val_loss: 88.9315 - 78ms/epoch - 9ms/step
# Epoch 118/1000
# 9/9 - 0s - loss: 93.5824 - val_loss: 88.2673 - 66ms/epoch - 7ms/step
# Epoch 119/1000
# 9/9 - 0s - loss: 92.7390 - val_loss: 87.7115 - 90ms/epoch - 10ms/step
# Epoch 120/1000
# 9/9 - 0s - loss: 92.3789 - val_loss: 87.1610 - 77ms/epoch - 9ms/step
# Epoch 121/1000
# 9/9 - 0s - loss: 91.7095 - val_loss: 86.6636 - 114ms/epoch - 13ms/step
# Epoch 122/1000
# 9/9 - 0s - loss: 91.2185 - val_loss: 86.1419 - 91ms/epoch - 10ms/step
# Epoch 123/1000
# 9/9 - 0s - loss: 90.6116 - val_loss: 85.5509 - 116ms/epoch - 13ms/step
# Epoch 124/1000
# 9/9 - 0s - loss: 90.4098 - val_loss: 85.1195 - 72ms/epoch - 8ms/step
# Epoch 125/1000
# 9/9 - 0s - loss: 89.6716 - val_loss: 84.4873 - 69ms/epoch - 8ms/step
# Epoch 126/1000
# 9/9 - 0s - loss: 89.0462 - val_loss: 83.9441 - 75ms/epoch - 8ms/step
# Epoch 127/1000
# 9/9 - 0s - loss: 88.3959 - val_loss: 83.4256 - 109ms/epoch - 12ms/step
# Epoch 128/1000
# 9/9 - 0s - loss: 88.0509 - val_loss: 83.0938 - 81ms/epoch - 9ms/step
# Epoch 129/1000
# 9/9 - 0s - loss: 87.6348 - val_loss: 82.3158 - 76ms/epoch - 8ms/step
# Epoch 130/1000
# 9/9 - 0s - loss: 86.8239 - val_loss: 81.7660 - 94ms/epoch - 10ms/step
# Epoch 131/1000
# 9/9 - 0s - loss: 86.2838 - val_loss: 81.2938 - 76ms/epoch - 8ms/step
# Epoch 132/1000
# 9/9 - 0s - loss: 85.7868 - val_loss: 80.9266 - 83ms/epoch - 9ms/step
# Epoch 133/1000
# 9/9 - 0s - loss: 85.5368 - val_loss: 80.6239 - 127ms/epoch - 14ms/step
# Epoch 134/1000
# 9/9 - 0s - loss: 84.9358 - val_loss: 79.6835 - 97ms/epoch - 11ms/step
# Epoch 135/1000
# 9/9 - 0s - loss: 84.4141 - val_loss: 79.2058 - 82ms/epoch - 9ms/step
# Epoch 136/1000
# 9/9 - 0s - loss: 83.7576 - val_loss: 78.6301 - 79ms/epoch - 9ms/step
# Epoch 137/1000
# 9/9 - 0s - loss: 83.1773 - val_loss: 78.2290 - 98ms/epoch - 11ms/step
# Epoch 138/1000
# 9/9 - 0s - loss: 82.8278 - val_loss: 77.6288 - 103ms/epoch - 11ms/step
# Epoch 139/1000
# 9/9 - 0s - loss: 82.2237 - val_loss: 77.1501 - 76ms/epoch - 8ms/step
# Epoch 140/1000
# 9/9 - 0s - loss: 81.4562 - val_loss: 76.6130 - 74ms/epoch - 8ms/step
# Epoch 141/1000
# 9/9 - 0s - loss: 81.2377 - val_loss: 76.1261 - 75ms/epoch - 8ms/step
# Epoch 142/1000
# 9/9 - 0s - loss: 80.6677 - val_loss: 75.4899 - 185ms/epoch - 21ms/step
# Epoch 143/1000
# 9/9 - 0s - loss: 80.0467 - val_loss: 75.3913 - 100ms/epoch - 11ms/step
# Epoch 144/1000
# 9/9 - 0s - loss: 79.8693 - val_loss: 74.4933 - 134ms/epoch - 15ms/step
# Epoch 145/1000
# 9/9 - 0s - loss: 79.1351 - val_loss: 73.9558 - 109ms/epoch - 12ms/step
# Epoch 146/1000
# 9/9 - 0s - loss: 78.6529 - val_loss: 73.5561 - 78ms/epoch - 9ms/step
# Epoch 147/1000
# 9/9 - 0s - loss: 78.1574 - val_loss: 72.9360 - 130ms/epoch - 14ms/step
# Epoch 148/1000
# 9/9 - 0s - loss: 77.4940 - val_loss: 72.4617 - 123ms/epoch - 14ms/step
# Epoch 149/1000
# 9/9 - 0s - loss: 77.1119 - val_loss: 71.9153 - 83ms/epoch - 9ms/step
# Epoch 150/1000
# 9/9 - 0s - loss: 76.4885 - val_loss: 71.5193 - 84ms/epoch - 9ms/step
# Epoch 151/1000
# 9/9 - 0s - loss: 76.0863 - val_loss: 70.8783 - 136ms/epoch - 15ms/step
# Epoch 152/1000
# 9/9 - 0s - loss: 75.3282 - val_loss: 70.5510 - 89ms/epoch - 10ms/step
# Epoch 153/1000
# 9/9 - 0s - loss: 75.0826 - val_loss: 69.9412 - 87ms/epoch - 10ms/step
# Epoch 154/1000
# 9/9 - 0s - loss: 74.6376 - val_loss: 69.5413 - 152ms/epoch - 17ms/step
# Epoch 155/1000
# 9/9 - 0s - loss: 73.9697 - val_loss: 68.9139 - 84ms/epoch - 9ms/step
# Epoch 156/1000
# 9/9 - 0s - loss: 73.7192 - val_loss: 68.4550 - 113ms/epoch - 13ms/step
# Epoch 157/1000
# 9/9 - 0s - loss: 73.5328 - val_loss: 68.5065 - 75ms/epoch - 8ms/step
# Epoch 158/1000
# 9/9 - 0s - loss: 72.7449 - val_loss: 67.4169 - 73ms/epoch - 8ms/step
# Epoch 159/1000
# 9/9 - 0s - loss: 72.1231 - val_loss: 67.0263 - 84ms/epoch - 9ms/step
# Epoch 160/1000
# 9/9 - 0s - loss: 71.6170 - val_loss: 66.4532 - 78ms/epoch - 9ms/step
# Epoch 161/1000
# 9/9 - 0s - loss: 71.1321 - val_loss: 66.0956 - 81ms/epoch - 9ms/step
# Epoch 162/1000
# 9/9 - 0s - loss: 71.0337 - val_loss: 65.6286 - 130ms/epoch - 14ms/step
# Epoch 163/1000
# 9/9 - 0s - loss: 70.1337 - val_loss: 64.9507 - 93ms/epoch - 10ms/step
# Epoch 164/1000
# 9/9 - 0s - loss: 69.5267 - val_loss: 64.4813 - 101ms/epoch - 11ms/step
# Epoch 165/1000
# 9/9 - 0s - loss: 69.1077 - val_loss: 64.0471 - 90ms/epoch - 10ms/step
# Epoch 166/1000
# 9/9 - 0s - loss: 68.6193 - val_loss: 63.5081 - 82ms/epoch - 9ms/step
# Epoch 167/1000
# 9/9 - 0s - loss: 68.4183 - val_loss: 63.1593 - 107ms/epoch - 12ms/step
# Epoch 168/1000
# 9/9 - 0s - loss: 67.7500 - val_loss: 62.5499 - 141ms/epoch - 16ms/step
# Epoch 169/1000
# 9/9 - 0s - loss: 67.0984 - val_loss: 62.1385 - 97ms/epoch - 11ms/step
# Epoch 170/1000
# 9/9 - 0s - loss: 66.7692 - val_loss: 61.5927 - 123ms/epoch - 14ms/step
# Epoch 171/1000
# 9/9 - 0s - loss: 66.4242 - val_loss: 61.1427 - 87ms/epoch - 10ms/step
# Epoch 172/1000
# 9/9 - 0s - loss: 65.9417 - val_loss: 60.8929 - 94ms/epoch - 10ms/step
# Epoch 173/1000
# 9/9 - 0s - loss: 65.5151 - val_loss: 60.1964 - 81ms/epoch - 9ms/step
# Epoch 174/1000
# 9/9 - 0s - loss: 66.4387 - val_loss: 60.4954 - 91ms/epoch - 10ms/step
# Epoch 175/1000
# 9/9 - 0s - loss: 64.7739 - val_loss: 59.4598 - 99ms/epoch - 11ms/step
# Epoch 176/1000
# 9/9 - 0s - loss: 63.9880 - val_loss: 58.8713 - 83ms/epoch - 9ms/step
# Epoch 177/1000
# 9/9 - 0s - loss: 63.5436 - val_loss: 58.4501 - 96ms/epoch - 11ms/step
# Epoch 178/1000
# 9/9 - 0s - loss: 63.2019 - val_loss: 58.1599 - 76ms/epoch - 8ms/step
# Epoch 179/1000
# 9/9 - 0s - loss: 62.8024 - val_loss: 57.6925 - 119ms/epoch - 13ms/step
# Epoch 180/1000
# 9/9 - 0s - loss: 62.4298 - val_loss: 57.2215 - 63ms/epoch - 7ms/step
# Epoch 181/1000
# 9/9 - 0s - loss: 61.9092 - val_loss: 56.6779 - 90ms/epoch - 10ms/step
# Epoch 182/1000
# 9/9 - 0s - loss: 61.1734 - val_loss: 56.2000 - 89ms/epoch - 10ms/step
# Epoch 183/1000
# 9/9 - 0s - loss: 60.8626 - val_loss: 55.8169 - 150ms/epoch - 17ms/step
# Epoch 184/1000
# 9/9 - 0s - loss: 60.3062 - val_loss: 55.2448 - 62ms/epoch - 7ms/step
# Epoch 185/1000
# 9/9 - 0s - loss: 59.9553 - val_loss: 54.8826 - 149ms/epoch - 17ms/step
# Epoch 186/1000
# 9/9 - 0s - loss: 59.3348 - val_loss: 54.3982 - 133ms/epoch - 15ms/step
# Epoch 187/1000
# 9/9 - 0s - loss: 59.0358 - val_loss: 54.2597 - 128ms/epoch - 14ms/step
# Epoch 188/1000
# 9/9 - 0s - loss: 58.9457 - val_loss: 53.5348 - 98ms/epoch - 11ms/step
# Epoch 189/1000
# 9/9 - 0s - loss: 58.5837 - val_loss: 53.1225 - 82ms/epoch - 9ms/step
# Epoch 190/1000
# 9/9 - 0s - loss: 57.8036 - val_loss: 53.0142 - 77ms/epoch - 9ms/step
# Epoch 191/1000
# 9/9 - 0s - loss: 57.3808 - val_loss: 52.2947 - 124ms/epoch - 14ms/step
# Epoch 192/1000
# 9/9 - 0s - loss: 56.9356 - val_loss: 51.8953 - 107ms/epoch - 12ms/step
# Epoch 193/1000
# 9/9 - 0s - loss: 56.4838 - val_loss: 51.4008 - 58ms/epoch - 6ms/step
# Epoch 194/1000
# 9/9 - 0s - loss: 56.0110 - val_loss: 51.0024 - 44ms/epoch - 5ms/step
# Epoch 195/1000
# 9/9 - 0s - loss: 55.4577 - val_loss: 50.5282 - 47ms/epoch - 5ms/step
# Epoch 196/1000
# 9/9 - 0s - loss: 55.0835 - val_loss: 50.1170 - 41ms/epoch - 5ms/step
# Epoch 197/1000
# 9/9 - 0s - loss: 54.6980 - val_loss: 49.7374 - 46ms/epoch - 5ms/step
# Epoch 198/1000
# 9/9 - 0s - loss: 54.2981 - val_loss: 49.3692 - 46ms/epoch - 5ms/step
# Epoch 199/1000
# 9/9 - 0s - loss: 53.9105 - val_loss: 48.9068 - 47ms/epoch - 5ms/step
# Epoch 200/1000
# 9/9 - 0s - loss: 53.5132 - val_loss: 48.5246 - 49ms/epoch - 5ms/step
# Epoch 201/1000
# 9/9 - 0s - loss: 53.3209 - val_loss: 48.2479 - 60ms/epoch - 7ms/step
# Epoch 202/1000
# 9/9 - 0s - loss: 53.3899 - val_loss: 47.8704 - 61ms/epoch - 7ms/step
# Epoch 203/1000
# 9/9 - 0s - loss: 52.3339 - val_loss: 47.4999 - 60ms/epoch - 7ms/step
# Epoch 204/1000
# 9/9 - 0s - loss: 52.1482 - val_loss: 47.0752 - 67ms/epoch - 7ms/step
# Epoch 205/1000
# 9/9 - 0s - loss: 51.6279 - val_loss: 46.5550 - 50ms/epoch - 6ms/step
# Epoch 206/1000
# 9/9 - 0s - loss: 51.0423 - val_loss: 46.1572 - 44ms/epoch - 5ms/step
# Epoch 207/1000
# 9/9 - 0s - loss: 50.6790 - val_loss: 45.7602 - 47ms/epoch - 5ms/step
# Epoch 208/1000
# 9/9 - 0s - loss: 50.2695 - val_loss: 45.3869 - 50ms/epoch - 6ms/step
# Epoch 209/1000
# 9/9 - 0s - loss: 49.9755 - val_loss: 44.9979 - 44ms/epoch - 5ms/step
# Epoch 210/1000
# 9/9 - 0s - loss: 49.5272 - val_loss: 44.6052 - 60ms/epoch - 7ms/step
# Epoch 211/1000
# 9/9 - 0s - loss: 49.0725 - val_loss: 44.2756 - 52ms/epoch - 6ms/step
# Epoch 212/1000
# 9/9 - 0s - loss: 48.8070 - val_loss: 43.8437 - 62ms/epoch - 7ms/step
# Epoch 213/1000
# 9/9 - 0s - loss: 48.6402 - val_loss: 43.8276 - 44ms/epoch - 5ms/step
# Epoch 214/1000
# 9/9 - 0s - loss: 48.0255 - val_loss: 43.1847 - 43ms/epoch - 5ms/step
# Epoch 215/1000
# 9/9 - 0s - loss: 47.6994 - val_loss: 42.7351 - 50ms/epoch - 6ms/step
# Epoch 216/1000
# 9/9 - 0s - loss: 47.2017 - val_loss: 42.3156 - 47ms/epoch - 5ms/step
# Epoch 217/1000
# 9/9 - 0s - loss: 46.7738 - val_loss: 42.2915 - 52ms/epoch - 6ms/step
# Epoch 218/1000
# 9/9 - 0s - loss: 46.8181 - val_loss: 41.7517 - 45ms/epoch - 5ms/step
# Epoch 219/1000
# 9/9 - 0s - loss: 46.1189 - val_loss: 41.2141 - 53ms/epoch - 6ms/step
# Epoch 220/1000
# 9/9 - 0s - loss: 45.7567 - val_loss: 40.8454 - 62ms/epoch - 7ms/step
# Epoch 221/1000
# 9/9 - 0s - loss: 45.5671 - val_loss: 40.6631 - 62ms/epoch - 7ms/step
# Epoch 222/1000
# 9/9 - 0s - loss: 45.0254 - val_loss: 40.1406 - 59ms/epoch - 7ms/step
# Epoch 223/1000
# 9/9 - 0s - loss: 44.5304 - val_loss: 39.7995 - 49ms/epoch - 5ms/step
# Epoch 224/1000
# 9/9 - 0s - loss: 44.1920 - val_loss: 39.4110 - 45ms/epoch - 5ms/step
# Epoch 225/1000
# 9/9 - 0s - loss: 43.9147 - val_loss: 39.0657 - 60ms/epoch - 7ms/step
# Epoch 226/1000
# 9/9 - 0s - loss: 43.5247 - val_loss: 38.7420 - 45ms/epoch - 5ms/step
# Epoch 227/1000
# 9/9 - 0s - loss: 43.1677 - val_loss: 38.4911 - 45ms/epoch - 5ms/step
# Epoch 228/1000
# 9/9 - 0s - loss: 43.0598 - val_loss: 38.1282 - 44ms/epoch - 5ms/step
# Epoch 229/1000
# 9/9 - 0s - loss: 42.5020 - val_loss: 37.8170 - 61ms/epoch - 7ms/step
# Epoch 230/1000
# 9/9 - 0s - loss: 42.1970 - val_loss: 37.4624 - 65ms/epoch - 7ms/step
# Epoch 231/1000
# 9/9 - 0s - loss: 41.7255 - val_loss: 37.1879 - 44ms/epoch - 5ms/step
# Epoch 232/1000
# 9/9 - 0s - loss: 41.8462 - val_loss: 36.9161 - 68ms/epoch - 8ms/step
# Epoch 233/1000
# 9/9 - 0s - loss: 41.2620 - val_loss: 36.5150 - 50ms/epoch - 6ms/step
# Epoch 234/1000
# 9/9 - 0s - loss: 40.7157 - val_loss: 36.2883 - 48ms/epoch - 5ms/step
# Epoch 235/1000
# 9/9 - 0s - loss: 40.9880 - val_loss: 36.1170 - 71ms/epoch - 8ms/step
# Epoch 236/1000
# 9/9 - 0s - loss: 40.0903 - val_loss: 35.7702 - 61ms/epoch - 7ms/step
# Epoch 237/1000
# 9/9 - 0s - loss: 40.0501 - val_loss: 35.2813 - 59ms/epoch - 7ms/step
# Epoch 238/1000
# 9/9 - 0s - loss: 39.6939 - val_loss: 34.9906 - 42ms/epoch - 5ms/step
# Epoch 239/1000
# 9/9 - 0s - loss: 39.1864 - val_loss: 34.7548 - 43ms/epoch - 5ms/step
# Epoch 240/1000
# 9/9 - 0s - loss: 39.0727 - val_loss: 34.3768 - 44ms/epoch - 5ms/step
# Epoch 241/1000
# 9/9 - 0s - loss: 38.9706 - val_loss: 34.5087 - 72ms/epoch - 8ms/step
# Epoch 242/1000
# 9/9 - 0s - loss: 38.6544 - val_loss: 33.8105 - 63ms/epoch - 7ms/step
# Epoch 243/1000
# 9/9 - 0s - loss: 38.0532 - val_loss: 33.5306 - 58ms/epoch - 6ms/step
# Epoch 244/1000
# 9/9 - 0s - loss: 37.9130 - val_loss: 33.2279 - 41ms/epoch - 5ms/step
# Epoch 245/1000
# 9/9 - 0s - loss: 37.6027 - val_loss: 33.0608 - 61ms/epoch - 7ms/step
# Epoch 246/1000
# 9/9 - 0s - loss: 37.4164 - val_loss: 32.7214 - 45ms/epoch - 5ms/step
# Epoch 247/1000
# 9/9 - 0s - loss: 36.9935 - val_loss: 32.6608 - 47ms/epoch - 5ms/step
# Epoch 248/1000
# 9/9 - 0s - loss: 37.1308 - val_loss: 32.2223 - 46ms/epoch - 5ms/step
# Epoch 249/1000
# 9/9 - 0s - loss: 36.7181 - val_loss: 32.2576 - 42ms/epoch - 5ms/step
# Epoch 250/1000
# 9/9 - 0s - loss: 36.2403 - val_loss: 31.6217 - 55ms/epoch - 6ms/step
# Epoch 251/1000
# 9/9 - 0s - loss: 35.8204 - val_loss: 31.3156 - 61ms/epoch - 7ms/step
# Epoch 252/1000
# 9/9 - 0s - loss: 35.6161 - val_loss: 31.0281 - 45ms/epoch - 5ms/step
# Epoch 253/1000
# 9/9 - 0s - loss: 35.2832 - val_loss: 31.0535 - 51ms/epoch - 6ms/step
# Epoch 254/1000
# 9/9 - 0s - loss: 35.1472 - val_loss: 30.5173 - 41ms/epoch - 5ms/step
# Epoch 255/1000
# 9/9 - 0s - loss: 35.0026 - val_loss: 30.4103 - 42ms/epoch - 5ms/step
# Epoch 256/1000
# 9/9 - 0s - loss: 34.4803 - val_loss: 30.2568 - 48ms/epoch - 5ms/step
# Epoch 257/1000
# 9/9 - 0s - loss: 34.3842 - val_loss: 29.6992 - 45ms/epoch - 5ms/step
# Epoch 258/1000
# 9/9 - 0s - loss: 33.8608 - val_loss: 29.4731 - 64ms/epoch - 7ms/step
# Epoch 259/1000
# 9/9 - 0s - loss: 33.6565 - val_loss: 29.3237 - 48ms/epoch - 5ms/step
# Epoch 260/1000
# 9/9 - 0s - loss: 33.3719 - val_loss: 28.9771 - 53ms/epoch - 6ms/step
# Epoch 261/1000
# 9/9 - 0s - loss: 33.4008 - val_loss: 28.8078 - 49ms/epoch - 5ms/step
# Epoch 262/1000
# 9/9 - 0s - loss: 33.1175 - val_loss: 28.8813 - 44ms/epoch - 5ms/step
# Epoch 263/1000
# 9/9 - 0s - loss: 32.9210 - val_loss: 28.2617 - 52ms/epoch - 6ms/step
# Epoch 264/1000
# 9/9 - 0s - loss: 32.4038 - val_loss: 28.0888 - 46ms/epoch - 5ms/step
# Epoch 265/1000
# 9/9 - 0s - loss: 32.1921 - val_loss: 27.8079 - 46ms/epoch - 5ms/step
# Epoch 266/1000
# 9/9 - 0s - loss: 31.9036 - val_loss: 27.8922 - 44ms/epoch - 5ms/step
# Epoch 267/1000
# 9/9 - 0s - loss: 31.8901 - val_loss: 27.3605 - 44ms/epoch - 5ms/step
# Epoch 268/1000
# 9/9 - 0s - loss: 31.5021 - val_loss: 27.1610 - 50ms/epoch - 6ms/step
# Epoch 269/1000
# 9/9 - 0s - loss: 31.2986 - val_loss: 27.1118 - 64ms/epoch - 7ms/step
# Epoch 270/1000
# 9/9 - 0s - loss: 31.0209 - val_loss: 26.7823 - 44ms/epoch - 5ms/step
# Epoch 271/1000
# 9/9 - 0s - loss: 30.7804 - val_loss: 26.5180 - 43ms/epoch - 5ms/step
# Epoch 272/1000
# 9/9 - 0s - loss: 30.5296 - val_loss: 26.3050 - 52ms/epoch - 6ms/step
# Epoch 273/1000
# 9/9 - 0s - loss: 30.2248 - val_loss: 26.3090 - 66ms/epoch - 7ms/step
# Epoch 274/1000
# 9/9 - 0s - loss: 30.1697 - val_loss: 25.9216 - 57ms/epoch - 6ms/step
# Epoch 275/1000
# 9/9 - 0s - loss: 29.8140 - val_loss: 25.7002 - 42ms/epoch - 5ms/step
# Epoch 276/1000
# 9/9 - 0s - loss: 29.7032 - val_loss: 25.4873 - 66ms/epoch - 7ms/step
# Epoch 277/1000
# 9/9 - 0s - loss: 29.7812 - val_loss: 25.3695 - 42ms/epoch - 5ms/step
# Epoch 278/1000
# 9/9 - 0s - loss: 28.9944 - val_loss: 25.1961 - 54ms/epoch - 6ms/step
# Epoch 279/1000
# 9/9 - 0s - loss: 29.1213 - val_loss: 24.8743 - 48ms/epoch - 5ms/step
# Epoch 280/1000
# 9/9 - 0s - loss: 28.9301 - val_loss: 24.7869 - 45ms/epoch - 5ms/step
# Epoch 281/1000
# 9/9 - 0s - loss: 28.5993 - val_loss: 24.5036 - 45ms/epoch - 5ms/step
# Epoch 282/1000
# 9/9 - 0s - loss: 28.4720 - val_loss: 24.2968 - 47ms/epoch - 5ms/step
# Epoch 283/1000
# 9/9 - 0s - loss: 28.3636 - val_loss: 24.2642 - 44ms/epoch - 5ms/step
# Epoch 284/1000
# 9/9 - 0s - loss: 28.1392 - val_loss: 24.0998 - 51ms/epoch - 6ms/step
# Epoch 285/1000
# 9/9 - 0s - loss: 27.8681 - val_loss: 23.7681 - 61ms/epoch - 7ms/step
# Epoch 286/1000
# 9/9 - 0s - loss: 27.5742 - val_loss: 23.5665 - 64ms/epoch - 7ms/step
# Epoch 287/1000
# 9/9 - 0s - loss: 27.3983 - val_loss: 23.4158 - 45ms/epoch - 5ms/step
# Epoch 288/1000
# 9/9 - 0s - loss: 27.9934 - val_loss: 23.5742 - 44ms/epoch - 5ms/step
# Epoch 289/1000
# 9/9 - 0s - loss: 26.9769 - val_loss: 23.0808 - 44ms/epoch - 5ms/step
# Epoch 290/1000
# 9/9 - 0s - loss: 26.8532 - val_loss: 22.8814 - 46ms/epoch - 5ms/step
# Epoch 291/1000
# 9/9 - 0s - loss: 26.7696 - val_loss: 22.7416 - 67ms/epoch - 7ms/step
# Epoch 292/1000
# 9/9 - 0s - loss: 26.4976 - val_loss: 22.5675 - 46ms/epoch - 5ms/step
# Epoch 293/1000
# 9/9 - 0s - loss: 26.4146 - val_loss: 22.3958 - 44ms/epoch - 5ms/step
# Epoch 294/1000
# 9/9 - 0s - loss: 26.3384 - val_loss: 22.2808 - 44ms/epoch - 5ms/step
# Epoch 295/1000
# 9/9 - 0s - loss: 25.8390 - val_loss: 22.2046 - 62ms/epoch - 7ms/step
# Epoch 296/1000
# 9/9 - 0s - loss: 25.8589 - val_loss: 21.9963 - 60ms/epoch - 7ms/step
# Epoch 297/1000
# 9/9 - 0s - loss: 25.6374 - val_loss: 21.7851 - 46ms/epoch - 5ms/step
# Epoch 298/1000
# 9/9 - 0s - loss: 25.5412 - val_loss: 21.6398 - 61ms/epoch - 7ms/step
# Epoch 299/1000
# 9/9 - 0s - loss: 25.2486 - val_loss: 21.5078 - 47ms/epoch - 5ms/step
# Epoch 300/1000
# 9/9 - 0s - loss: 25.2108 - val_loss: 21.3373 - 65ms/epoch - 7ms/step
# Epoch 301/1000
# 9/9 - 0s - loss: 25.0467 - val_loss: 21.2713 - 61ms/epoch - 7ms/step
# Epoch 302/1000
# 9/9 - 0s - loss: 24.9048 - val_loss: 21.1164 - 55ms/epoch - 6ms/step
# Epoch 303/1000
# 9/9 - 0s - loss: 24.6848 - val_loss: 20.9425 - 42ms/epoch - 5ms/step
# Epoch 304/1000
# 9/9 - 0s - loss: 24.5019 - val_loss: 20.8009 - 47ms/epoch - 5ms/step
# Epoch 305/1000
# 9/9 - 0s - loss: 24.6881 - val_loss: 20.6607 - 48ms/epoch - 5ms/step
# Epoch 306/1000
# 9/9 - 0s - loss: 24.4298 - val_loss: 20.6763 - 59ms/epoch - 7ms/step
# Epoch 307/1000
# 9/9 - 0s - loss: 24.1384 - val_loss: 20.5626 - 64ms/epoch - 7ms/step
# Epoch 308/1000
# 9/9 - 0s - loss: 24.1780 - val_loss: 20.2741 - 43ms/epoch - 5ms/step
# Epoch 309/1000
# 9/9 - 0s - loss: 24.1352 - val_loss: 20.5064 - 53ms/epoch - 6ms/step
# Epoch 310/1000
# 9/9 - 0s - loss: 23.8050 - val_loss: 20.1341 - 43ms/epoch - 5ms/step
# Epoch 311/1000
# 9/9 - 0s - loss: 23.5859 - val_loss: 19.9067 - 61ms/epoch - 7ms/step
# Epoch 312/1000
# 9/9 - 0s - loss: 23.4021 - val_loss: 19.7647 - 63ms/epoch - 7ms/step
# Epoch 313/1000
# 9/9 - 0s - loss: 23.6588 - val_loss: 19.6236 - 60ms/epoch - 7ms/step
# Epoch 314/1000
# 9/9 - 0s - loss: 22.9666 - val_loss: 19.7457 - 57ms/epoch - 6ms/step
# Epoch 315/1000
# 9/9 - 0s - loss: 23.3405 - val_loss: 19.4460 - 61ms/epoch - 7ms/step
# Epoch 316/1000
# 9/9 - 0s - loss: 22.8368 - val_loss: 19.3225 - 64ms/epoch - 7ms/step
# Epoch 317/1000
# 9/9 - 0s - loss: 22.7360 - val_loss: 19.2282 - 59ms/epoch - 7ms/step
# Epoch 318/1000
# 9/9 - 0s - loss: 22.6654 - val_loss: 19.0943 - 43ms/epoch - 5ms/step
# Epoch 319/1000
# 9/9 - 0s - loss: 22.4949 - val_loss: 19.0626 - 48ms/epoch - 5ms/step
# Epoch 320/1000
# 9/9 - 0s - loss: 22.3825 - val_loss: 18.9267 - 44ms/epoch - 5ms/step
# Epoch 321/1000
# 9/9 - 0s - loss: 22.1131 - val_loss: 18.9889 - 49ms/epoch - 5ms/step
# Epoch 322/1000
# 9/9 - 0s - loss: 22.4242 - val_loss: 18.7079 - 56ms/epoch - 6ms/step
# Epoch 323/1000
# 9/9 - 0s - loss: 22.0720 - val_loss: 18.5472 - 44ms/epoch - 5ms/step
# Epoch 324/1000
# 9/9 - 0s - loss: 21.9073 - val_loss: 18.4728 - 45ms/epoch - 5ms/step
# Epoch 325/1000
# 9/9 - 0s - loss: 21.7569 - val_loss: 18.3746 - 62ms/epoch - 7ms/step
# Epoch 326/1000
# 9/9 - 0s - loss: 21.6337 - val_loss: 18.2701 - 59ms/epoch - 7ms/step
# Epoch 327/1000
# 9/9 - 0s - loss: 21.9152 - val_loss: 18.1929 - 42ms/epoch - 5ms/step
# Epoch 328/1000
# 9/9 - 0s - loss: 21.8298 - val_loss: 18.3403 - 61ms/epoch - 7ms/step
# Epoch 329/1000
# 9/9 - 0s - loss: 21.3406 - val_loss: 18.1600 - 68ms/epoch - 8ms/step
# Epoch 330/1000
# 9/9 - 0s - loss: 21.4062 - val_loss: 17.9083 - 58ms/epoch - 6ms/step
# Epoch 331/1000
# 9/9 - 0s - loss: 21.3906 - val_loss: 17.9489 - 66ms/epoch - 7ms/step
# Epoch 332/1000
# 9/9 - 0s - loss: 21.0483 - val_loss: 17.7541 - 41ms/epoch - 5ms/step
# Epoch 333/1000
# 9/9 - 0s - loss: 21.0189 - val_loss: 17.7178 - 46ms/epoch - 5ms/step
# Epoch 334/1000
# 9/9 - 0s - loss: 20.7603 - val_loss: 17.5876 - 46ms/epoch - 5ms/step
# Epoch 335/1000
# 9/9 - 0s - loss: 20.9302 - val_loss: 17.4982 - 60ms/epoch - 7ms/step
# Epoch 336/1000
# 9/9 - 0s - loss: 20.6619 - val_loss: 17.5711 - 56ms/epoch - 6ms/step
# Epoch 337/1000
# 9/9 - 0s - loss: 20.8276 - val_loss: 17.4165 - 46ms/epoch - 5ms/step
# Epoch 338/1000
# 9/9 - 0s - loss: 20.4193 - val_loss: 17.2642 - 47ms/epoch - 5ms/step
# Epoch 339/1000
# 9/9 - 0s - loss: 20.3337 - val_loss: 17.1507 - 48ms/epoch - 5ms/step
# Epoch 340/1000
# 9/9 - 0s - loss: 20.4465 - val_loss: 17.1857 - 47ms/epoch - 5ms/step
# Epoch 341/1000
# 9/9 - 0s - loss: 20.3196 - val_loss: 17.0295 - 47ms/epoch - 5ms/step
# Epoch 342/1000
# 9/9 - 0s - loss: 20.1348 - val_loss: 17.1099 - 52ms/epoch - 6ms/step
# Epoch 343/1000
# 9/9 - 0s - loss: 19.9356 - val_loss: 16.9694 - 45ms/epoch - 5ms/step
# Epoch 344/1000
# 9/9 - 0s - loss: 20.2661 - val_loss: 16.8990 - 66ms/epoch - 7ms/step
# Epoch 345/1000
# 9/9 - 0s - loss: 19.9257 - val_loss: 16.7414 - 42ms/epoch - 5ms/step
# Epoch 346/1000
# 9/9 - 0s - loss: 19.6633 - val_loss: 16.8476 - 41ms/epoch - 5ms/step
# Epoch 347/1000
# 9/9 - 0s - loss: 20.0119 - val_loss: 16.6496 - 42ms/epoch - 5ms/step
# Epoch 348/1000
# 9/9 - 0s - loss: 19.6167 - val_loss: 16.5600 - 57ms/epoch - 6ms/step
# Epoch 349/1000
# 9/9 - 0s - loss: 19.5593 - val_loss: 16.4976 - 76ms/epoch - 8ms/step
# Epoch 350/1000
# 9/9 - 0s - loss: 19.4685 - val_loss: 16.5541 - 42ms/epoch - 5ms/step
# Epoch 351/1000
# 9/9 - 0s - loss: 19.4989 - val_loss: 16.3493 - 47ms/epoch - 5ms/step
# Epoch 352/1000
# 9/9 - 0s - loss: 19.5242 - val_loss: 16.3855 - 48ms/epoch - 5ms/step
# Epoch 353/1000
# 9/9 - 0s - loss: 19.4511 - val_loss: 16.2325 - 66ms/epoch - 7ms/step
# Epoch 354/1000
# 9/9 - 0s - loss: 19.6241 - val_loss: 16.2198 - 44ms/epoch - 5ms/step
# Epoch 355/1000
# 9/9 - 0s - loss: 19.4100 - val_loss: 16.4326 - 66ms/epoch - 7ms/step
# Epoch 356/1000
# 9/9 - 0s - loss: 19.0765 - val_loss: 16.0518 - 48ms/epoch - 5ms/step
# Epoch 357/1000
# 9/9 - 0s - loss: 18.9098 - val_loss: 16.0022 - 47ms/epoch - 5ms/step
# Epoch 358/1000
# 9/9 - 0s - loss: 19.0450 - val_loss: 15.9426 - 65ms/epoch - 7ms/step
# Epoch 359/1000
# 9/9 - 0s - loss: 18.9679 - val_loss: 15.9593 - 46ms/epoch - 5ms/step
# Epoch 360/1000
# 9/9 - 0s - loss: 18.9929 - val_loss: 16.0168 - 61ms/epoch - 7ms/step
# Epoch 361/1000
# 9/9 - 0s - loss: 18.9279 - val_loss: 16.0237 - 44ms/epoch - 5ms/step
# Epoch 362/1000
# 9/9 - 0s - loss: 18.6371 - val_loss: 15.7414 - 56ms/epoch - 6ms/step
# Epoch 363/1000
# 9/9 - 0s - loss: 18.5481 - val_loss: 15.7410 - 63ms/epoch - 7ms/step
# Epoch 364/1000
# 9/9 - 0s - loss: 18.9620 - val_loss: 15.6364 - 42ms/epoch - 5ms/step
# Epoch 365/1000
# 9/9 - 0s - loss: 18.8654 - val_loss: 15.9543 - 45ms/epoch - 5ms/step
# Epoch 366/1000
# 9/9 - 0s - loss: 18.7735 - val_loss: 15.5992 - 45ms/epoch - 5ms/step
# Epoch 367/1000
# 9/9 - 0s - loss: 18.5090 - val_loss: 15.6407 - 53ms/epoch - 6ms/step
# Epoch 368/1000
# 9/9 - 0s - loss: 18.2259 - val_loss: 15.6190 - 62ms/epoch - 7ms/step
# Epoch 369/1000
# 9/9 - 0s - loss: 18.2066 - val_loss: 15.4526 - 48ms/epoch - 5ms/step
# Epoch 370/1000
# 9/9 - 0s - loss: 18.0969 - val_loss: 15.3951 - 60ms/epoch - 7ms/step
# Epoch 371/1000
# 9/9 - 0s - loss: 18.0489 - val_loss: 15.3356 - 45ms/epoch - 5ms/step
# Epoch 372/1000
# 9/9 - 0s - loss: 18.0548 - val_loss: 15.4666 - 45ms/epoch - 5ms/step
# Epoch 373/1000
# 9/9 - 0s - loss: 18.4220 - val_loss: 15.2544 - 50ms/epoch - 6ms/step
# Epoch 374/1000
# 9/9 - 0s - loss: 18.2234 - val_loss: 15.3900 - 45ms/epoch - 5ms/step
# Epoch 375/1000
# 9/9 - 0s - loss: 17.8757 - val_loss: 15.1732 - 44ms/epoch - 5ms/step
# Epoch 376/1000
# 9/9 - 0s - loss: 17.8072 - val_loss: 15.1480 - 46ms/epoch - 5ms/step
# Epoch 377/1000
# 9/9 - 0s - loss: 17.8538 - val_loss: 15.1279 - 45ms/epoch - 5ms/step
# Epoch 378/1000
# 9/9 - 0s - loss: 17.6673 - val_loss: 15.0588 - 42ms/epoch - 5ms/step
# Epoch 379/1000
# 9/9 - 0s - loss: 17.6271 - val_loss: 15.0456 - 64ms/epoch - 7ms/step
# Epoch 380/1000
# 9/9 - 0s - loss: 17.7323 - val_loss: 15.0440 - 59ms/epoch - 7ms/step
# Epoch 381/1000
# 9/9 - 0s - loss: 17.7086 - val_loss: 15.1358 - 48ms/epoch - 5ms/step
# Epoch 382/1000
# 9/9 - 0s - loss: 17.4551 - val_loss: 14.9195 - 40ms/epoch - 4ms/step
# Epoch 383/1000
# 9/9 - 0s - loss: 17.3814 - val_loss: 15.0071 - 41ms/epoch - 5ms/step
# Epoch 384/1000
# 9/9 - 0s - loss: 17.7155 - val_loss: 14.8848 - 41ms/epoch - 5ms/step
# Epoch 385/1000
# 9/9 - 0s - loss: 17.4379 - val_loss: 14.8080 - 57ms/epoch - 6ms/step
# Epoch 386/1000
# 9/9 - 0s - loss: 17.3264 - val_loss: 14.7903 - 52ms/epoch - 6ms/step
# Epoch 387/1000
# 9/9 - 0s - loss: 17.3148 - val_loss: 14.7504 - 44ms/epoch - 5ms/step
# Epoch 388/1000
# 9/9 - 0s - loss: 17.3783 - val_loss: 14.8230 - 44ms/epoch - 5ms/step
# Epoch 389/1000
# 9/9 - 0s - loss: 17.2877 - val_loss: 14.7852 - 45ms/epoch - 5ms/step
# Epoch 390/1000
# 9/9 - 0s - loss: 17.7862 - val_loss: 14.6703 - 43ms/epoch - 5ms/step
# Epoch 391/1000
# 9/9 - 0s - loss: 17.7247 - val_loss: 14.7814 - 47ms/epoch - 5ms/step
# Epoch 392/1000
# 9/9 - 0s - loss: 17.0400 - val_loss: 15.2918 - 40ms/epoch - 4ms/step
# Epoch 393/1000
# 9/9 - 0s - loss: 16.9304 - val_loss: 14.8103 - 46ms/epoch - 5ms/step
# Epoch 394/1000
# 9/9 - 0s - loss: 17.4251 - val_loss: 14.5491 - 53ms/epoch - 6ms/step
# Epoch 395/1000
# 9/9 - 0s - loss: 17.0320 - val_loss: 14.6163 - 44ms/epoch - 5ms/step
# Epoch 396/1000
# 9/9 - 0s - loss: 16.8733 - val_loss: 14.4846 - 60ms/epoch - 7ms/step
# Epoch 397/1000
# 9/9 - 0s - loss: 16.9989 - val_loss: 14.5121 - 50ms/epoch - 6ms/step
# Epoch 398/1000
# 9/9 - 0s - loss: 17.4379 - val_loss: 14.4742 - 62ms/epoch - 7ms/step
# Epoch 399/1000
# 9/9 - 0s - loss: 17.3229 - val_loss: 14.8158 - 39ms/epoch - 4ms/step
# Epoch 400/1000
# 9/9 - 0s - loss: 16.8122 - val_loss: 14.8201 - 56ms/epoch - 6ms/step
# Epoch 401/1000
# 9/9 - 0s - loss: 17.1655 - val_loss: 14.4249 - 43ms/epoch - 5ms/step
# Epoch 402/1000
# 9/9 - 0s - loss: 16.9827 - val_loss: 14.3724 - 50ms/epoch - 6ms/step
# Epoch 403/1000
# 9/9 - 0s - loss: 16.7095 - val_loss: 14.3813 - 41ms/epoch - 5ms/step
# Epoch 404/1000
# 9/9 - 0s - loss: 16.6055 - val_loss: 14.4143 - 44ms/epoch - 5ms/step
# Epoch 405/1000
# 9/9 - 0s - loss: 16.4806 - val_loss: 14.3430 - 46ms/epoch - 5ms/step
# Epoch 406/1000
# 9/9 - 0s - loss: 16.5320 - val_loss: 14.3120 - 48ms/epoch - 5ms/step
# Epoch 407/1000
# 9/9 - 0s - loss: 16.6135 - val_loss: 14.3245 - 42ms/epoch - 5ms/step
# Epoch 408/1000
# 9/9 - 0s - loss: 16.5958 - val_loss: 14.2234 - 57ms/epoch - 6ms/step
# Epoch 409/1000
# 9/9 - 0s - loss: 16.7393 - val_loss: 14.2209 - 42ms/epoch - 5ms/step
# Epoch 410/1000
# 9/9 - 0s - loss: 16.6228 - val_loss: 14.3147 - 56ms/epoch - 6ms/step
# Epoch 411/1000
# 9/9 - 0s - loss: 16.7102 - val_loss: 14.1747 - 43ms/epoch - 5ms/step
# Epoch 412/1000
# 9/9 - 0s - loss: 16.3976 - val_loss: 14.3568 - 42ms/epoch - 5ms/step
# Epoch 413/1000
# 9/9 - 0s - loss: 16.4064 - val_loss: 14.1538 - 43ms/epoch - 5ms/step
# Epoch 414/1000
# 9/9 - 0s - loss: 16.2707 - val_loss: 14.2404 - 60ms/epoch - 7ms/step
# Epoch 415/1000
# 9/9 - 0s - loss: 16.1941 - val_loss: 14.1140 - 43ms/epoch - 5ms/step
# Epoch 416/1000
# 9/9 - 0s - loss: 16.1216 - val_loss: 14.2147 - 62ms/epoch - 7ms/step
# Epoch 417/1000
# 9/9 - 0s - loss: 16.3739 - val_loss: 14.0391 - 40ms/epoch - 4ms/step
# Epoch 418/1000
# 9/9 - 0s - loss: 16.2318 - val_loss: 14.0194 - 41ms/epoch - 5ms/step
# Epoch 419/1000
# 9/9 - 0s - loss: 16.0340 - val_loss: 14.0539 - 59ms/epoch - 7ms/step
# Epoch 420/1000
# 9/9 - 0s - loss: 16.0365 - val_loss: 13.9870 - 54ms/epoch - 6ms/step
# Epoch 421/1000
# 9/9 - 0s - loss: 16.0566 - val_loss: 14.0583 - 46ms/epoch - 5ms/step
# Epoch 422/1000
# 9/9 - 0s - loss: 16.2846 - val_loss: 13.9479 - 71ms/epoch - 8ms/step
# Epoch 423/1000
# 9/9 - 0s - loss: 16.0834 - val_loss: 13.9348 - 45ms/epoch - 5ms/step
# Epoch 424/1000
# 9/9 - 0s - loss: 15.9696 - val_loss: 13.9574 - 60ms/epoch - 7ms/step
# Epoch 425/1000
# 9/9 - 0s - loss: 15.9363 - val_loss: 13.9252 - 44ms/epoch - 5ms/step
# Epoch 426/1000
# 9/9 - 0s - loss: 15.9935 - val_loss: 13.9042 - 42ms/epoch - 5ms/step
# Epoch 427/1000
# 9/9 - 0s - loss: 15.9393 - val_loss: 13.8953 - 61ms/epoch - 7ms/step
# Epoch 428/1000
# 9/9 - 0s - loss: 15.8601 - val_loss: 13.8693 - 42ms/epoch - 5ms/step
# Epoch 429/1000
# 9/9 - 0s - loss: 15.7967 - val_loss: 13.8614 - 43ms/epoch - 5ms/step
# Epoch 430/1000
# 9/9 - 0s - loss: 15.7991 - val_loss: 13.8563 - 40ms/epoch - 4ms/step
# Epoch 431/1000
# 9/9 - 0s - loss: 15.7341 - val_loss: 13.8092 - 60ms/epoch - 7ms/step
# Epoch 432/1000
# 9/9 - 0s - loss: 15.8357 - val_loss: 13.7932 - 63ms/epoch - 7ms/step
# Epoch 433/1000
# 9/9 - 0s - loss: 15.7896 - val_loss: 13.7848 - 44ms/epoch - 5ms/step
# Epoch 434/1000
# 9/9 - 0s - loss: 15.7379 - val_loss: 13.8292 - 42ms/epoch - 5ms/step
# Epoch 435/1000
# 9/9 - 0s - loss: 15.6765 - val_loss: 13.8195 - 45ms/epoch - 5ms/step
# Epoch 436/1000
# 9/9 - 0s - loss: 16.2143 - val_loss: 13.7353 - 47ms/epoch - 5ms/step
# Epoch 437/1000
# 9/9 - 0s - loss: 15.5795 - val_loss: 13.7551 - 45ms/epoch - 5ms/step
# Epoch 438/1000
# 9/9 - 0s - loss: 15.7669 - val_loss: 13.7021 - 43ms/epoch - 5ms/step
# Epoch 439/1000
# 9/9 - 0s - loss: 15.6365 - val_loss: 13.8357 - 50ms/epoch - 6ms/step
# Epoch 440/1000
# 9/9 - 0s - loss: 15.8381 - val_loss: 13.7023 - 44ms/epoch - 5ms/step
# Epoch 441/1000
# 9/9 - 0s - loss: 15.5086 - val_loss: 13.8131 - 44ms/epoch - 5ms/step
# Epoch 442/1000
# 9/9 - 0s - loss: 16.3272 - val_loss: 13.8764 - 44ms/epoch - 5ms/step
# Epoch 443/1000
# 9/9 - 0s - loss: 16.3211 - val_loss: 13.6849 - 63ms/epoch - 7ms/step
# Epoch 444/1000
# 9/9 - 0s - loss: 15.4367 - val_loss: 13.6292 - 58ms/epoch - 6ms/step
# Epoch 445/1000
# 9/9 - 0s - loss: 15.5739 - val_loss: 13.7460 - 61ms/epoch - 7ms/step
# Epoch 446/1000
# 9/9 - 0s - loss: 16.2420 - val_loss: 13.5926 - 45ms/epoch - 5ms/step
# Epoch 447/1000
# 9/9 - 0s - loss: 16.4588 - val_loss: 13.5895 - 44ms/epoch - 5ms/step
# Epoch 448/1000
# 9/9 - 0s - loss: 16.2376 - val_loss: 13.7001 - 49ms/epoch - 5ms/step
# Epoch 449/1000
# 9/9 - 0s - loss: 15.3930 - val_loss: 13.5498 - 42ms/epoch - 5ms/step
# Epoch 450/1000
# 9/9 - 0s - loss: 15.2609 - val_loss: 13.6278 - 43ms/epoch - 5ms/step
# Epoch 451/1000
# 9/9 - 0s - loss: 15.3043 - val_loss: 13.5230 - 57ms/epoch - 6ms/step
# Epoch 452/1000
# 9/9 - 0s - loss: 15.4987 - val_loss: 13.5096 - 43ms/epoch - 5ms/step
# Epoch 453/1000
# 9/9 - 0s - loss: 15.3055 - val_loss: 13.5620 - 47ms/epoch - 5ms/step
# Epoch 454/1000
# 9/9 - 0s - loss: 15.2233 - val_loss: 13.5071 - 64ms/epoch - 7ms/step
# Epoch 455/1000
# 9/9 - 0s - loss: 15.2194 - val_loss: 13.4771 - 62ms/epoch - 7ms/step
# Epoch 456/1000
# 9/9 - 0s - loss: 15.3445 - val_loss: 13.4607 - 41ms/epoch - 5ms/step
# Epoch 457/1000
# 9/9 - 0s - loss: 15.2149 - val_loss: 13.4735 - 42ms/epoch - 5ms/step
# Epoch 458/1000
# 9/9 - 0s - loss: 15.2264 - val_loss: 13.5654 - 51ms/epoch - 6ms/step
# Epoch 459/1000
# 9/9 - 0s - loss: 15.2153 - val_loss: 13.4740 - 45ms/epoch - 5ms/step
# Epoch 460/1000
# 9/9 - 0s - loss: 15.6034 - val_loss: 13.4291 - 44ms/epoch - 5ms/step
# Epoch 461/1000
# 9/9 - 0s - loss: 15.1946 - val_loss: 13.3996 - 43ms/epoch - 5ms/step
# Epoch 462/1000
# 9/9 - 0s - loss: 15.6241 - val_loss: 13.3885 - 46ms/epoch - 5ms/step
# Epoch 463/1000
# 9/9 - 0s - loss: 14.9649 - val_loss: 13.6127 - 68ms/epoch - 8ms/step
# Epoch 464/1000
# 9/9 - 0s - loss: 15.0444 - val_loss: 13.5212 - 43ms/epoch - 5ms/step
# Epoch 465/1000
# 9/9 - 0s - loss: 16.1261 - val_loss: 13.9303 - 44ms/epoch - 5ms/step
# Epoch 466/1000
# 9/9 - 0s - loss: 15.6748 - val_loss: 13.3830 - 47ms/epoch - 5ms/step
# Epoch 467/1000
# 9/9 - 0s - loss: 15.2363 - val_loss: 13.3919 - 45ms/epoch - 5ms/step
# Epoch 468/1000
# 9/9 - 0s - loss: 14.9402 - val_loss: 13.3230 - 63ms/epoch - 7ms/step
# Epoch 469/1000
# 9/9 - 0s - loss: 15.0471 - val_loss: 13.4149 - 44ms/epoch - 5ms/step
# Epoch 470/1000
# 9/9 - 0s - loss: 15.4307 - val_loss: 13.3053 - 42ms/epoch - 5ms/step
# Epoch 471/1000
# 9/9 - 0s - loss: 15.1290 - val_loss: 13.3981 - 42ms/epoch - 5ms/step
# Epoch 472/1000
# 9/9 - 0s - loss: 14.9179 - val_loss: 13.5821 - 63ms/epoch - 7ms/step
# Epoch 473/1000
# 9/9 - 0s - loss: 15.6913 - val_loss: 13.2789 - 45ms/epoch - 5ms/step
# Epoch 474/1000
# 9/9 - 0s - loss: 15.4288 - val_loss: 13.4136 - 41ms/epoch - 5ms/step
# Epoch 475/1000
# 9/9 - 0s - loss: 14.9128 - val_loss: 13.3099 - 44ms/epoch - 5ms/step
# Epoch 476/1000
# 9/9 - 0s - loss: 14.9415 - val_loss: 13.2235 - 46ms/epoch - 5ms/step
# Epoch 477/1000
# 9/9 - 0s - loss: 14.7452 - val_loss: 13.2928 - 49ms/epoch - 5ms/step
# Epoch 478/1000
# 9/9 - 0s - loss: 14.7452 - val_loss: 13.2106 - 52ms/epoch - 6ms/step
# Epoch 479/1000
# 9/9 - 0s - loss: 14.6936 - val_loss: 13.3172 - 57ms/epoch - 6ms/step
# Epoch 480/1000
# 9/9 - 0s - loss: 14.7500 - val_loss: 13.2329 - 44ms/epoch - 5ms/step
# Epoch 481/1000
# 9/9 - 0s - loss: 14.7662 - val_loss: 13.2818 - 41ms/epoch - 5ms/step
# Epoch 482/1000
# 9/9 - 0s - loss: 15.0100 - val_loss: 13.3928 - 58ms/epoch - 6ms/step
# Epoch 483/1000
# 9/9 - 0s - loss: 14.6808 - val_loss: 13.1921 - 42ms/epoch - 5ms/step
# Epoch 484/1000
# 9/9 - 0s - loss: 14.9442 - val_loss: 13.2156 - 47ms/epoch - 5ms/step
# Epoch 485/1000
# 9/9 - 0s - loss: 14.8530 - val_loss: 13.2657 - 63ms/epoch - 7ms/step
# Epoch 486/1000
# 9/9 - 0s - loss: 15.1156 - val_loss: 13.1077 - 61ms/epoch - 7ms/step
# Epoch 487/1000
# 9/9 - 0s - loss: 14.6419 - val_loss: 13.1050 - 63ms/epoch - 7ms/step
# Epoch 488/1000
# 9/9 - 0s - loss: 14.5532 - val_loss: 13.0829 - 52ms/epoch - 6ms/step
# Epoch 489/1000
# 9/9 - 0s - loss: 14.6685 - val_loss: 13.1235 - 43ms/epoch - 5ms/step
# Epoch 490/1000
# 9/9 - 0s - loss: 15.2778 - val_loss: 13.3701 - 43ms/epoch - 5ms/step
# Epoch 491/1000
# 9/9 - 0s - loss: 15.0362 - val_loss: 13.0763 - 58ms/epoch - 6ms/step
# Epoch 492/1000
# 9/9 - 0s - loss: 14.6797 - val_loss: 13.3342 - 57ms/epoch - 6ms/step
# Epoch 493/1000
# 9/9 - 0s - loss: 14.4002 - val_loss: 13.0603 - 62ms/epoch - 7ms/step
# Epoch 494/1000
# 9/9 - 0s - loss: 14.6877 - val_loss: 13.1641 - 44ms/epoch - 5ms/step
# Epoch 495/1000
# 9/9 - 0s - loss: 14.4822 - val_loss: 13.0233 - 62ms/epoch - 7ms/step
# Epoch 496/1000
# 9/9 - 0s - loss: 14.2823 - val_loss: 13.4092 - 54ms/epoch - 6ms/step
# Epoch 497/1000
# 9/9 - 0s - loss: 14.6893 - val_loss: 12.9874 - 65ms/epoch - 7ms/step
# Epoch 498/1000
# 9/9 - 0s - loss: 14.3192 - val_loss: 13.0072 - 58ms/epoch - 6ms/step
# Epoch 499/1000
# 9/9 - 0s - loss: 14.2989 - val_loss: 12.9679 - 60ms/epoch - 7ms/step
# Epoch 500/1000
# 9/9 - 0s - loss: 14.3066 - val_loss: 13.0807 - 58ms/epoch - 6ms/step
# Epoch 501/1000
# 9/9 - 0s - loss: 14.4665 - val_loss: 13.0510 - 42ms/epoch - 5ms/step
# Epoch 502/1000
# 9/9 - 0s - loss: 14.6398 - val_loss: 13.0628 - 44ms/epoch - 5ms/step
# Epoch 503/1000
# 9/9 - 0s - loss: 14.2402 - val_loss: 12.9697 - 44ms/epoch - 5ms/step
# Epoch 504/1000
# 9/9 - 0s - loss: 14.3904 - val_loss: 12.9167 - 64ms/epoch - 7ms/step
# Epoch 505/1000
# 9/9 - 0s - loss: 14.1798 - val_loss: 12.9135 - 45ms/epoch - 5ms/step
# Epoch 506/1000
# 9/9 - 0s - loss: 14.1770 - val_loss: 13.0870 - 61ms/epoch - 7ms/step
# Epoch 507/1000
# 9/9 - 0s - loss: 14.1466 - val_loss: 12.8821 - 44ms/epoch - 5ms/step
# Epoch 508/1000
# 9/9 - 0s - loss: 14.1311 - val_loss: 12.8705 - 45ms/epoch - 5ms/step
# Epoch 509/1000
# 9/9 - 0s - loss: 14.3887 - val_loss: 13.0857 - 45ms/epoch - 5ms/step
# Epoch 510/1000
# 9/9 - 0s - loss: 14.4612 - val_loss: 12.8780 - 42ms/epoch - 5ms/step
# Epoch 511/1000
# 9/9 - 0s - loss: 14.1573 - val_loss: 12.8438 - 44ms/epoch - 5ms/step
# Epoch 512/1000
# 9/9 - 0s - loss: 14.8973 - val_loss: 13.6269 - 40ms/epoch - 4ms/step
# Epoch 513/1000
# 9/9 - 0s - loss: 14.7606 - val_loss: 12.9635 - 41ms/epoch - 5ms/step
# Epoch 514/1000
# 9/9 - 0s - loss: 14.2061 - val_loss: 13.0438 - 57ms/epoch - 6ms/step
# Epoch 515/1000
# 9/9 - 0s - loss: 14.0861 - val_loss: 12.7972 - 48ms/epoch - 5ms/step
# Epoch 516/1000
# 9/9 - 0s - loss: 14.0945 - val_loss: 12.8082 - 58ms/epoch - 6ms/step
# Epoch 517/1000
# 9/9 - 0s - loss: 14.2707 - val_loss: 13.0394 - 44ms/epoch - 5ms/step
# Epoch 518/1000
# 9/9 - 0s - loss: 14.0695 - val_loss: 12.7800 - 68ms/epoch - 8ms/step
# Epoch 519/1000
# 9/9 - 0s - loss: 14.1009 - val_loss: 12.8162 - 46ms/epoch - 5ms/step
# Epoch 520/1000
# 9/9 - 0s - loss: 14.0162 - val_loss: 13.1881 - 61ms/epoch - 7ms/step
# Epoch 521/1000
# 9/9 - 0s - loss: 14.3666 - val_loss: 12.7481 - 45ms/epoch - 5ms/step
# Epoch 522/1000
# 9/9 - 0s - loss: 13.8749 - val_loss: 12.8198 - 65ms/epoch - 7ms/step
# Epoch 523/1000
# 9/9 - 0s - loss: 13.8422 - val_loss: 12.7322 - 68ms/epoch - 8ms/step
# Epoch 524/1000
# 9/9 - 0s - loss: 13.8386 - val_loss: 13.7490 - 60ms/epoch - 7ms/step
# Epoch 525/1000
# 9/9 - 0s - loss: 14.6323 - val_loss: 13.4537 - 44ms/epoch - 5ms/step
# Epoch 526/1000
# 9/9 - 0s - loss: 15.1757 - val_loss: 14.3827 - 68ms/epoch - 8ms/step
# Epoch 527/1000
# 9/9 - 0s - loss: 15.0844 - val_loss: 12.7963 - 41ms/epoch - 5ms/step
# Epoch 528/1000
# 9/9 - 0s - loss: 13.9795 - val_loss: 12.7016 - 44ms/epoch - 5ms/step
# Epoch 529/1000
# 9/9 - 0s - loss: 14.9717 - val_loss: 13.2525 - 43ms/epoch - 5ms/step
# Epoch 530/1000
# 9/9 - 0s - loss: 14.2834 - val_loss: 12.8161 - 69ms/epoch - 8ms/step
# Epoch 531/1000
# 9/9 - 0s - loss: 13.8717 - val_loss: 12.7131 - 47ms/epoch - 5ms/step
# Epoch 532/1000
# 9/9 - 0s - loss: 14.1361 - val_loss: 12.8640 - 49ms/epoch - 5ms/step
# Epoch 533/1000
# Restoring model weights from the end of the best epoch: 528.
# 9/9 - 0s - loss: 14.2491 - val_loss: 12.7455 - 80ms/epoch - 9ms/step
# Epoch 533: early stopping
# 3/3 [==============================] - 0s 5ms/step

# %% [markdown]
# Now that we've trained the neural network, we can check its RMSE error.

# %%
import numpy as np

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 3.5639284216296003

# %% [markdown]
# Now we are ready to generate the Kaggle submission file.  We will use the MPG test data that does not contain a $y$ target value.  It is our job to predict this value and submit it to Kaggle.

# %%
import pandas as pd

# Generate Kaggle submit file

# Encode feature vector
df_test = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/datasets/"+\
    "kaggle_auto_test.csv", na_values=['NA','?'])

# Convert to numpy - regression
ids = df_test['id']
df_test.drop('id', axis=1, inplace=True)

# Handle missing value
df_test['horsepower'] = df_test['horsepower'].\
    fillna(df['horsepower'].median())

x = df_test[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values

# Generate predictions
pred = model.predict(x)
#pred

# Create submission data set

df_submit = pd.DataFrame(pred)
df_submit.insert(0,'id',ids)
df_submit.columns = ['id','mpg']

# Write submit file locally
df_submit.to_csv("auto_submit.csv", index=False) 

print(df_submit[:5])
# Out:
# 2/2 [==============================] - 0s 5ms/step
#     id        mpg
# 0  350  31.349438
# 1  351  29.072880
# 2  352  30.096264
# 3  353  29.706753
# 4  354  29.783253
