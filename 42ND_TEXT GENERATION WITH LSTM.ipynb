# %% [markdown]
# #  Applications of Deep Neural Networks
# **Module 10: Time Series in Keras**

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 10.3: Text Generation with LSTM
#
# Recurrent neural networks are also known for their ability to generate text. As a result, the neural network's output can be free-form text. This section will demonstrate how to train an LSTM on a textual document, such as classic literature, and learn to output new text that appears to be of the same form as the training material. If you train your LSTM on [Shakespeare](https://en.wikipedia.org/wiki/William_Shakespeare), it will learn to crank out new prose similar to what Shakespeare had written.
#
# Don't get your hopes up. You will not teach your deep neural network to write the next [Pulitzer Prize for Fiction](https://en.wikipedia.org/wiki/Pulitzer_Prize_for_Fiction). The prose generated by your neural network will be nonsensical. However, the output text will usually be nearly grammatically correct and similar to the source training documents.
#
# A neural network generating nonsensical text based on literature may not seem helpful. However, this technology gets so much interest because it forms the foundation for many more advanced technologies. The LSTM will typically learn human grammar from the source document opens a wide range of possibilities. You can use similar technology to complete sentences when entering text. The ability to output free-form text has become the foundation of many other technologies. In the next part, we will use this technique to create a neural network that can write captions for images to describe what is going on in the picture.
#
# ## Additional Information
#
# The following are some articles that I found helpful in putting this section together.
#
# * [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
# * [Keras LSTM Generation Example](https://keras.io/examples/lstm_text_generation/)
#
# ## Character-Level Text Generation
#
# There are several different approaches to teaching a neural network to output free-form text. The most basic question is if you wish the neural network to learn at the word or character level. Learning at the character level is the more interesting of the two. The LSTM is learning to construct its own words without even being shown what a word is. We will begin with character-level text generation. In the next module, we will see how we can use nearly the same technique to operate at the word level. We will implement word-level automatic captioning in the next module.
#
# We import the needed Python packages and define the sequence length, named **maxlen**. Time-series neural networks always accept their input as a fixed-length array. Because you might not use all of the sequence elements, filling extra pieces with zeros is common. You will divide the text into sequences of this length, and the neural network will train to predict what comes after this sequence.

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re

# %% [markdown]
# We will train the neural network on the classic children's book [Treasure Island](https://en.wikipedia.org/wiki/Treasure_Island).  We begin by loading this text into a Python string and displaying the first 1,000 characters.

# %%
r = requests.get("https://data.heatonresearch.com/data/t81-558/text/"\
                 "treasure_island.txt")
raw_text = r.text
print(raw_text[0:1000])
# Out:
# ï»¿The Project Gutenberg EBook of Treasure Island, by Robert Louis Stevenson
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: Treasure Island
#
# Author: Robert Louis Stevenson
#
# Illustrator: Milo Winter
#
# Release Date: January 12, 2009 [EBook #27780]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK TREASURE ISLAND ***
#
#
#
#
# Produced by Juliet Sutherland, Stephen Blundell and the
# Online Distributed Proofreading Team at http://www.pgdp.net
#
#
#
#
#
#
#
#
#
#  THE ILLUSTRATED CHILDREN'S LIBRARY
#
#
#          _Treasure Island_
#
#        Robert Louis Stevenson
#
#           _Illustrated by_
#             Milo Winter
#
#
#            [Illustration]
#
#
#            GRAMERCY BOOKS
#               NEW YORK
#
#
#
#
#  Foreword copyright Â© 1986 by Random House V

# %% [markdown]
# We will extract all unique characters from the text and sort them.  This technique allows us to assign a unique ID to each character.  Because we sorted the characters, these IDs should remain the same.  The IDs will change if we add new characters to the original text.  We build two dictionaries.  The first **char2idx** is used to convert a character into its ID.  The second **idx2char** converts an ID back into its character.

# %%
processed_text = raw_text.lower()
processed_text = re.sub(r'[^\x00-\x7f]',r'', processed_text) 

print('corpus length:', len(processed_text))

chars = sorted(list(set(processed_text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 397400
# total chars: 60

# %% [markdown]
# We are now ready to build the actual sequences.  Like previous neural networks, there will be an $x$ and $y$.  However, for the LSTM, $x$ and $y$ will be sequences.  The $x$ input will specify the sequences where $y$ is the expected output.  The following code generates all possible sequences.

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(processed_text) - maxlen, step):
    sentences.append(processed_text[i: i + maxlen])
    next_chars.append(processed_text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 132454

# %%
sentences
# Out:
# ['the project gutenberg ebook of treasure ',
#  ' project gutenberg ebook of treasure isl',
#  'oject gutenberg ebook of treasure island',
#  'ct gutenberg ebook of treasure island, b',
#  'gutenberg ebook of treasure island, by r',
#  'enberg ebook of treasure island, by robe',
#  'erg ebook of treasure island, by robert ',
#  ' ebook of treasure island, by robert lou',
#  'ook of treasure island, by robert louis ',
#  ' of treasure island, by robert louis ste',
#  ' treasure island, by robert louis steven',
#  'easure island, by robert louis stevenson',
#  'ure island, by robert louis stevenson\r\n\r',
#  ' island, by robert louis stevenson\r\n\r\nth',
#  'land, by robert louis stevenson\r\n\r\nthis ',
#  'd, by robert louis stevenson\r\n\r\nthis ebo',
#  'by robert louis stevenson\r\n\r\nthis ebook ',
#  'robert louis stevenson\r\n\r\nthis ebook is ',
#  'ert louis stevenson\r\n\r\nthis ebook is for',
#  ' louis stevenson\r\n\r\nthis ebook is for th',
#  'uis stevenson\r\n\r\nthis ebook is for the u',
#  ' stevenson\r\n\r\nthis ebook is for the use ',
#  'evenson\r\n\r\nthis ebook is for the use of ',
#  'nson\r\n\r\nthis ebook is for the use of any',
#  'n\r\n\r\nthis ebook is for the use of anyone',
#  '\r\nthis ebook is for the use of anyone an',
#  'his ebook is for the use of anyone anywh',
#  ' ebook is for the use of anyone anywhere',
#  'ook is for the use of anyone anywhere at',
#  ' is for the use of anyone anywhere at no',
#  ' for the use of anyone anywhere at no co',
#  'r the use of anyone anywhere at no cost ',
#  'he use of anyone anywhere at no cost and',
#  'use of anyone anywhere at no cost and wi',
#  ' of anyone anywhere at no cost and with\r',
#  ' anyone anywhere at no cost and with\r\nal',
#  'yone anywhere at no cost and with\r\nalmos',
#  'e anywhere at no cost and with\r\nalmost n',
#  'nywhere at no cost and with\r\nalmost no r',
#  'here at no cost and with\r\nalmost no rest',
#  'e at no cost and with\r\nalmost no restric',
#  't no cost and with\r\nalmost no restrictio',
#  'o cost and with\r\nalmost no restrictions ',
#  'ost and with\r\nalmost no restrictions wha',
#  ' and with\r\nalmost no restrictions whatso',
#  'd with\r\nalmost no restrictions whatsoeve',
#  'ith\r\nalmost no restrictions whatsoever. ',
#  '\r\nalmost no restrictions whatsoever.  yo',
#  'lmost no restrictions whatsoever.  you m',
#  'st no restrictions whatsoever.  you may ',
#  'no restrictions whatsoever.  you may cop',
#  'restrictions whatsoever.  you may copy i',
#  'trictions whatsoever.  you may copy it, ',
#  'ctions whatsoever.  you may copy it, giv',
#  'ons whatsoever.  you may copy it, give i',
#  ' whatsoever.  you may copy it, give it a',
#  'atsoever.  you may copy it, give it away',
#  'oever.  you may copy it, give it away or',
#  'er.  you may copy it, give it away or\r\nr',
#  '  you may copy it, give it away or\r\nre-u',
#  'ou may copy it, give it away or\r\nre-use ',
#  'may copy it, give it away or\r\nre-use it ',
#  ' copy it, give it away or\r\nre-use it und',
#  'py it, give it away or\r\nre-use it under ',
#  'it, give it away or\r\nre-use it under the',
#  ' give it away or\r\nre-use it under the te',
#  've it away or\r\nre-use it under the terms',
#  'it away or\r\nre-use it under the terms of',
#  'away or\r\nre-use it under the terms of th',
#  'y or\r\nre-use it under the terms of the p',
#  'r\r\nre-use it under the terms of the proj',
#  're-use it under the terms of the project',
#  'use it under the terms of the project gu',
#  ' it under the terms of the project guten',
#  ' under the terms of the project gutenber',
#  'der the terms of the project gutenberg l',
#  ' the terms of the project gutenberg lice',
#  'e terms of the project gutenberg license',
#  'erms of the project gutenberg license in',
#  's of the project gutenberg license inclu',
#  'f the project gutenberg license included',
#  'he project gutenberg license included\r\nw',
#  'project gutenberg license included\r\nwith',
#  'ject gutenberg license included\r\nwith th',
#  't gutenberg license included\r\nwith this ',
#  'utenberg license included\r\nwith this ebo',
#  'nberg license included\r\nwith this ebook ',
#  'rg license included\r\nwith this ebook or ',
#  'license included\r\nwith this ebook or onl',
#  'ense included\r\nwith this ebook or online',
#  'e included\r\nwith this ebook or online at',
#  'ncluded\r\nwith this ebook or online at ww',
#  'uded\r\nwith this ebook or online at www.g',
#  'd\r\nwith this ebook or online at www.gute',
#  'with this ebook or online at www.gutenbe',
#  'h this ebook or online at www.gutenberg.',
#  'his ebook or online at www.gutenberg.net',
#  ' ebook or online at www.gutenberg.net\r\n\r',
#  'ook or online at www.gutenberg.net\r\n\r\n\r\n',
#  ' or online at www.gutenberg.net\r\n\r\n\r\ntit',
#  ' online at www.gutenberg.net\r\n\r\n\r\ntitle:',
#  'line at www.gutenberg.net\r\n\r\n\r\ntitle: tr',
#  'e at www.gutenberg.net\r\n\r\n\r\ntitle: treas',
#  't www.gutenberg.net\r\n\r\n\r\ntitle: treasure',
#  'ww.gutenberg.net\r\n\r\n\r\ntitle: treasure is',
#  'gutenberg.net\r\n\r\n\r\ntitle: treasure islan',
#  'enberg.net\r\n\r\n\r\ntitle: treasure island\r\n',
#  'erg.net\r\n\r\n\r\ntitle: treasure island\r\n\r\na',
#  '.net\r\n\r\n\r\ntitle: treasure island\r\n\r\nauth',
#  't\r\n\r\n\r\ntitle: treasure island\r\n\r\nauthor:',
#  '\r\n\r\ntitle: treasure island\r\n\r\nauthor: ro',
#  '\ntitle: treasure island\r\n\r\nauthor: rober',
#  'tle: treasure island\r\n\r\nauthor: robert l',
#  ': treasure island\r\n\r\nauthor: robert loui',
#  'reasure island\r\n\r\nauthor: robert louis s',
#  'sure island\r\n\r\nauthor: robert louis stev',
#  'e island\r\n\r\nauthor: robert louis stevens',
#  'sland\r\n\r\nauthor: robert louis stevenson\r',
#  'nd\r\n\r\nauthor: robert louis stevenson\r\n\r\n',
#  '\n\r\nauthor: robert louis stevenson\r\n\r\nill',
#  'author: robert louis stevenson\r\n\r\nillust',
#  'hor: robert louis stevenson\r\n\r\nillustrat',
#  ': robert louis stevenson\r\n\r\nillustrator:',
#  'obert louis stevenson\r\n\r\nillustrator: mi',
#  'rt louis stevenson\r\n\r\nillustrator: milo ',
#  'louis stevenson\r\n\r\nillustrator: milo win',
#  'is stevenson\r\n\r\nillustrator: milo winter',
#  'stevenson\r\n\r\nillustrator: milo winter\r\n\r',
#  'venson\r\n\r\nillustrator: milo winter\r\n\r\nre',
#  'son\r\n\r\nillustrator: milo winter\r\n\r\nrelea',
#  '\r\n\r\nillustrator: milo winter\r\n\r\nrelease ',
#  '\nillustrator: milo winter\r\n\r\nrelease dat',
#  'lustrator: milo winter\r\n\r\nrelease date: ',
#  'trator: milo winter\r\n\r\nrelease date: jan',
#  'tor: milo winter\r\n\r\nrelease date: januar',
#  ': milo winter\r\n\r\nrelease date: january 1',
#  'ilo winter\r\n\r\nrelease date: january 12, ',
#  ' winter\r\n\r\nrelease date: january 12, 200',
#  'nter\r\n\r\nrelease date: january 12, 2009 [',
#  'r\r\n\r\nrelease date: january 12, 2009 [ebo',
#  '\r\nrelease date: january 12, 2009 [ebook ',
#  'elease date: january 12, 2009 [ebook #27',
#  'ase date: january 12, 2009 [ebook #27780',
#  ' date: january 12, 2009 [ebook #27780]\r\n',
#  'te: january 12, 2009 [ebook #27780]\r\n\r\nl',
#  ' january 12, 2009 [ebook #27780]\r\n\r\nlang',
#  'nuary 12, 2009 [ebook #27780]\r\n\r\nlanguag',
#  'ry 12, 2009 [ebook #27780]\r\n\r\nlanguage: ',
#  '12, 2009 [ebook #27780]\r\n\r\nlanguage: eng',
#  ' 2009 [ebook #27780]\r\n\r\nlanguage: englis',
#  '09 [ebook #27780]\r\n\r\nlanguage: english\r\n',
#  '[ebook #27780]\r\n\r\nlanguage: english\r\n\r\n\r',
#  'ook #27780]\r\n\r\nlanguage: english\r\n\r\n\r\n**',
#  ' #27780]\r\n\r\nlanguage: english\r\n\r\n\r\n*** s',
#  '7780]\r\n\r\nlanguage: english\r\n\r\n\r\n*** star',
#  '0]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start o',
#  '\n\r\nlanguage: english\r\n\r\n\r\n*** start of t',
#  'language: english\r\n\r\n\r\n*** start of this',
#  'guage: english\r\n\r\n\r\n*** start of this pr',
#  'ge: english\r\n\r\n\r\n*** start of this proje',
#  ' english\r\n\r\n\r\n*** start of this project ',
#  'glish\r\n\r\n\r\n*** start of this project gut',
#  'sh\r\n\r\n\r\n*** start of this project gutenb',
#  '\n\r\n\r\n*** start of this project gutenberg',
#  '\r\n*** start of this project gutenberg eb',
#  '** start of this project gutenberg ebook',
#  'start of this project gutenberg ebook tr',
#  'rt of this project gutenberg ebook treas',
#  'of this project gutenberg ebook treasure',
#  'this project gutenberg ebook treasure is',
#  's project gutenberg ebook treasure islan',
#  'roject gutenberg ebook treasure island *',
#  'ect gutenberg ebook treasure island ***\r',
#  ' gutenberg ebook treasure island ***\r\n\r\n',
#  'tenberg ebook treasure island ***\r\n\r\n\r\n\r',
#  'berg ebook treasure island ***\r\n\r\n\r\n\r\n\r\n',
#  'g ebook treasure island ***\r\n\r\n\r\n\r\n\r\npro',
#  'book treasure island ***\r\n\r\n\r\n\r\n\r\nproduc',
#  'k treasure island ***\r\n\r\n\r\n\r\n\r\nproduced ',
#  'reasure island ***\r\n\r\n\r\n\r\n\r\nproduced by ',
#  'sure island ***\r\n\r\n\r\n\r\n\r\nproduced by jul',
#  'e island ***\r\n\r\n\r\n\r\n\r\nproduced by juliet',
#  'sland ***\r\n\r\n\r\n\r\n\r\nproduced by juliet su',
#  'nd ***\r\n\r\n\r\n\r\n\r\nproduced by juliet suthe',
#  '***\r\n\r\n\r\n\r\n\r\nproduced by juliet sutherla',
#  '\r\n\r\n\r\n\r\n\r\nproduced by juliet sutherland,',
#  '\n\r\n\r\n\r\nproduced by juliet sutherland, st',
#  '\r\n\r\nproduced by juliet sutherland, steph',
#  '\nproduced by juliet sutherland, stephen ',
#  'oduced by juliet sutherland, stephen blu',
#  'ced by juliet sutherland, stephen blunde',
#  ' by juliet sutherland, stephen blundell ',
#  ' juliet sutherland, stephen blundell and',
#  'liet sutherland, stephen blundell and th',
#  't sutherland, stephen blundell and the\r\n',
#  'utherland, stephen blundell and the\r\nonl',
#  'erland, stephen blundell and the\r\nonline',
#  'and, stephen blundell and the\r\nonline di',
#  ', stephen blundell and the\r\nonline distr',
#  'tephen blundell and the\r\nonline distribu',
#  'hen blundell and the\r\nonline distributed',
#  ' blundell and the\r\nonline distributed pr',
#  'undell and the\r\nonline distributed proof',
#  'ell and the\r\nonline distributed proofrea',
#  ' and the\r\nonline distributed proofreadin',
#  'd the\r\nonline distributed proofreading t',
#  'he\r\nonline distributed proofreading team',
#  '\nonline distributed proofreading team at',
#  'line distributed proofreading team at ht',
#  'e distributed proofreading team at http:',
#  'istributed proofreading team at http://w',
#  'ributed proofreading team at http://www.',
#  'uted proofreading team at http://www.pgd',
#  'd proofreading team at http://www.pgdp.n',
#  'roofreading team at http://www.pgdp.net\r',
#  'freading team at http://www.pgdp.net\r\n\r\n',
#  'ading team at http://www.pgdp.net\r\n\r\n\r\n\r',
#  'ng team at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n',
#  'team at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r',
#  'm at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n',
#  't http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r',
#  'ttp://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n t',
#  '://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the ',
#  'www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the ill',
#  '.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illust',
#  'dp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrat',
#  'net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated ',
#  '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated chi',
#  '\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated childr',
#  "\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated children'",
#  "\n\r\n\r\n\r\n\r\n\r\n the illustrated children's l",
#  "\r\n\r\n\r\n\r\n the illustrated children's libr",
#  "\n\r\n\r\n the illustrated children's library",
#  "\r\n the illustrated children's library\r\n\r",
#  "the illustrated children's library\r\n\r\n\r\n",
#  " illustrated children's library\r\n\r\n\r\n   ",
#  "lustrated children's library\r\n\r\n\r\n      ",
#  "trated children's library\r\n\r\n\r\n         ",
#  "ted children's library\r\n\r\n\r\n         _tr",
#  " children's library\r\n\r\n\r\n         _treas",
#  "ildren's library\r\n\r\n\r\n         _treasure",
#  "ren's library\r\n\r\n\r\n         _treasure is",
#  "'s library\r\n\r\n\r\n         _treasure islan",
#  'library\r\n\r\n\r\n         _treasure island_\r',
#  'rary\r\n\r\n\r\n         _treasure island_\r\n\r\n',
#  'y\r\n\r\n\r\n         _treasure island_\r\n\r\n   ',
#  '\r\n\r\n         _treasure island_\r\n\r\n      ',
#  '\n         _treasure island_\r\n\r\n       ro',
#  '       _treasure island_\r\n\r\n       rober',
#  '    _treasure island_\r\n\r\n       robert l',
#  ' _treasure island_\r\n\r\n       robert loui',
#  'reasure island_\r\n\r\n       robert louis s',
#  'sure island_\r\n\r\n       robert louis stev',
#  'e island_\r\n\r\n       robert louis stevens',
#  'sland_\r\n\r\n       robert louis stevenson\r',
#  'nd_\r\n\r\n       robert louis stevenson\r\n\r\n',
#  '\r\n\r\n       robert louis stevenson\r\n\r\n   ',
#  '\n       robert louis stevenson\r\n\r\n      ',
#  '     robert louis stevenson\r\n\r\n         ',
#  '  robert louis stevenson\r\n\r\n          _i',
#  'obert louis stevenson\r\n\r\n          _illu',
#  'rt louis stevenson\r\n\r\n          _illustr',
#  'louis stevenson\r\n\r\n          _illustrate',
#  'is stevenson\r\n\r\n          _illustrated b',
#  'stevenson\r\n\r\n          _illustrated by_\r',
#  'venson\r\n\r\n          _illustrated by_\r\n  ',
#  'son\r\n\r\n          _illustrated by_\r\n     ',
#  '\r\n\r\n          _illustrated by_\r\n        ',
#  '\n          _illustrated by_\r\n           ',
#  '        _illustrated by_\r\n            mi',
#  '     _illustrated by_\r\n            milo ',
#  '  _illustrated by_\r\n            milo win',
#  'illustrated by_\r\n            milo winter',
#  'ustrated by_\r\n            milo winter\r\n\r',
#  'rated by_\r\n            milo winter\r\n\r\n\r\n',
#  'ed by_\r\n            milo winter\r\n\r\n\r\n   ',
#  'by_\r\n            milo winter\r\n\r\n\r\n      ',
#  '\r\n            milo winter\r\n\r\n\r\n         ',
#  '           milo winter\r\n\r\n\r\n           [',
#  '        milo winter\r\n\r\n\r\n           [ill',
#  '     milo winter\r\n\r\n\r\n           [illust',
#  '  milo winter\r\n\r\n\r\n           [illustrat',
#  'ilo winter\r\n\r\n\r\n           [illustration',
#  ' winter\r\n\r\n\r\n           [illustration]\r\n',
#  'nter\r\n\r\n\r\n           [illustration]\r\n\r\n\r',
#  'r\r\n\r\n\r\n           [illustration]\r\n\r\n\r\n  ',
#  '\r\n\r\n           [illustration]\r\n\r\n\r\n     ',
#  '\n           [illustration]\r\n\r\n\r\n        ',
#  '         [illustration]\r\n\r\n\r\n           ',
#  '      [illustration]\r\n\r\n\r\n           gra',
#  '   [illustration]\r\n\r\n\r\n           gramer',
#  '[illustration]\r\n\r\n\r\n           gramercy ',
#  'lustration]\r\n\r\n\r\n           gramercy boo',
#  'tration]\r\n\r\n\r\n           gramercy books\r',
#  'tion]\r\n\r\n\r\n           gramercy books\r\n  ',
#  'n]\r\n\r\n\r\n           gramercy books\r\n     ',
#  '\n\r\n\r\n           gramercy books\r\n        ',
#  '\r\n           gramercy books\r\n           ',
#  '          gramercy books\r\n              ',
#  '       gramercy books\r\n              new',
#  '    gramercy books\r\n              new yo',
#  ' gramercy books\r\n              new york\r',
#  'amercy books\r\n              new york\r\n\r\n',
#  'rcy books\r\n              new york\r\n\r\n\r\n\r',
#  ' books\r\n              new york\r\n\r\n\r\n\r\n\r\n',
#  'oks\r\n              new york\r\n\r\n\r\n\r\n\r\n fo',
#  '\r\n              new york\r\n\r\n\r\n\r\n\r\n forew',
#  '             new york\r\n\r\n\r\n\r\n\r\n foreword',
#  '          new york\r\n\r\n\r\n\r\n\r\n foreword co',
#  '       new york\r\n\r\n\r\n\r\n\r\n foreword copyr',
#  '    new york\r\n\r\n\r\n\r\n\r\n foreword copyrigh',
#  ' new york\r\n\r\n\r\n\r\n\r\n foreword copyright  ',
#  'w york\r\n\r\n\r\n\r\n\r\n foreword copyright  198',
#  'ork\r\n\r\n\r\n\r\n\r\n foreword copyright  1986 b',
#  '\r\n\r\n\r\n\r\n\r\n foreword copyright  1986 by r',
#  '\n\r\n\r\n\r\n foreword copyright  1986 by rand',
#  '\r\n\r\n foreword copyright  1986 by random ',
#  '\n foreword copyright  1986 by random hou',
#  'oreword copyright  1986 by random house ',
#  'word copyright  1986 by random house val',
#  'd copyright  1986 by random house value ',
#  'opyright  1986 by random house value pub',
#  'right  1986 by random house value publis',
#  'ht  1986 by random house value publishin',
#  ' 1986 by random house value publishing\r\n',
#  '86 by random house value publishing\r\n co',
#  'by random house value publishing\r\n color',
#  'random house value publishing\r\n color il',
#  'dom house value publishing\r\n color illus',
#  ' house value publishing\r\n color illustra',
#  'use value publishing\r\n color illustratio',
#  ' value publishing\r\n color illustrations ',
#  'lue publishing\r\n color illustrations by ',
#  ' publishing\r\n color illustrations by mil',
#  'blishing\r\n color illustrations by milo w',
#  'shing\r\n color illustrations by milo wint',
#  'ng\r\n color illustrations by milo winter ',
#  '\n color illustrations by milo winter cop',
#  'olor illustrations by milo winter copyri',
#  'r illustrations by milo winter copyright',
#  'llustrations by milo winter copyright  1',
#  'strations by milo winter copyright  1915',
#  'ations by milo winter copyright  1915, 1',
#  'ons by milo winter copyright  1915, 1943',
#  ' by milo winter copyright  1915, 1943 by',
#  ' milo winter copyright  1915, 1943 by ra',
#  'lo winter copyright  1915, 1943 by rand\r',
#  'winter copyright  1915, 1943 by rand\r\n m',
#  'ter copyright  1915, 1943 by rand\r\n mcna',
#  ' copyright  1915, 1943 by rand\r\n mcnally',
#  'pyright  1915, 1943 by rand\r\n mcnally & ',
#  'ight  1915, 1943 by rand\r\n mcnally & com',
#  't  1915, 1943 by rand\r\n mcnally & compan',
#  '1915, 1943 by rand\r\n mcnally & company\r\n',
#  '5, 1943 by rand\r\n mcnally & company\r\n al',
#  '1943 by rand\r\n mcnally & company\r\n all r',
#  '3 by rand\r\n mcnally & company\r\n all righ',
#  'y rand\r\n mcnally & company\r\n all rights ',
#  'and\r\n mcnally & company\r\n all rights res',
#  '\r\n mcnally & company\r\n all rights reserv',
#  'mcnally & company\r\n all rights reserved.',
#  'ally & company\r\n all rights reserved.\r\n\r',
#  'y & company\r\n all rights reserved.\r\n\r\n t',
#  ' company\r\n all rights reserved.\r\n\r\n this',
#  'mpany\r\n all rights reserved.\r\n\r\n this 20',
#  'ny\r\n all rights reserved.\r\n\r\n this 2002 ',
#  '\n all rights reserved.\r\n\r\n this 2002 edi',
#  'll rights reserved.\r\n\r\n this 2002 editio',
#  'rights reserved.\r\n\r\n this 2002 edition p',
#  'hts reserved.\r\n\r\n this 2002 edition publ',
#  ' reserved.\r\n\r\n this 2002 edition publish',
#  'served.\r\n\r\n this 2002 edition published ',
#  'ved.\r\n\r\n this 2002 edition published by ',
#  '.\r\n\r\n this 2002 edition published by gra',
#  '\r\n this 2002 edition published by gramer',
#  'this 2002 edition published by gramercy ',
#  's 2002 edition published by gramercy boo',
#  '002 edition published by gramercy books,',
#  ' edition published by gramercy books, an',
#  'ition published by gramercy books, an im',
#  'on published by gramercy books, an impri',
#  'published by gramercy books, an imprint ',
#  'lished by gramercy books, an imprint of ',
#  'hed by gramercy books, an imprint of ran',
#  ' by gramercy books, an imprint of random',
#  ' gramercy books, an imprint of random\r\n ',
#  'amercy books, an imprint of random\r\n hou',
#  'rcy books, an imprint of random\r\n house ',
#  ' books, an imprint of random\r\n house val',
#  'oks, an imprint of random\r\n house value ',
#  ', an imprint of random\r\n house value pub',
#  'n imprint of random\r\n house value publis',
#  'mprint of random\r\n house value publishin',
#  'int of random\r\n house value publishing, ',
#  ' of random\r\n house value publishing, a d',
#  ' random\r\n house value publishing, a divi',
#  'ndom\r\n house value publishing, a divisio',
#  'm\r\n house value publishing, a division o',
#  ' house value publishing, a division of r',
#  'use value publishing, a division of rand',
#  ' value publishing, a division of random ',
#  'lue publishing, a division of random hou',
#  ' publishing, a division of random house,',
#  'blishing, a division of random house, in',
#  'shing, a division of random house, inc.,',
#  'ng, a division of random house, inc., 28',
#  ' a division of random house, inc., 280 p',
#  'division of random house, inc., 280 park',
#  'ision of random house, inc., 280 park\r\n ',
#  'on of random house, inc., 280 park\r\n ave',
#  'of random house, inc., 280 park\r\n avenue',
#  'random house, inc., 280 park\r\n avenue, n',
#  'dom house, inc., 280 park\r\n avenue, new ',
#  ' house, inc., 280 park\r\n avenue, new yor',
#  'use, inc., 280 park\r\n avenue, new york, ',
#  ', inc., 280 park\r\n avenue, new york, ny ',
#  'nc., 280 park\r\n avenue, new york, ny 100',
#  ', 280 park\r\n avenue, new york, ny 10017.',
#  '80 park\r\n avenue, new york, ny 10017.\r\n\r',
#  'park\r\n avenue, new york, ny 10017.\r\n\r\n g',
#  'k\r\n avenue, new york, ny 10017.\r\n\r\n gram',
#  ' avenue, new york, ny 10017.\r\n\r\n gramerc',
#  'enue, new york, ny 10017.\r\n\r\n gramercy i',
#  'e, new york, ny 10017.\r\n\r\n gramercy is a',
#  'new york, ny 10017.\r\n\r\n gramercy is a re',
#  ' york, ny 10017.\r\n\r\n gramercy is a regis',
#  'rk, ny 10017.\r\n\r\n gramercy is a register',
#  ' ny 10017.\r\n\r\n gramercy is a registered ',
#  ' 10017.\r\n\r\n gramercy is a registered tra',
#  '017.\r\n\r\n gramercy is a registered tradem',
#  '.\r\n\r\n gramercy is a registered trademark',
#  '\r\n gramercy is a registered trademark an',
#  'gramercy is a registered trademark and t',
#  'mercy is a registered trademark and the ',
#  'cy is a registered trademark and the col',
#  'is a registered trademark and the coloph',
#  'a registered trademark and the colophon ',
#  'egistered trademark and the colophon is ',
#  'stered trademark and the colophon is a t',
#  'red trademark and the colophon is a trad',
#  ' trademark and the colophon is a tradema',
#  'ademark and the colophon is a trademark ',
#  'mark and the colophon is a trademark of\r',
#  'k and the colophon is a trademark of\r\n r',
#  'nd the colophon is a trademark of\r\n rand',
#  'the colophon is a trademark of\r\n random ',
#  ' colophon is a trademark of\r\n random hou',
#  'lophon is a trademark of\r\n random house,',
#  'hon is a trademark of\r\n random house, in',
#  ' is a trademark of\r\n random house, inc.\r',
#  ' a trademark of\r\n random house, inc.\r\n\r\n',
#  'trademark of\r\n random house, inc.\r\n\r\n pr',
#  'demark of\r\n random house, inc.\r\n\r\n print',
#  'ark of\r\n random house, inc.\r\n\r\n printed ',
#  ' of\r\n random house, inc.\r\n\r\n printed and',
#  '\r\n random house, inc.\r\n\r\n printed and bo',
#  'random house, inc.\r\n\r\n printed and bound',
#  'dom house, inc.\r\n\r\n printed and bound in',
#  ' house, inc.\r\n\r\n printed and bound in th',
#  'use, inc.\r\n\r\n printed and bound in the u',
#  ', inc.\r\n\r\n printed and bound in the unit',
#  'nc.\r\n\r\n printed and bound in the united ',
#  '\r\n\r\n printed and bound in the united sta',
#  '\n printed and bound in the united states',
#  'rinted and bound in the united states of',
#  'ted and bound in the united states of am',
#  ' and bound in the united states of ameri',
#  'd bound in the united states of america\r',
#  'ound in the united states of america\r\n\r\n',
#  'd in the united states of america\r\n\r\n co',
#  'n the united states of america\r\n\r\n cover',
#  'he united states of america\r\n\r\n cover de',
#  'united states of america\r\n\r\n cover desig',
#  'ted states of america\r\n\r\n cover design b',
#  ' states of america\r\n\r\n cover design by j',
#  'ates of america\r\n\r\n cover design by judy',
#  's of america\r\n\r\n cover design by judy fu',
#  'f america\r\n\r\n cover design by judy fucci',
#  'merica\r\n\r\n cover design by judy fucci, s',
#  'ica\r\n\r\n cover design by judy fucci, stud',
#  '\r\n\r\n cover design by judy fucci, studio ',
#  '\n cover design by judy fucci, studio gra',
#  'over design by judy fucci, studio graphi',
#  'r design by judy fucci, studio graphix, ',
#  'esign by judy fucci, studio graphix, inc',
#  'gn by judy fucci, studio graphix, inc.\r\n',
#  'by judy fucci, studio graphix, inc.\r\n\r\n ',
#  'judy fucci, studio graphix, inc.\r\n\r\n ran',
#  'y fucci, studio graphix, inc.\r\n\r\n random',
#  'ucci, studio graphix, inc.\r\n\r\n random ho',
#  'i, studio graphix, inc.\r\n\r\n random house',
#  'studio graphix, inc.\r\n\r\n random house\r\n ',
#  'dio graphix, inc.\r\n\r\n random house\r\n new',
#  ' graphix, inc.\r\n\r\n random house\r\n new yo',
#  'aphix, inc.\r\n\r\n random house\r\n new york ',
#  'ix, inc.\r\n\r\n random house\r\n new york  to',
#  ' inc.\r\n\r\n random house\r\n new york  toron',
#  'c.\r\n\r\n random house\r\n new york  toronto ',
#  '\n\r\n random house\r\n new york  toronto  lo',
#  ' random house\r\n new york  toronto  londo',
#  'ndom house\r\n new york  toronto  london  ',
#  'm house\r\n new york  toronto  london  syd',
#  'ouse\r\n new york  toronto  london  sydney',
#  'e\r\n new york  toronto  london  sydney  a',
#  ' new york  toronto  london  sydney  auck',
#  'w york  toronto  london  sydney  aucklan',
#  'ork  toronto  london  sydney  auckland\r\n',
#  '  toronto  london  sydney  auckland\r\n ww',
#  'oronto  london  sydney  auckland\r\n www.r',
#  'nto  london  sydney  auckland\r\n www.rand',
#  '  london  sydney  auckland\r\n www.randomh',
#  'ondon  sydney  auckland\r\n www.randomhous',
#  'on  sydney  auckland\r\n www.randomhouse.c',
#  ' sydney  auckland\r\n www.randomhouse.com\r',
#  'dney  auckland\r\n www.randomhouse.com\r\n\r\n',
#  'y  auckland\r\n www.randomhouse.com\r\n\r\n\r\n ',
#  'auckland\r\n www.randomhouse.com\r\n\r\n\r\n lib',
#  'kland\r\n www.randomhouse.com\r\n\r\n\r\n librar',
#  'nd\r\n www.randomhouse.com\r\n\r\n\r\n library o',
#  '\n www.randomhouse.com\r\n\r\n\r\n library of c',
#  'ww.randomhouse.com\r\n\r\n\r\n library of cong',
#  'randomhouse.com\r\n\r\n\r\n library of congres',
#  'domhouse.com\r\n\r\n\r\n library of congress c',
#  'house.com\r\n\r\n\r\n library of congress cata',
#  'se.com\r\n\r\n\r\n library of congress catalog',
#  'com\r\n\r\n\r\n library of congress cataloging',
#  '\r\n\r\n\r\n library of congress cataloging-in',
#  '\n\r\n library of congress cataloging-in-pu',
#  ' library of congress cataloging-in-publi',
#  'brary of congress cataloging-in-publicat',
#  'ry of congress cataloging-in-publication',
#  'of congress cataloging-in-publication da',
#  'congress cataloging-in-publication data\r',
#  'gress cataloging-in-publication data\r\n\r\n',
#  'ss cataloging-in-publication data\r\n\r\n st',
#  'cataloging-in-publication data\r\n\r\n steve',
#  'aloging-in-publication data\r\n\r\n stevenso',
#  'ging-in-publication data\r\n\r\n stevenson, ',
#  'g-in-publication data\r\n\r\n stevenson, rob',
#  'n-publication data\r\n\r\n stevenson, robert',
#  'ublication data\r\n\r\n stevenson, robert lo',
#  'ication data\r\n\r\n stevenson, robert louis',
#  'tion data\r\n\r\n stevenson, robert louis, 1',
#  'n data\r\n\r\n stevenson, robert louis, 1850',
#  'ata\r\n\r\n stevenson, robert louis, 1850-18',
#  '\r\n\r\n stevenson, robert louis, 1850-1894.',
#  '\n stevenson, robert louis, 1850-1894.\r\n ',
#  'tevenson, robert louis, 1850-1894.\r\n    ',
#  'enson, robert louis, 1850-1894.\r\n     tr',
#  'on, robert louis, 1850-1894.\r\n     treas',
#  ' robert louis, 1850-1894.\r\n     treasure',
#  'bert louis, 1850-1894.\r\n     treasure is',
#  't louis, 1850-1894.\r\n     treasure islan',
#  'ouis, 1850-1894.\r\n     treasure island/r',
#  's, 1850-1894.\r\n     treasure island/robe',
#  '1850-1894.\r\n     treasure island/robert ',
#  '0-1894.\r\n     treasure island/robert lou',
#  '894.\r\n     treasure island/robert louis ',
#  '.\r\n     treasure island/robert louis ste',
#  '     treasure island/robert louis steven',
#  '  treasure island/robert louis stevenson',
#  'reasure island/robert louis stevenson; i',
#  'sure island/robert louis stevenson; illu',
#  'e island/robert louis stevenson; illustr',
#  'sland/robert louis stevenson; illustrate',
#  'nd/robert louis stevenson; illustrated i',
#  'robert louis stevenson; illustrated in c',
#  'ert louis stevenson; illustrated in colo',
#  ' louis stevenson; illustrated in color b',
#  'uis stevenson; illustrated in color by\r\n',
#  ' stevenson; illustrated in color by\r\n   ',
#  'evenson; illustrated in color by\r\n   mil',
#  'nson; illustrated in color by\r\n   milo w',
#  'n; illustrated in color by\r\n   milo wint',
#  'illustrated in color by\r\n   milo winter.',
#  'ustrated in color by\r\n   milo winter.\r\n ',
#  'rated in color by\r\n   milo winter.\r\n    ',
#  'ed in color by\r\n   milo winter.\r\n       ',
#  'in color by\r\n   milo winter.\r\n       p. ',
#  'color by\r\n   milo winter.\r\n       p. cm.',
#  'or by\r\n   milo winter.\r\n       p. cm.--(',
#  'by\r\n   milo winter.\r\n       p. cm.--(ill',
#  '\n   milo winter.\r\n       p. cm.--(illust',
#  ' milo winter.\r\n       p. cm.--(illustrat',
#  'lo winter.\r\n       p. cm.--(illustrated ',
#  'winter.\r\n       p. cm.--(illustrated chi',
#  'ter.\r\n       p. cm.--(illustrated childr',
#  ".\r\n       p. cm.--(illustrated children'",
#  "       p. cm.--(illustrated children's l",
#  "    p. cm.--(illustrated children's libr",
#  " p. cm.--(illustrated children's library",
#  " cm.--(illustrated children's library)\r\n",
#  ".--(illustrated children's library)\r\n   ",
#  "(illustrated children's library)\r\n     o",
#  "lustrated children's library)\r\n     orig",
#  "trated children's library)\r\n     origina",
#  "ted children's library)\r\n     originally",
#  " children's library)\r\n     originally pu",
#  "ildren's library)\r\n     originally publi",
#  "ren's library)\r\n     originally publishe",
#  "'s library)\r\n     originally published: ",
#  'library)\r\n     originally published: new',
#  'rary)\r\n     originally published: new yo',
#  'y)\r\n     originally published: new york:',
#  '\n     originally published: new york: ch',
#  '   originally published: new york: child',
#  'originally published: new york: children',
#  "ginally published: new york: children's ",
#  "ally published: new york: children's cla",
#  "y published: new york: children's classi",
#  "ublished: new york: children's classics,",
#  "ished: new york: children's classics, 19",
#  "ed: new york: children's classics, 1986.",
#  " new york: children's classics, 1986.\r\n ",
#  "w york: children's classics, 1986.\r\n    ",
#  "ork: children's classics, 1986.\r\n     su",
#  ": children's classics, 1986.\r\n     summa",
#  "hildren's classics, 1986.\r\n     summary:",
#  "dren's classics, 1986.\r\n     summary: wh",
#  "n's classics, 1986.\r\n     summary: while",
#  ' classics, 1986.\r\n     summary: while go',
#  'assics, 1986.\r\n     summary: while going',
#  'ics, 1986.\r\n     summary: while going th',
#  ', 1986.\r\n     summary: while going throu',
#  '986.\r\n     summary: while going through ',
#  '.\r\n     summary: while going through the',
#  '     summary: while going through the po',
#  '  summary: while going through the posse',
#  'ummary: while going through the possessi',
#  'ary: while going through the possessions',
#  ': while going through the possessions of',
#  'hile going through the possessions of a ',
#  'e going through the possessions of a dec',
#  'oing through the possessions of a deceas',
#  'g through the possessions of a deceased ',
#  'hrough the possessions of a deceased gue',
#  'ugh the possessions of a deceased guest\r',
#  ' the possessions of a deceased guest\r\n  ',
#  'e possessions of a deceased guest\r\n   wh',
#  'ossessions of a deceased guest\r\n   who o',
#  'essions of a deceased guest\r\n   who owed',
#  'ions of a deceased guest\r\n   who owed th',
#  's of a deceased guest\r\n   who owed them ',
#  'f a deceased guest\r\n   who owed them mon',
#  ' deceased guest\r\n   who owed them money,',
#  'ceased guest\r\n   who owed them money, th',
#  'sed guest\r\n   who owed them money, the m',
#  ' guest\r\n   who owed them money, the mist',
#  'est\r\n   who owed them money, the mistres',
#  '\r\n   who owed them money, the mistress o',
#  '  who owed them money, the mistress of t',
#  'ho owed them money, the mistress of the ',
#  'owed them money, the mistress of the inn',
#  'd them money, the mistress of the inn an',
#  'hem money, the mistress of the inn and h',
#  ' money, the mistress of the inn and her ',
#  'ney, the mistress of the inn and her son',
#  ', the mistress of the inn and her son fi',
#  'he mistress of the inn and her son find ',
#  'mistress of the inn and her son find a\r\n',
#  'tress of the inn and her son find a\r\n   ',
#  'ss of the inn and her son find a\r\n   tre',
#  'of the inn and her son find a\r\n   treasu',
#  'the inn and her son find a\r\n   treasure ',
#  ' inn and her son find a\r\n   treasure map',
#  'n and her son find a\r\n   treasure map th',
#  'nd her son find a\r\n   treasure map that ',
#  'her son find a\r\n   treasure map that lea',
#  ' son find a\r\n   treasure map that leads ',
#  'n find a\r\n   treasure map that leads the',
#  'ind a\r\n   treasure map that leads them t',
#  ' a\r\n   treasure map that leads them to a',
#  '\n   treasure map that leads them to a pi',
#  ' treasure map that leads them to a pirat',
#  "easure map that leads them to a pirate's",
#  "ure map that leads them to a pirate's fo",
#  " map that leads them to a pirate's fortu",
#  "p that leads them to a pirate's fortune.",
#  "hat leads them to a pirate's fortune.\r\n ",
#  " leads them to a pirate's fortune.\r\n    ",
#  "ads them to a pirate's fortune.\r\n     is",
#  " them to a pirate's fortune.\r\n     isbn ",
#  "em to a pirate's fortune.\r\n     isbn 0-5",
#  "to a pirate's fortune.\r\n     isbn 0-517-",
#  "a pirate's fortune.\r\n     isbn 0-517-221",
#  "irate's fortune.\r\n     isbn 0-517-22114-",
#  "te's fortune.\r\n     isbn 0-517-22114-4\r\n",
#  's fortune.\r\n     isbn 0-517-22114-4\r\n   ',
#  'ortune.\r\n     isbn 0-517-22114-4\r\n     [',
#  'une.\r\n     isbn 0-517-22114-4\r\n     [1. ',
#  '.\r\n     isbn 0-517-22114-4\r\n     [1. bur',
#  '     isbn 0-517-22114-4\r\n     [1. buried',
#  '  isbn 0-517-22114-4\r\n     [1. buried tr',
#  'sbn 0-517-22114-4\r\n     [1. buried treas',
#  ' 0-517-22114-4\r\n     [1. buried treasure',
#  '517-22114-4\r\n     [1. buried treasure--f',
#  '-22114-4\r\n     [1. buried treasure--fict',
#  '114-4\r\n     [1. buried treasure--fiction',
#  '-4\r\n     [1. buried treasure--fiction. 2',
#  '\n     [1. buried treasure--fiction. 2. p',
#  '   [1. buried treasure--fiction. 2. pira',
#  '[1. buried treasure--fiction. 2. pirates',
#  ' buried treasure--fiction. 2. pirates--f',
#  'ried treasure--fiction. 2. pirates--fict',
#  'd treasure--fiction. 2. pirates--fiction',
#  'reasure--fiction. 2. pirates--fiction. 3',
#  'sure--fiction. 2. pirates--fiction. 3. a',
#  'e--fiction. 2. pirates--fiction. 3. adve',
#  'fiction. 2. pirates--fiction. 3. adventu',
#  'tion. 2. pirates--fiction. 3. adventure\r',
#  'n. 2. pirates--fiction. 3. adventure\r\n  ',
#  '2. pirates--fiction. 3. adventure\r\n   an',
#  'pirates--fiction. 3. adventure\r\n   and a',
#  'ates--fiction. 3. adventure\r\n   and adve',
#  's--fiction. 3. adventure\r\n   and adventu',
#  'fiction. 3. adventure\r\n   and adventures',
#  'tion. 3. adventure\r\n   and adventures--f',
#  'n. 3. adventure\r\n   and adventures--fict',
#  '3. adventure\r\n   and adventures--fiction',
#  'adventure\r\n   and adventures--fiction. 4',
#  'enture\r\n   and adventures--fiction. 4. c',
#  'ure\r\n   and adventures--fiction. 4. cari',
#  '\r\n   and adventures--fiction. 4. caribbe',
#  '  and adventures--fiction. 4. caribbean ',
#  'nd adventures--fiction. 4. caribbean are',
#  'adventures--fiction. 4. caribbean area--',
#  'entures--fiction. 4. caribbean area--his',
#  'ures--fiction. 4. caribbean area--histor',
#  's--fiction. 4. caribbean area--history--',
#  'fiction. 4. caribbean area--history--18t',
#  'tion. 4. caribbean area--history--18th\r\n',
#  'n. 4. caribbean area--history--18th\r\n   ',
#  '4. caribbean area--history--18th\r\n   cen',
#  'caribbean area--history--18th\r\n   centur',
#  'ibbean area--history--18th\r\n   century--',
#  'ean area--history--18th\r\n   century--fic',
#  ' area--history--18th\r\n   century--fictio',
#  'ea--history--18th\r\n   century--fiction.]',
#  '-history--18th\r\n   century--fiction.] i.',
#  'story--18th\r\n   century--fiction.] i. wi',
#  'ry--18th\r\n   century--fiction.] i. winte',
#  '-18th\r\n   century--fiction.] i. winter, ',
#  'th\r\n   century--fiction.] i. winter, mil',
#  '\n   century--fiction.] i. winter, milo, ',
#  ' century--fiction.] i. winter, milo, 188',
#  'ntury--fiction.] i. winter, milo, 1888-1',
#  'ry--fiction.] i. winter, milo, 1888-1956',
#  '-fiction.] i. winter, milo, 1888-1956, i',
#  'ction.] i. winter, milo, 1888-1956, ill.',
#  'on.] i. winter, milo, 1888-1956, ill. ii',
#  '] i. winter, milo, 1888-1956, ill. ii. t',
#  '. winter, milo, 1888-1956, ill. ii. titl',
#  'inter, milo, 1888-1956, ill. ii. title.\r',
#  'er, milo, 1888-1956, ill. ii. title.\r\n  ',
#  ' milo, 1888-1956, ill. ii. title.\r\n   ii',
#  'lo, 1888-1956, ill. ii. title.\r\n   iii. ',
#  ' 1888-1956, ill. ii. title.\r\n   iii. ser',
#  '88-1956, ill. ii. title.\r\n   iii. series',
#  '1956, ill. ii. title.\r\n   iii. series.\r\n',
#  '6, ill. ii. title.\r\n   iii. series.\r\n\r\n ',
#  'ill. ii. title.\r\n   iii. series.\r\n\r\n   p',
#  '. ii. title.\r\n   iii. series.\r\n\r\n   pz7.',
#  'i. title.\r\n   iii. series.\r\n\r\n   pz7.s84',
#  'title.\r\n   iii. series.\r\n\r\n   pz7.s8482 ',
#  'le.\r\n   iii. series.\r\n\r\n   pz7.s8482 tr ',
#  '\r\n   iii. series.\r\n\r\n   pz7.s8482 tr 200',
#  '  iii. series.\r\n\r\n   pz7.s8482 tr 2002\r\n',
#  'ii. series.\r\n\r\n   pz7.s8482 tr 2002\r\n   ',
#  ' series.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fi',
#  'ries.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fic]-',
#  's.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fic]--dc',
#  '\n\r\n   pz7.s8482 tr 2002\r\n   [fic]--dc21\r',
#  '   pz7.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n',
#  'pz7.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n   ',
#  '.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n      ',
#  '482 tr 2002\r\n   [fic]--dc21\r\n\r\n         ',
#  ' tr 2002\r\n   [fic]--dc21\r\n\r\n            ',
#  ' 2002\r\n   [fic]--dc21\r\n\r\n               ',
#  '02\r\n   [fic]--dc21\r\n\r\n                  ',
#  '\n   [fic]--dc21\r\n\r\n                     ',
#  ' [fic]--dc21\r\n\r\n                        ',
#  'ic]--dc21\r\n\r\n                           ',
#  '--dc21\r\n\r\n                              ',
#  'c21\r\n\r\n                                 ',
#  '\r\n\r\n                                    ',
#  '\n                                       ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                       2',
#  '                                    2002',
#  '                                 2002023',
#  '                              2002023301',
#  '                           2002023301\r\n ',
#  '                        2002023301\r\n 9 8',
#  '                     2002023301\r\n 9 8 7 ',
#  '                  2002023301\r\n 9 8 7 6 5',
#  '               2002023301\r\n 9 8 7 6 5 4 ',
#  '            2002023301\r\n 9 8 7 6 5 4 3 2',
#  '         2002023301\r\n 9 8 7 6 5 4 3 2 1\r',
#  '      2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n',
#  '   2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\nt',
#  '2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntran',
#  '2023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscr',
#  '3301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscribe',
#  "1\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's",
#  " 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's no",
#  "8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's note:",
#  " 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r",
#  "5 4 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n  ",
#  " 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n    m",
#  "2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n    mino",
#  "\r\n\r\n\r\ntranscriber's note:\r\n\r\n    minor s",
#  "\n\r\ntranscriber's note:\r\n\r\n    minor spel",
#  "transcriber's note:\r\n\r\n    minor spellin",
#  "nscriber's note:\r\n\r\n    minor spelling a",
#  "riber's note:\r\n\r\n    minor spelling and ",
#  "er's note:\r\n\r\n    minor spelling and typ",
#  's note:\r\n\r\n    minor spelling and typogr',
#  'ote:\r\n\r\n    minor spelling and typograph',
#  ':\r\n\r\n    minor spelling and typographica',
#  '\r\n    minor spelling and typographical e',
#  '   minor spelling and typographical erro',
#  'minor spelling and typographical errors ',
#  'or spelling and typographical errors hav',
#  'spelling and typographical errors have b',
#  'lling and typographical errors have been',
#  'ng and typographical errors have been co',
#  'and typographical errors have been corre',
#  ' typographical errors have been correcte',
#  'pographical errors have been corrected w',
#  'raphical errors have been corrected with',
#  'hical errors have been corrected without',
#  'al errors have been corrected without\r\n ',
#  'errors have been corrected without\r\n    ',
#  'ors have been corrected without\r\n    not',
#  ' have been corrected without\r\n    note. ',
#  've been corrected without\r\n    note. dia',
#  'been corrected without\r\n    note. dialec',
#  'n corrected without\r\n    note. dialect a',
#  'orrected without\r\n    note. dialect and ',
#  'ected without\r\n    note. dialect and var',
#  'ed without\r\n    note. dialect and varian',
#  'without\r\n    note. dialect and variant s',
#  'hout\r\n    note. dialect and variant spel',
#  't\r\n    note. dialect and variant spellin',
#  '    note. dialect and variant spellings ',
#  ' note. dialect and variant spellings hav',
#  'te. dialect and variant spellings have b',
#  ' dialect and variant spellings have been',
#  'alect and variant spellings have been re',
#  'ct and variant spellings have been retai',
#  'and variant spellings have been retained',
#  ' variant spellings have been retained, w',
#  'riant spellings have been retained, whil',
#  'nt spellings have been retained, whilst\r',
#  'spellings have been retained, whilst\r\n  ',
#  'llings have been retained, whilst\r\n    i',
#  'ngs have been retained, whilst\r\n    inco',
#  ' have been retained, whilst\r\n    inconsi',
#  've been retained, whilst\r\n    inconsiste',
#  'been retained, whilst\r\n    inconsistent ',
#  'n retained, whilst\r\n    inconsistent hyp',
#  'etained, whilst\r\n    inconsistent hyphen',
#  'ined, whilst\r\n    inconsistent hyphenati',
#  'd, whilst\r\n    inconsistent hyphenation ',
#  'whilst\r\n    inconsistent hyphenation has',
#  'lst\r\n    inconsistent hyphenation has be',
#  '\r\n    inconsistent hyphenation has been ',
#  '   inconsistent hyphenation has been sta',
#  'inconsistent hyphenation has been standa',
#  'onsistent hyphenation has been standardi',
#  'istent hyphenation has been standardised',
#  'ent hyphenation has been standardised. c',
#  ' hyphenation has been standardised. colo',
#  'phenation has been standardised. color p',
#  'nation has been standardised. color plat',
#  'ion has been standardised. color plates ',
#  ' has been standardised. color plates hav',
#  's been standardised. color plates have\r\n',
#  'een standardised. color plates have\r\n   ',
#  ' standardised. color plates have\r\n    be',
#  'andardised. color plates have\r\n    been ',
#  'ardised. color plates have\r\n    been rep',
#  'ised. color plates have\r\n    been reposi',
#  'd. color plates have\r\n    been repositio',
#  'color plates have\r\n    been repositioned',
#  'or plates have\r\n    been repositioned ac',
#  'plates have\r\n    been repositioned accor',
#  'tes have\r\n    been repositioned accordin',
#  ' have\r\n    been repositioned according t',
#  've\r\n    been repositioned according to t',
#  '\n    been repositioned according to thei',
#  '  been repositioned according to their c',
#  'een repositioned according to their capt',
#  ' repositioned according to their caption',
#  'positioned according to their captions; ',
#  'itioned according to their captions; the',
#  "oned according to their captions; the 'c",
#  "d according to their captions; the 'colo",
#  "ccording to their captions; the 'color p",
#  "rding to their captions; the 'color plat",
#  "ng to their captions; the 'color plates'",
#  "to their captions; the 'color plates'\r\n ",
#  "their captions; the 'color plates'\r\n    ",
#  "ir captions; the 'color plates'\r\n    lis",
#  "captions; the 'color plates'\r\n    listin",
#  "tions; the 'color plates'\r\n    listing r",
#  "ns; the 'color plates'\r\n    listing rema",
#  " the 'color plates'\r\n    listing remains",
#  "e 'color plates'\r\n    listing remains as",
#  "color plates'\r\n    listing remains as pr",
#  "or plates'\r\n    listing remains as print",
#  "plates'\r\n    listing remains as printed ",
#  "tes'\r\n    listing remains as printed to ",
#  "'\r\n    listing remains as printed to ind",
#  '    listing remains as printed to indica',
#  ' listing remains as printed to indicate ',
#  'sting remains as printed to indicate the',
#  'ng remains as printed to indicate the or',
#  'remains as printed to indicate the origi',
#  'ains as printed to indicate the original',
#  's as printed to indicate the original lo',
#  's printed to indicate the original locat',
#  'rinted to indicate the original location',
#  'ted to indicate the original locations.\r',
#  ' to indicate the original locations.\r\n\r\n',
#  ' indicate the original locations.\r\n\r\n\r\n\r',
#  'dicate the original locations.\r\n\r\n\r\n\r\n\r\n',
#  'ate the original locations.\r\n\r\n\r\n\r\n\r\ncon',
#  ' the original locations.\r\n\r\n\r\n\r\n\r\nconten',
#  'e original locations.\r\n\r\n\r\n\r\n\r\ncontents\r',
#  'riginal locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n',
#  'inal locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n ',
#  'l locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n    ',
#  'ocations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n       ',
#  'tions.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n          ',
#  'ns.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n             ',
#  '\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n                ',
#  '\n\r\n\r\n\r\ncontents\r\n\r\n\r\n                   ',
#  '\r\n\r\ncontents\r\n\r\n\r\n                      ',
#  '\ncontents\r\n\r\n\r\n                         ',
#  'ntents\r\n\r\n\r\n                            ',
#  'nts\r\n\r\n\r\n                               ',
#  '\r\n\r\n\r\n                                  ',
#  '\n\r\n                                     ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                     pag',
#  '                                  page\r\n',
#  '                               page\r\n _t',
#  '                            page\r\n _to t',
#  '                         page\r\n _to the ',
#  '                      page\r\n _to the hes',
#  '                   page\r\n _to the hesita',
#  '                page\r\n _to the hesitatin',
#  '             page\r\n _to the hesitating p',
#  '          page\r\n _to the hesitating purc',
#  '       page\r\n _to the hesitating purchas',
#  '    page\r\n _to the hesitating purchaser_',
#  ' page\r\n _to the hesitating purchaser_   ',
#  'ge\r\n _to the hesitating purchaser_      ',
#  '\n _to the hesitating purchaser_         ',
#  'to the hesitating purchaser_            ',
#  'the hesitating purchaser_               ',
#  ' hesitating purchaser_                  ',
#  'sitating purchaser_                     ',
#  'ating purchaser_                        ',
#  'ng purchaser_                           ',
#  'purchaser_                             _',
#  'chaser_                             _vii',
#  'ser_                             _viii_\r',
#  '_                             _viii_\r\n _',
#  '                           _viii_\r\n _lis',
#  '                        _viii_\r\n _list o',
#  '                     _viii_\r\n _list of c',
#  '                  _viii_\r\n _list of colo',
#  '               _viii_\r\n _list of color p',
#  '            _viii_\r\n _list of color plat',
#  '         _viii_\r\n _list of color plates_',
#  '      _viii_\r\n _list of color plates_   ',
#  '   _viii_\r\n _list of color plates_      ',
#  '_viii_\r\n _list of color plates_         ',
#  'ii_\r\n _list of color plates_            ',
#  '\r\n _list of color plates_               ',
#  '_list of color plates_                  ',
#  'st of color plates_                     ',
#  'of color plates_                        ',
#  'color plates_                           ',
#  'or plates_                              ',
#  ...]

# %% [markdown]
# We can now convert the text into vectors.

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...
# <ipython-input-7-b1fdc504c468>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-7-b1fdc504c468>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# Next, we create the neural network.  This neural network's primary feature is the LSTM layer, which allows the sequences to be processed.

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               96768
#
#  dense (Dense)               (None, 60)                7740
#
# =================================================================
# Total params: 104,508
# Trainable params: 104,508
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The LSTM will produce new text character by character.  We will need to sample the correct letter from the LSTM predictions each time.  The **sample** function accepts the following two parameters:
#
# * **preds** - The output neurons.
# * **temperature** - 1.0 is the most conservative, 0.0 is the most confident (willing to make spelling and other errors).
#
# The sample function below essentially performs a softmax on the neural network predictions.  This process causes each output neuron to become a probability of its particular letter.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Keras calls the following function at the end of each training Epoch.  The code generates sample text generations that visually demonstrate the neural network better at text generation.  As the neural network trains, the generations should look more realistic.

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print("******************************************************")
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(processed_text) - maxlen - 1)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temperature)

        generated = ''
        sentence = processed_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# We are now ready to train.  Depending on how fast your computer is, it can take up to an hour to train this network.  If you have a GPU available, please make sure to use it.

# %%
# Ignore useless W0819 warnings generated by TensorFlow 2.0.  Hopefully can remove this ignore in the future.
# See https://github.com/tensorflow/tensorflow/issues/31308
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 2.0236******************************************************
# ----- Generating text after Epoch: 0
# ----- temperature: 0.2
# ----- Generating with seed: "back the lid in a twinkling.
#
# a strong"
# back the lid in a twinkling.
#
#
# the said the stick and and the start and the start and as a captain of the said the start and the said the start in the start and the stack and a companted and and a companion and see the said that the stood and a stoad the stack and the start and stopped the start and the still
# ----- temperature: 0.5
# ----- Generating with seed: "back the lid in a twinkling.
#
# a strong"
# back the lid in a twinkling.
#
# a strong the suruptiins of the sain that he had beacher heart had pegan the brasse the sturper. the camtain fand the soon the shipse "for the every of the copsponed and it we had ling the stow and the sain had to the fall the captain and ment of the recome about and for the man and all well, should heart what i now be the were for that soon nearting the soon with the corss, and in the stack and we was the
# ----- temperature: 1.0
# ----- Generating with seed: "back the lid in a twinkling.
#
# a strong"
# back the lid in a twinkling.
#
#
#
#
#
#
#
#
#
#
#
# betheck in me fe
# ----- temperature: 1.2
# ----- Generating with seed: "back the lid in a twinkling.
#
# a strong"
# back the lid in a twinkling.
#
#
#
#
#
# detkites-for upon that's verys, whearike ink, wut bellow it!" said all, i that lake shotterminld wast-alonverf
#
#
#
#
# waice for sim,,
# 1035/1035 [==============================] - 84s 75ms/step - loss: 2.0214
# Epoch 2/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.6496******************************************************
# ----- Generating text after Epoch: 1
# ----- temperature: 0.2
# ----- Generating with seed: "rd.
#
# i began after a little to grow ve"
# rd.
#
# i began after a little to grow very the man a chain the more the should the man the man the should the should the man a should the man a chied the should the man a chipper and a chaper the should the man a should the man the land the man the man a chippanted the man and the should the all was the should the man the should the man a little and the man on the should the man the should the storn the man the should the man the should
# ----- temperature: 0.5
# ----- Generating with seed: "rd.
#
# i began after a little to grow ve"
# rd.
#
#
#
#
#
# all in me his padied to the the renterness. the work as a green of the shout the see the shot wome propent to the men ward the deck. nor a countite to be captain to for her supper, drow and the reck, john the most a cutse, and the men a chipage, and we
# ----- temperature: 1.0
# ----- Generating with seed: "rd.
#
# i began after a little to grow ve"
# rd.
#
#
#
#
#
#
#
#
# lecole. he mandly to not exved he, and charot len then half; you were w
# ----- temperature: 1.2
# ----- Generating with seed: "rd.
#
# i began after a little to grow ve"
# rd.
#
#
#
#
#
#
#
#
#  chide. i had thered, youtlawaince donn ben usving some ne gentetted hims. and arm mriel agaved, tot o
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.6496
# Epoch 3/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.5401******************************************************
# ----- Generating text after Epoch: 2
# ----- temperature: 0.2
# ----- Generating with seed: "outed the squire after him.
#
# "ay, ay, "
# outed the squire after him.
#
#
#
# "and the man so the ready on the ship and the stand of the sandy of the stand of the stand of the stand, and the south of the stand of the south and a should see the bersh of the stack of the stack, and the stand of the stand of the stand of the captain. "i sand the same be sound say on the start of the starts, and the stand of the start and a saw and the south of the s
# ----- temperature: 0.5
# ----- Generating with seed: "outed the squire after him.
#
# "ay, ay, "
# outed the squire after him.
#
#
#
#
#
# "now, "were you have cook me th
# ----- temperature: 1.0
# ----- Generating with seed: "outed the squire after him.
#
# "ay, ay, "
# outed the squire after him.
#
#
#
#
#
#
#
#
#
# "the styeake exevesy upon the whole as and was a surmistrance or.
# ----- temperature: 1.2
# ----- Generating with seed: "outed the squire after him.
#
# "ay, ay, "
# outed the squire after him.
#
#
#
#
#
#
#
#
#
#
#
# i deadhure pieccle." rea to bans you that see m
# 1035/1035 [==============================] - 78s 75ms/step - loss: 1.5404
# Epoch 4/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.4788******************************************************
# ----- Generating text after Epoch: 3
# ----- temperature: 0.2
# ----- Generating with seed: "and short and dry, and not a
# word waste"
# and short and dry, and not a
# word wasted of the stockade, and the corner of the ship's ship's shore the ship's side of the ship's a ship's ship's statter a ship's ship's silver, as a ship's ship's silver, sir, and the ship's first the stockade, silver was stold the stockade, and the stockade, and the stockade, the ship's stood the ship's silver, the ship's chered in the ship's stores were the boat, and the stockade, the thought the sto
# ----- temperature: 0.5
# ----- Generating with seed: "and short and dry, and not a
# word waste"
# and short and dry, and not a
#
#
#
#
#
# ----- temperature: 1.0
# ----- Generating with seed: "and short and dry, and not a
# word waste"
# and short and dry, and not a
#
#
#
#
#
#
# fly out we had a    ain welt sart-on partled in chay was clored to lives, awortace, evening fisst of copfaging the stocks was
# ----- temperature: 1.2
# ----- Generating with seed: "and short and dry, and not a
# word waste"
# and short and dry, and not a
#
#
#
#
#
#
#
#
#
#
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.4790
# Epoch 5/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.4357******************************************************
# ----- Generating text after Epoch: 4
# ----- temperature: 0.2
# ----- Generating with seed: "m that first look onward i
# hated the ve"
# m that first look onward i
# hated the very stand the starmed the stockade and the start of the stockade of the stockade of the strong the boat the stockade of the strong the strong the strong the stockade, and and the stare the strong the stockade of the stockade and the strong the strong the start of the strong the stockade, and the stockade, and the stare and the stockade of the stockade and the stockade, and the stockade, and there w
# ----- temperature: 0.5
# ----- Generating with seed: "m that first look onward i
# hated the ve"
# m that first look onward i
#
# by the south was a place the sound the blind of the books, and but and his hands we had all the doctor and and shrough the other our neat off and stood the ship and that last the surseral orse we had leet the sound so his one of the thing ship the boboy, the books and had stalling and the
# ----- temperature: 1.0
# ----- Generating with seed: "m that first look onward i
# hated the ve"
# m that first look onward i
#
#
#
#
#
#
#
#
#
#
#
#
# the aningsimms old from her fullable risellit
# ----- temperature: 1.2
# ----- Generating with seed: "m that first look onward i
# hated the ve"
# m that first look onward i
#
#
#
#
#
#
#
#
#
#     ' reasuen," clier a peay, hoarh o'fape seraa
# 1035/1035 [==============================] - 78s 76ms/step - loss: 1.4357
# Epoch 6/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.4068******************************************************
# ----- Generating text after Epoch: 5
# ----- temperature: 0.2
# ----- Generating with seed: "anything like a prolonged campaign.
#
# e"
# anything like a prolonged campaign.
#
# even the captain and the stornd of the shore, and the captain to the same was the shore of the captain and the same of the sure and the same was the captain and the captain and the coracle and the same by the sound and the same of the captain. i had been a strong the story of the same back to the captain to the shore. then i was the sails the same with the sound the shore, and the shore of the same
# ----- temperature: 0.5
# ----- Generating with seed: "anything like a prolonged campaign.
#
# e"
# anything like a prolonged campaign.
#
#
#
#
# "and then
# ----- temperature: 1.0
# ----- Generating with seed: "anything like a prolonged campaign.
#
# e"
# anything like a prolonged campaign.
#
#
#
#
#
#
#
# bart that had a strofg breach of suck at the close printing was a hot side. cruel had  and whongly you could can for the dure but some
# ----- temperature: 1.2
# ----- Generating with seed: "anything like a prolonged campaign.
#
# e"
# anything like a prolonged campaign.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.4064
# Epoch 7/60
# 1027/1035 [============================>.] - ETA: 0s - loss: 1.3829******************************************************
# ----- Generating text after Epoch: 6
# ----- temperature: 0.2
# ----- Generating with seed: "ndlord.
#
# i plucked up courage at once,"
# ndlord.
#
# i plucked up courage at once, and the shoulder, and i was a should have that the shoulder, and i was the stockade, and the shoulder of the shoulder, and the shoulder, and i was the shoulder of the shoulder, and i was the shoulder, and the shoulder, and the shoulder in the shoulder of the shoulder of the country, and the boats, and the stores of the shoulder, and the shoulder of the shoulder of the shoulder of the shoulder of
# ----- temperature: 0.5
# ----- Generating with seed: "ndlord.
#
# i plucked up courage at once,"
# ndlord.
#
#
# in whom says it money, and under the ship the times of the first t
# ----- temperature: 1.0
# ----- Generating with seed: "ndlord.
#
# i plucked up courage at once,"
# ndlord.
#
#
#
#
#
#
#
# on shot wondered, whom was once's to ben hands
# ----- temperature: 1.2
# ----- Generating with seed: "ndlord.
#
# i plucked up courage at once,"
# ndlord.
#
#
#
#
#
#
#
#
#
# a surn the upsiance, and wene aptancloitess you fo wouldn't onquarge! ond and we'd ret all what which ycheed
# 1035/1035 [==============================] - 78s 75ms/step - loss: 1.3825
# Epoch 8/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3610******************************************************
# ----- Generating text after Epoch: 7
# ----- temperature: 0.2
# ----- Generating with seed: " in chains,
# birds about 'em, seamen p'i"
#  in chains,
# birds about 'em, seamen p'ing the storn and the storn and a ship and the souther and little and the stockade and start and started the captain. the boats were all the boats was a stand of the boats, and stand had stared the captain. the stockade, and a stand and the stockade the strange of the worst of the same back and line of the boats were the chart of the stockade. i was a speaking the stockade, and the boats were all t
# ----- temperature: 0.5
# ----- Generating with seed: " in chains,
# birds about 'em, seamen p'i"
#  in chains,
#
#
#
#
#
#
# the captain, and or from the captain. i was in a sound the stat, and when they
# ----- temperature: 1.0
# ----- Generating with seed: " in chains,
# birds about 'em, seamen p'i"
#  in chains,
#
#
#
#
#
# the two, nwhist! all still above said. the long better unsilved, quite then a
# ----- temperature: 1.2
# ----- Generating with seed: " in chains,
# birds about 'em, seamen p'i"
#  in chains,
#
#
#
#
#
#
#
#
#
# all as i lidev
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.3612
# Epoch 9/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3470******************************************************
# ----- Generating text after Epoch: 8
# ----- temperature: 0.2
# ----- Generating with seed: "! 'deposed'--that's it, is it? very pret"
# ! 'deposed'--that's it, is it? very pretty and stand of the story to the south in the south of the south of the porthed to the south of the stockade, and the south in the south of the stranger, and the storess, and the storess, and the story the south his country, but i had seen the spores, and the south in the story to the south and the side of the suning to see the stranger and the spores, and the south is the south where he was a sou
# ----- temperature: 0.5
# ----- Generating with seed: "! 'deposed'--that's it, is it? very pret"
# ! 'deposed'--that's it, is it? very pretty ship's work of a grikn, and a moment, i had so down in the stores, and the storne, and looking of his shoulder and for the captain smollett of the treasure to see the curred of the more was all he was a sound the spites is itself a bottle of the spites of the stremend, and black, and i setter the statter of his sheaking lives, there tailing to the sea-cheer, and the trunl work of the boats and
# ----- temperature: 1.0
# ----- Generating with seed: "! 'deposed'--that's it, is it? very pret"
#
#
#
#
#
#
#
#
#
#
#
#
# hardly come him were
# ----- temperature: 1.2
# ----- Generating with seed: "! 'deposed'--that's it, is it? very pret"
#
#
#
#
#
#
#
#
#
#
#
#
#
# silver, as slaps along on ys with much to you," he lay
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.3471
# Epoch 10/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.3344******************************************************
# ----- Generating text after Epoch: 9
# ----- temperature: 0.2
# ----- Generating with seed: "unn's time (this is what you'll say)--th"
# unn's time (this is what you'll say)--the shore--and a sure, and the starn of the stranger, and the stranger, and a picked and the stranger, and a single and the shore, and the first and the shore. and so the stranger, and a thick and the black spot and the black spot and the stormed of the stranger, and the starn the captain was a stand of the black spot and the same more and the stranger, and the black spot and the black spot on the s
# ----- temperature: 0.5
# ----- Generating with seed: "unn's time (this is what you'll say)--th"
#
# noth with place and side the exched to be singer, and a face of the trees and the rest of the man and sailing to the way was not voice and the surpersions and the first and man of the wine and side was a fancy, and lay the pirates permissed to the besite a power to t
# ----- temperature: 1.0
# ----- Generating with seed: "unn's time (this is what you'll say)--th"
#
#
#
#
#
#
#
# each far, an nother of th
# ----- temperature: 1.2
# ----- Generating with seed: "unn's time (this is what you'll say)--th"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# almost ather
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.3344
# Epoch 11/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.3194******************************************************
# ----- Generating text after Epoch: 10
# ----- temperature: 0.2
# ----- Generating with seed: "of the sea
# about him too.
#
# i asked hi"
# of the sea
# about him too.
#
# i asked him the deck of the captain stood to the project gutenberg-tm electrony. i had stood on the same man to the stockade, and a thing the same men to the sea-cheep to the sure to the other to the party of the said. there was a sight and there was to the stock to the party of the said. there was the captain side to the stockade, and there was still as sing of the stockade, and there we had stood to the s
# ----- temperature: 0.5
# ----- Generating with seed: "of the sea
# about him too.
#
# i asked hi"
# of the sea
# about him too.
#
#
#
#
#
#
#
# "why, you are as i were beck of the samornor to and a
# ----- temperature: 1.0
# ----- Generating with seed: "of the sea
# about him too.
#
# i asked hi"
# of the sea
# about him too.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ied the place awore quietf and treaded againce, and then john place, and
# ----- temperature: 1.2
# ----- Generating with seed: "of the sea
# about him too.
#
# i asked hi"
# of the sea
# about him too.
#
#
#
#
#
#
#
#
#
#
#
# if h
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.3195
# Epoch 12/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.3089******************************************************
# ----- Generating text after Epoch: 11
# ----- temperature: 0.2
# ----- Generating with seed: "f--shouldn't drink with the men before t"
# f--shouldn't drink with the men before the captain still with the sea so the same was short and had strong and the shoulder, and the captain shore and the doctor that we were all the ship was the captain should be an arraist the black shoulder and the ship was the captain should and that we came of the ship was the captain should be an work of the captain. he had see the doctor that i was so the ship was the captain short and a shipping
# ----- temperature: 0.5
# ----- Generating with seed: "f--shouldn't drink with the men before t"
#
#
#
#
# "doctor, you don't that first, sir," said the doctor i was the villed to the word and the same time in the shoulder, and then this we could deed the shoulder on the degrees. so a chafe me that we must hear a sound the  in his ship had once more captain must have as shippered the treasure in their plank
# ----- temperature: 1.0
# ----- Generating with seed: "f--shouldn't drink with the men before t"
#
# by the captain. he had yaulk bring cencuter say you. they 's put they we'll have seen his plairated to think of the smilking. has now, this earpe such very sure, will the chies and had two, with silver--bring 'lone some sting his rangeante, a word rock. the doctor, armailed fifting. all of forenadnimaly
# ----- temperature: 1.2
# ----- Generating with seed: "f--shouldn't drink with the men before t"
#
#
#
#
# but they tole what il
# 1035/1035 [==============================] - 78s 75ms/step - loss: 1.3087
# Epoch 13/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.3003******************************************************
# ----- Generating text after Epoch: 12
# ----- temperature: 0.2
# ----- Generating with seed: "ied by the idea of the seafaring man wit"
#
#
#  for the same before the same passed and sailing a ships and the same was a sound and from th
# ----- temperature: 0.5
# ----- Generating with seed: "ied by the idea of the seafaring man wit"
# ied by the idea of the seafaring man with the doctor lads make and the lads that were and not redruth and from that. i was a shot last and was a hols work a heavy the words--so for the same was from the sea allow the brusk slight and heard the wind on the southard to his head to go soon so the barruls, and we been still was so here and sailing the same moment the fiver of the holding by the fams before the sim farrore sort in the bid an
# ----- temperature: 1.0
# ----- Generating with seed: "ied by the idea of the seafaring man wit"
#
#
#
#
#
#
#
#
# way but my hearting, and caroneing through the passage of that bristolchard too soull. he is doing could see the nassearhal mark, continued for a m
# ----- temperature: 1.2
# ----- Generating with seed: "ied by the idea of the seafaring man wit"
#
#
#
#
#
#
#
#
#
#
#
#
# knows--body gones i go_
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.3007
# Epoch 14/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.2924******************************************************
# ----- Generating text after Epoch: 13
# ----- temperature: 0.2
# ----- Generating with seed: "ted, and at last dismissed.
#
# "and now,"
# ted, and at last dismissed.
#
# "and now, man of the captain. "then i were to the same but the captain that i was a state the start of the party was a ship, and the cheer before the state of the cutely was a sound and come to the woods of the country, and the cheer the stockade, and we were black outen to the party to the state the start of the woods and the cheer the black spot of the captain. the same was a sound of the bottle of the t
# ----- temperature: 0.5
# ----- Generating with seed: "ted, and at last dismissed.
#
# "and now,"
# ted, and at last dismissed.
#
#
#
#
#
#
#
#
# not the wood of the treasure in the same was the thought of one countressss. the
# ----- temperature: 1.0
# ----- Generating with seed: "ted, and at last dismissed.
#
# "and now,"
# ted, and at last dismissed.
#
#
#
#
#
#
# will fire-piess
# ----- temperature: 1.2
# ----- Generating with seed: "ted, and at last dismissed.
#
# "and now,"
# ted, and at last dismissed.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "ifeing teinh, mem."ther. i be the re
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.2926
# Epoch 15/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2838******************************************************
# ----- Generating text after Epoch: 14
# ----- temperature: 0.2
# ----- Generating with seed: "ver-bold act, but i was determined to do"
# ver-bold act, but i was determined to do were all the south and the ship was the south of the shoulder, and the south in the south and the south of the ship, and the south of the ship, and the south and the ship was the ship of the shores, and the sure and seemed to see the man the boat, and the south and the south of the south of the shores, and the south of the sea things in the south of the shoulder. the shoulder, and the south and t
# ----- temperature: 0.5
# ----- Generating with seed: "ver-bold act, but i was determined to do"
#
#
#
#
# "and the captain's one of th
# ----- temperature: 1.0
# ----- Generating with seed: "ver-bold act, but i was determined to do"
#
#
#
#
#
#
#
#
#
# "my meern to inlidorod"ing encherral own surface in the
# ----- temperature: 1.2
# ----- Generating with seed: "ver-bold act, but i was determined to do"
#
#
#
#
#
#
#
#
#
#
#
# sproyally
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.2839
# Epoch 16/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.2788******************************************************
# ----- Generating text after Epoch: 15
# ----- temperature: 0.2
# ----- Generating with seed: "at's better odds than we had at starting"
# at's better odds than we had at starting the captain. i had still into the sound, and while in the strange and a sure in the inter the more and leaving the thought of the sailing the strange island into the more the sound and the strange island to the strange island to the strange island to the captain. i had something a seaman to the same moment it was a some time, and it was a bring the strange and he was a sound and companions of the
# ----- temperature: 0.5
# ----- Generating with seed: "at's better odds than we had at starting"
#
#
#
#
# on who had been side of the wood my way in the bole, and the cut of all outside the offer of the parting and bod
# ----- temperature: 1.0
# ----- Generating with seed: "at's better odds than we had at starting"
#
#
#
#
#
#
#
#
# mea
# ----- temperature: 1.2
# ----- Generating with seed: "at's better odds than we had at starting"
#
#
#
#
#
# "very jift in yo--"broke them's h. that's ycretened. "shoth sboved you suchance, "
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.2789
# Epoch 17/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.2694******************************************************
# ----- Generating text after Epoch: 16
# ----- temperature: 0.2
# ----- Generating with seed: " i do."
#
# and he pinched me again, in t"
#  i do."
#
# and he pinched me again, in the strange in the storyang were all the strange the captain, and the stood beside the stranger livesey was a ship was a ship in the stranger of the strong the strong the story in the strange in the strange in the stopy the strange in the strange in the party and when the story the stockade, and the first was better and the story in the strange of the strange in the strange in the strange in the st
# ----- temperature: 0.5
# ----- Generating with seed: " i do."
#
# and he pinched me again, in t"
#  i do."
#
#
# of entern, while the trees of the stockade, and then i was to see the captain was all the boat, were here in a
# ----- temperature: 1.0
# ----- Generating with seed: " i do."
#
# and he pinched me again, in t"
#  i do."
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "and then, saying, muherery!" draw, and i will the yancace and i as i've here any
# ----- temperature: 1.2
# ----- Generating with seed: " i do."
#
# and he pinched me again, in t"
#  i do."
#
#
#
#
#
#
#
# gra.
#
#
#
#
# "well, imeninny w!" he could "alret,lying you? a
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.2693
# Epoch 18/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.2612******************************************************
# ----- Generating text after Epoch: 17
# ----- temperature: 0.2
# ----- Generating with seed: "u
# would lose your precious life, and yo"
# u
# would lose your precious life, and you can be sure, and i said the ship i had stood with a shoulder of the stockade, and the stockade, and the stockade, and the stockade, and the rest was and the stockade, and the stockade, and the stores, and the stockade, and the stockade, and the stockade, and the stockade, where i said the stockade, and the stockade, and the stockade, and the stockade, and the stockade, and the stockade, and the
# ----- temperature: 0.5
# ----- Generating with seed: "u
# would lose your precious life, and yo"
# u
#
#
#
#
#
#
#     so silver was a man that i had stood and should a counting his co
# ----- temperature: 1.0
# ----- Generating with seed: "u
# would lose your precious life, and yo"
# u
#
#
#
#
#
#
#
#
#
#
#
# heard diensened and would one noterboarder, and i sill fr
# ----- temperature: 1.2
# ----- Generating with seed: "u
# would lose your precious life, and yo"
# u
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# treguage
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2614
# Epoch 19/60
# 1032/1035 [============================>.] - ETA: 0s - loss: 1.2578******************************************************
# ----- Generating text after Epoch: 18
# ----- temperature: 0.2
# ----- Generating with seed: "he blockhouse
# showed me the worst of my"
# he blockhouse
# showed me the worst of my head to the sound and the sun his safe and story in the sound and a suddenly and the same sundor, and i was a suddenly the sun and the treasure island to the same was a sound and long john and a suddenly the sun his sea and the sun his sea some of the same mind of the same was the sun his sead of the stores, and the sun his sea-chiendly story was the south of the stockade, and the sun his sea som
# ----- temperature: 0.5
# ----- Generating with seed: "he blockhouse
# showed me the worst of my"
# he blockhouse
# showed me the worst of my nearest and and hearten that was the sand of a peck the captain side the sea-creeks with a project gutenberg literal to the lower dead stopped with his hand and from the water of the same was a starks in the same stard, and about all that was story me out and had not and the pirates; i had already could hear a sea of the woods, and i don't a bird and with that was been any of the same was right i
# ----- temperature: 1.0
# ----- Generating with seed: "he blockhouse
# showed me the worst of my"
# he blockhouse
#
#
#
#
#
#
#
#
#
#
# sit and luding looked the stoud back to the thright 'el word, and any's his buccane, is what i
# ----- temperature: 1.2
# ----- Generating with seed: "he blockhouse
# showed me the worst of my"
# he blockhouse
#
#
#
#
#
# soon you doo a! thee expiteancabed itcreads, and
# 1035/1035 [==============================] - 78s 76ms/step - loss: 1.2576
# Epoch 20/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.2509******************************************************
# ----- Generating text after Epoch: 19
# ----- temperature: 0.2
# ----- Generating with seed: "at man," he would say, "and i should exp"
# at man," he would say, "and i should explessed the captain, and the black spot was and the ship in the first with a sound the redruating the spit to the stockade, and the black spot to the ship was a long to the sound the stockade was the sound the silver was some of the stockade, and the stockade, and the stockade and the black spot to the same man the black spot was for the boat-fast was some sound and the country, and the black spot
# ----- temperature: 0.5
# ----- Generating with seed: "at man," he would say, "and i should exp"
# at man," he would say, "and i should explessed, and he was it, and the black spot, but the time was a could by the first stands, the night was down the blind man him, and there was only hand of the blockhouses, i felt charring about dead the very ship hand to the stockade, in the man and discontered to be some to the same was so a sound a good time and distributing as he came and a ship's the ship. in some some of the briskly was for th
# ----- temperature: 1.0
# ----- Generating with seed: "at man," he would say, "and i should exp"
#
#
#
#
#
#
# the morning. you'll tilf obserned ing every ng
# ----- temperature: 1.2
# ----- Generating with seed: "at man," he would say, "and i should exp"
#
#
#
#
#
#
#
# irly fact, and with the coot--"diging treep-may riskpy on any. we'll little plain. rate"." i were xired mobned think gentlembean, withon, if formy. we operly again rem
# 1035/1035 [==============================] - 79s 76ms/step - loss: 1.2512
# Epoch 21/60
# 1031/1035 [============================>.] - ETA: 0s - loss: 1.2467******************************************************
# ----- Generating text after Epoch: 20
# ----- temperature: 0.2
# ----- Generating with seed: ", mind that--in a gen'leman born than in"
# , mind that--in a gen'leman born than in the same mother and the ship's captain to the sea against the boatswance of the sea against the captain that was a sure to help him the story. the stranger, and the stockade, and the ship was a man of the stockade, and the stockade, and the shore, and the stockade, and the stockade, and the stockade, and we were been strange at the stranger, and the stranger, and the ship was a shore and believe
# ----- temperature: 0.5
# ----- Generating with seed: ", mind that--in a gen'leman born than in"
#
#
#
#
#
#
#
# i had been parried wi
# ----- temperature: 1.0
# ----- Generating with seed: ", mind that--in a gen'leman born than in"
#
#
# you could see nothing met her head appleady fourle to see impusion; and trelawney, as a heave to old molken. but then had frolty arce, serviverperth thousan will retere innarrar back were will set the sounh yourself," re
# ----- temperature: 1.2
# ----- Generating with seed: ", mind that--in a gen'leman born than in"
#
#
#
#
#
#
#
#
#
#
#
#
# "lobricabills out. kee
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.2468
# Epoch 22/60
# 1031/1035 [============================>.] - ETA: 0s - loss: 1.2425******************************************************
# ----- Generating text after Epoch: 21
# ----- temperature: 0.2
# ----- Generating with seed: "d when they had talked to their heart's "
#
# as i was stopped the doctor. and i could see the shoulders of the schooner of the trees to the same time and on the stockade, and the stores and the stockade was a treeward himself and the chart, and we was a sea-cheeter was stood the same time in the spit, and the deck. i was a side of the ship the sure in the spit, and the stockade and
# ----- temperature: 0.5
# ----- Generating with seed: "d when they had talked to their heart's "
#
#
# "well, i'll call do this sure, and i thought i saw the doctor and the cruise criep and providing to the end in the stockade, and we
# ----- temperature: 1.0
# ----- Generating with seed: "d when they had talked to their heart's "
#
#
#
#
#
# chart of is for si; roat
# ----- temperature: 1.2
# ----- Generating with seed: "d when they had talked to their heart's "
#
#
#
# a by pase, and i could see three you, gentlemandor, tench but ne: the appear them. behind him pourd
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2421
# Epoch 23/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.2361******************************************************
# ----- Generating text after Epoch: 22
# ----- temperature: 0.2
# ----- Generating with seed: " shot the others
# like partridges. all t"
#  shot the others
#
# sharper of the ship was a courage, and a shipper of the ship was a sound a sound and the sound the same men and the southern of the sea in the parricirence of the same man and the sound the sea soon and the sound the sea soon of the sea-castaging the sound the cover to the corner of the ship was the sound the same more and on the ship was a seaman of the signal was the same man and t
# ----- temperature: 0.5
# ----- Generating with seed: " shot the others
# like partridges. all t"
#  shot the others
#
#
#
#
#
# stargring of the sound to the stee. and t
# ----- temperature: 1.0
# ----- Generating with seed: " shot the others
# like partridges. all t"
#  shot the others
#
#
#
# 1.p
#
#
#
#
#
#
# then here's shipmant to on. i''ll wity pridlabeen that's someat," sterped away gradually every, and given suring ad. euch noway i mean
# ----- temperature: 1.2
# ----- Generating with seed: " shot the others
# like partridges. all t"
#  shot the others
#
#
#
#
#
#
#
# "coonly laymation's fash,," arrall occupt as fa--the coast hearth their spra
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.2363
# Epoch 24/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.2336******************************************************
# ----- Generating text after Epoch: 23
# ----- temperature: 0.2
# ----- Generating with seed: "ad
# seen so gloomy, shouting at the oars"
# ad
#
#
#
#
# "well, when the squire's sea-chey," said
# ----- temperature: 0.5
# ----- Generating with seed: "ad
# seen so gloomy, shouting at the oars"
# ad
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "well, i'll g
# ----- temperature: 1.0
# ----- Generating with seed: "ad
# seen so gloomy, shouting at the oars"
# ad
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# there, round the ke
# ----- temperature: 1.2
# ----- Generating with seed: "ad
# seen so gloomy, shouting at the oars"
# ad
# seen so gloomy, shouting at the oars lo,
#
#
#
#
# like, silenty clothiri
# 1035/1035 [==============================] - 76s 74ms/step - loss: 1.2341
# Epoch 25/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2270******************************************************
# ----- Generating text after Epoch: 24
# ----- temperature: 0.2
# ----- Generating with seed: "lver joined as heartily as any.
#
# three"
# lver joined as heartily as any.
#
# three you was a man and the stockade, and the thought at last in the stockade, and the blockhouse of the ship's come of the stren the boat--sure, and i could see among the man of the book, and it was all the boat--the thing and the thought as it was a sure and the door in the stranger of the three to the strait, and the door instantly from the more and the conton of the boat--spairing and at the more a
# ----- temperature: 0.5
# ----- Generating with seed: "lver joined as heartily as any.
#
# three"
# lver joined as heartily as any.
#
#
#
#
#
#
# for the great turned the mast before the broken the sure to sea out should far an bid in at only along the work upon the party was slipped at the point
# ----- temperature: 1.0
# ----- Generating with seed: "lver joined as heartily as any.
#
# three"
# lver joined as heartily as any.
#
#
#
#
#
#
#
#
#
# the stice. it's all, is detimen, his man, as it was like our others--the blood-heaving it down and up, underitle it. what.
# ----- temperature: 1.2
# ----- Generating with seed: "lver joined as heartily as any.
#
# three"
# lver joined as heartily as any.
#
#
#
#
#
#
#
#
#
#
# pr
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2273
# Epoch 26/60
# 1029/1035 [============================>.] - ETA: 0s - loss: 1.2225******************************************************
# ----- Generating text after Epoch: 25
# ----- temperature: 0.2
# ----- Generating with seed: " a-crossin' of you?"
#
# "why, how many t"
#  a-crossin' of you?"
#
# "why, how many tall a ship was the brow out and the corner of the same must be chay to said the same mother in the same motnesed the corner of the captain. and the same time the storess of the sure to his feet the story was a sound the stockade, and at the same time the captain, and the captain the black spot, and the sure the same sailed behind the same motele of the boy of the captain of the stranger, and the s
# ----- temperature: 0.5
# ----- Generating with seed: " a-crossin' of you?"
#
# "why, how many t"
#  a-crossin' of you?"
#
# "why, how many to can understand of the point and for the inforation of this alling the corner of the worsts of big and the coracle, and i could be unst a ship was boy, i was still had been the blockhouse, when the remiss; and the lorg worst if the sure to the best the companionsed the fellow was brought a shipping me than the water had stare the stockade, and we passed him the mound and he was about a tree to th
# ----- temperature: 1.0
# ----- Generating with seed: " a-crossin' of you?"
#
# "why, how many t"
#  a-crossin' of you?"
#
#
#
#
#
#
#
#
# m
# ----- temperature: 1.2
# ----- Generating with seed: " a-crossin' of you?"
#
# "why, how many t"
#  a-crossin' of you?"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# i told me how
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.2225
# Epoch 27/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2546******************************************************
# ----- Generating text after Epoch: 26
# ----- temperature: 0.2
# ----- Generating with seed: "he sound of their voices, but by the beh"
#
# stage to the stranger, and the coracle of the stranger, and the stockade and the stockade, and the starp and the stockade, and the stockade, and the captain was the stranger. i had seen the captain and the blockhouse, some of the companion was the chart of the shores, and the coracle of the stockade, and we were all the boat thing the stockade, and the squire was before the stockade, and the c
# ----- temperature: 0.5
# ----- Generating with seed: "he sound of their voices, but by the beh"
#
#
#
# "come of the bring a sure, hands, to can feet. and it was not between me shot on the trees.
# ----- temperature: 1.0
# ----- Generating with seed: "he sound of their voices, but by the beh"
#
#
#
#
#
#
#
# sune smond and mizhteen and nothin
# ----- temperature: 1.2
# ----- Generating with seed: "he sound of their voices, but by the beh"
#
#
#
#
#
#
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2548
# Epoch 28/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2596******************************************************
# ----- Generating text after Epoch: 27
# ----- temperature: 0.2
# ----- Generating with seed: "t once. some
# news of the lugger in kitt"
# t once. some
# news of the lugger in kitting to the captain to the stockade, and the captain should when the stockade, and the captain should the boatswain the door and the captain should the captain soon a stark of the captain strong at the same moment the boatswain and the thing of the stockade, and the captain should and the captain shot the stockade, and the captain see the stockade, and the captain should the stockade, and the capta
# ----- temperature: 0.5
# ----- Generating with seed: "t once. some
# news of the lugger in kitt"
# t once. some
#
#
#
#
#
# a thought so down the captain should thought i mean the keen and for
# ----- temperature: 1.0
# ----- Generating with seed: "t once. some
# news of the lugger in kitt"
# t once. some
#
#
#
#
#
#
#
# of the famom-, and
# ----- temperature: 1.2
# ----- Generating with seed: "t once. some
# news of the lugger in kitt"
# t once. some
#
#
#
#
#
#
#
#  on up joyce, certainly distributure, y
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.2594
# Epoch 29/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.2832******************************************************
# ----- Generating text after Epoch: 28
# ----- temperature: 0.2
# ----- Generating with seed: " out. who might have done that, i wonder"
#  out. who might have done that, i wondered the stockade, and the stores, and the stores, and the spit would have had a suddenly and the stockade, and the stores, and the stockade, and the same man and the stockade, and the stores, and the sound of the stren the stockade, and the sure of the same man of the stockade, and the stockade, and we were all the sound of the stren the stockade, and a cour the sound of the ship in a thing the sto
# ----- temperature: 0.5
# ----- Generating with seed: " out. who might have done that, i wonder"
#  out. who might have done that, i wondered the sail in the fore in a man the sound the blind mates of a good out the same man and were to the thing the black dog-
#
#
# thing was the stren of the door of the captain side, and we were for when i was a suffil the tried to be some some hands--the most ship bend behive mo
# ----- temperature: 1.0
# ----- Generating with seed: " out. who might have done that, i wonder"
#
#
#
#
#
#
# go the very walk desiing. for the pilats comp here ake or north among the portate. ipsmy con, one behwuted to the best
# ----- temperature: 1.2
# ----- Generating with seed: " out. who might have done that, i wonder"
#
#
#
#
#
#
#
#
#
# "it would smil rame to you was go at a dave
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2830
# Epoch 30/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.2759******************************************************
# ----- Generating text after Epoch: 29
# ----- temperature: 0.2
# ----- Generating with seed: " to share in the reward.
#
# "come in, ji"
#  to share in the reward.
#
# "come in, jim the rock, you can see the sail of the thick--and the stockade, and the ship was a shoulder of the sailor a ship and the shoulders of the shore-furting to the stren was still strong the stockade, and the stockade, and the stockade, and the stockade, and we was still stronged the first was still and the stockade, and the stranger, and we were all the boats, and the stockade, and the fire the shoul
# ----- temperature: 0.5
# ----- Generating with seed: " to share in the reward.
#
# "come in, ji"
#  to share in the reward.
#
# "come in, jim man about to think in which i should pard side, and the sickang shouthers was find heart to understile one of the chart. and the thing had permiss had began to and the thickning and distribution to the sandy the same time, and was searing a left of all this works on the safety ben gunn the came of a side and companion of the corcel. i had seen the word, and a bit, it was stood every and the flin
# ----- temperature: 1.0
# ----- Generating with seed: " to share in the reward.
#
# "come in, ji"
#  to share in the reward.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# i have h
# ----- temperature: 1.2
# ----- Generating with seed: " to share in the reward.
#
# "come in, ji"
#  to share in the reward.
#
#
#
#
#
#
#
#
#
#
#
#
#
# "ilm wanters u
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.2759
# Epoch 31/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.2439******************************************************
# ----- Generating text after Epoch: 30
# ----- temperature: 0.2
# ----- Generating with seed: "" asked the captain.
#
# "mr. trelawney, "
# " asked the captain.
#
#
#
# ----- temperature: 0.5
# ----- Generating with seed: "" asked the captain.
#
# "mr. trelawney, "
# " asked the captain.
#
#
#
#
# of the feel was now and sleep and the rest of the ship's companies, the watching of the words in the into was his crutch of the water of the worst came out to be sut her captain. he got to the so his sail and the spacing farned before, and a
# ----- temperature: 1.0
# ----- Generating with seed: "" asked the captain.
#
# "mr. trelawney, "
# " asked the captain.
#
#
#
#
#
#
# posty mist suppor goates in their a smell as the were, as the public of old angasted his mi
# ----- temperature: 1.2
# ----- Generating with seed: "" asked the captain.
#
# "mr. trelawney, "
# " asked the captain.
#
#
#
#
#
#
#
#
#
#
#
# you and dy most get to a comp
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.2440
# Epoch 32/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.2283******************************************************
# ----- Generating text after Epoch: 31
# ----- temperature: 0.2
# ----- Generating with seed: "followed by the former silence.
#
# "heav"
# followed by the former silence.
#
#
#
# the squire was the stranged of the stockade, and the stockade, and a sound of the ships of the same mutines was began to the ship was the stockade, and the stockade, the stockade, and the ships were the stockade, and the stranger of the stockade, and and the captain should be sure, but i had spared the stockade, a
# ----- temperature: 0.5
# ----- Generating with seed: "followed by the former silence.
#
# "heav"
# followed by the former silence.
#
# "heavy from the squire's so that dead side, and they were spiles the stranger and destroin the cave a bit, he come, it was siging a such of the schooner, the stockade, and when you sheet they were all than the squire's as soon the squire, what i did all the ships we could not lay to the lookly the spit of my some time, sprang as i can done in the part of the face, when they had been no chabing the foot
# ----- temperature: 1.0
# ----- Generating with seed: "followed by the former silence.
#
# "heav"
# followed by the former silence.
#
#
#
#
#
#
#
#
# ," i not lay stalled my eyes of the house; but an ebbow's
# ----- temperature: 1.2
# ----- Generating with seed: "followed by the former silence.
#
# "heav"
# followed by the former silence.
#
#
#
#
#
#
#
#
#
#
# i thoughted y
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.2288
# Epoch 33/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2167******************************************************
# ----- Generating text after Epoch: 32
# ----- temperature: 0.2
# ----- Generating with seed: "e captain's was enough to frighten them "
# e captain's was enough to frighten them side that the stores of the stockade, and before the sea together of the man the boat, with the breeze to the strodge for the boat, and the stockade, and who had come to be sort of the stifflect had been a sure that we was the boat, who had seen to the back to be sure, and seen the captain says, and before the shoulder of the stockade, and with the sure that which was a sure that we were all that
# ----- temperature: 0.5
# ----- Generating with seed: "e captain's was enough to frighten them "
#
# remarks, and had still to the tree blassust, and who had been all that the whole sailed the pork and project gutenberg-tm time at the fore had seen to be so here,
# ----- temperature: 1.0
# ----- Generating with seed: "e captain's was enough to frighten them "
#
#
#
#
#
#
#
#
#
# stipishable almost round and creeped a-boop
# ----- temperature: 1.2
# ----- Generating with seed: "e captain's was enough to frighten them "
#
#
#
#
#
#
# nowd and lforting, i was morth huseons. addradiug to grow a man almost cameecuation about, landing up it. the first threblessian, for it,  a
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.2166
# Epoch 34/60
# 1029/1035 [============================>.] - ETA: 0s - loss: 1.2096******************************************************
# ----- Generating text after Epoch: 33
# ----- temperature: 0.2
# ----- Generating with seed: "to that! if i hadn't took to you like pi"
# to that! if i hadn't took to you like pines of the ship while the ship while the captain smollett the same man the story. the spy-glass, and the spit of his sail. the same time the story. the stockade, and the shore and ship the ship was the same was the spy-glass, and seen the black spot of the story in the spit of the captain. and the storor of the ship was along, and said the captain smollett to see the same man the spy-glass, and th
# ----- temperature: 0.5
# ----- Generating with seed: "to that! if i hadn't took to you like pi"
#
# times of the place of water the same might a soin of the same was our own one of the last shipper in a mighty and laid a changing of was his a ship was the flund i was done would have been for the change of his second from the blockhord, and the close i had entered the corner of like what i had entered the confident sp
# ----- temperature: 1.0
# ----- Generating with seed: "to that! if i hadn't took to you like pi"
#
#
#
#
#
# tear all of like but nore 'em of his treft, i had bleeding." sbe land i could not the first from his face do not men
# ----- temperature: 1.2
# ----- Generating with seed: "to that! if i hadn't took to you like pi"
#
#
#
#
#
#
#
#
#
#
#
#
# came that bled very every among and ex"flognder with caingive himself our bigled the th
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.2099
# Epoch 35/60
# ...
# Epoch 49/60
# 1029/1035 [============================>.] - ETA: 0s - loss: 1.1617******************************************************
# ----- Generating text after Epoch: 48
# ----- temperature: 0.2
# ----- Generating with seed: "sing another in the very same words of f"
# sing another in the very same words of free the stockade and with a man the corner of the stockade, and a speakess, and which the whole ship work out as a pipe was a sperred, and a sing to the stockade, and the captain and a man work the portable and the stockade, and the stockade and the boat, which the stockade while the boats was the stockade, and the stockade and which we were all in the work the work of the chance and a ship who ha
# ----- temperature: 0.5
# ----- Generating with seed: "sing another in the very same words of f"
#
#
# they was a run and a course, and a feeth the stockade and doctor livesey,
# ----- temperature: 1.0
# ----- Generating with seed: "sing another in the very same words of f"
#
#
#
#
#
#
# were at once, and this sitting us leaves to the project then would heed the councilus and dolactwitio
# ----- temperature: 1.2
# ----- Generating with seed: "sing another in the very same words of f"
#
#
#
#
#
#
#
#
#
#
# writheh i'm catyinvered; i mear ode, and i tall
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.1616
# Epoch 50/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1587******************************************************
# ----- Generating text after Epoch: 49
# ----- temperature: 0.2
# ----- Generating with seed: "n if things so fell out that he was forc"
#
#
#
#
# "and you may come to sea to the your can with the sound. i had still had been the colors, and the sound of the stockade, and the stockade, and with the corner of the stockade, and the long back in
# ----- temperature: 0.5
# ----- Generating with seed: "n if things so fell out that he was forc"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.0
# ----- Generating with seed: "n if things so fell out that he was forc"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# he was plain and including recenmed.
# ----- temperature: 1.2
# ----- Generating with seed: "n if things so fell out that he was forc"
#
#
#
#
#
#
# we were and forgated described about by the partituole sort in. there consert. i fand for shore
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.1587
# Epoch 51/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.1580******************************************************
# ----- Generating text after Epoch: 50
# ----- temperature: 0.2
# ----- Generating with seed: " too much of the
# born favorite for me. "
#  too much of the
# born favorite for me. i was still rather of the ship the stockade, and we were all the project gutenberg-tm electronic work as the sandy and shot me to the story will a state of the strange and the stockade, and the first the boatswain to the strong and the man with the trees, and the stockade, and the stockade, and the first had silver had been the sandy was a state of the stockade, and with the way of the ship the st
# ----- temperature: 0.5
# ----- Generating with seed: " too much of the
# born favorite for me. "
#  too much of the
# born favorite for me. i all were to the same prodrish of my project gutenberg-tm electronic works in the fallen and something the part of the sandy in the anchorage mutted me than the dament for a cornes with the island, and course, and the ship of the stockade. and i was the strange and beside the captain said the corner of the man with the rest was a shought of the parrice. i said the nearest sleed a corner in the wi
# ----- temperature: 1.0
# ----- Generating with seed: " too much of the
# born favorite for me. "
#  too much of the
#
#
#
# you are led the gun, second to wadned to the mr. scrasc-roughed ebooks up  appro
# ----- temperature: 1.2
# ----- Generating with seed: " too much of the
# born favorite for me. "
#  too much of the
#
#
#
#
#
#
#
# there i oth
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.1580
# Epoch 52/60
# 1033/1035 [============================>.] - ETA: 0s - loss: 1.1568******************************************************
# ----- Generating text after Epoch: 51
# ----- temperature: 0.2
# ----- Generating with seed: "long john, who was standing by, with his"
# long john, who was standing by, with his shoulder of the sailor, and it was a stiff began to be sure, and the stockade, and the black dog appearance i was a stiff began to be companiey was the ship. i saw spit and the captain of the stockade, and the captain to the inclide the woods and still was a states, and the stockade, and the stockade, and a fear behind me that was a stiff began to be sure the stockade, and the most come of the st
# ----- temperature: 0.5
# ----- Generating with seed: "long john, who was standing by, with his"
# long john, who was standing by, with his shoulder and the blessed until start to be sure, and the blockhouse, and dosred to save is it, and i was been to fiel i starn, and the captain, as we were to a sounding our of its the stockade, and the black dog, and couldn't and propeed to go doontly where i wouldn't are to be sure any place, but i began to be sure the stockade, and we were so and the landing to scrose. i in the room, and i coul
# ----- temperature: 1.0
# ----- Generating with seed: "long john, who was standing by, with his"
#
#
#
#
#
#
# then he neared the decap how
# ----- temperature: 1.2
# ----- Generating with seed: "long john, who was standing by, with his"
#
#
#
#
#
#
#
#
#
#
#
#
#
# detride chlinge by hapch how, up or that
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.1570
# Epoch 53/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.1511******************************************************
# ----- Generating text after Epoch: 52
# ----- temperature: 0.2
# ----- Generating with seed: " lofty grove had been destroyed. most of"
#  lofty grove had been destroyed. most of the same time the chart as i set a thing and the boatswain, and the boat, who had still as the boatswain, and a thing to see the stores, and the stores, and the boats had along a stands, and as soon as the boatswain, which was the stockade and the boat, which we were blow on the sand of the stockade and the boats had been the story and strong the stockade to the work and the stockade, and we were
# ----- temperature: 0.5
# ----- Generating with seed: " lofty grove had been destroyed. most of"
#
# inderance and were for all the side of eive and like a side back and the stockade and the pine of the cove to an ashoun. i allurk ashore the spit of all the sea togeter. we had been gleeted the corner of the blockhouses and pleased to a what were all was along the big just two out at the same into the back to and set
# ----- temperature: 1.0
# ----- Generating with seed: " lofty grove had been destroyed. most of"
#
#
#
#
# i could me my woods, sounded a
# ----- temperature: 1.2
# ----- Generating with seed: " lofty grove had been destroyed. most of"
#
#
#
#
#
#
# lookex, as for wh
# 1035/1035 [==============================] - 77s 74ms/step - loss: 1.1520
# Epoch 54/60
# 1029/1035 [============================>.] - ETA: 0s - loss: 1.1494******************************************************
# ----- Generating text after Epoch: 53
# ----- temperature: 0.2
# ----- Generating with seed: " of song, "here's to ourselves, and hold"
#
#
# "well, i say, "you are, silver, silver," said he. "i've the black and the black and the black spot to the best hand of the more the sound of the boats, and the worse of the ship was a sead of the south, and the captain to the stockade, and a third of the stockade, and the three the corner of the stockade, and the black dog appeared by the strange of the sound of the stockade, a
# ----- temperature: 0.5
# ----- Generating with seed: " of song, "here's to ourselves, and hold"
#
#
#
#
# great to the rec
# ----- temperature: 1.0
# ----- Generating with seed: " of song, "here's to ourselves, and hold"
#
#
#
#
#
#
#
#
# to come done in the door the my ears of course, tunsbers strose
# ----- temperature: 1.2
# ----- Generating with seed: " of song, "here's to ourselves, and hold"
#
#
#
#
#
#
#
#
#
# say," i saw, and restifned,
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.1496
# Epoch 55/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.1476******************************************************
# ----- Generating text after Epoch: 54
# ----- temperature: 0.2
# ----- Generating with seed: ", a
# boy--against five strong and active"
# , a
# boy--against five strong and active to the stockade, and whis alarm and the sea addronest to the stockade, and a shipper and the stockade, and a ship and the cove and the fire out of the sea some of the ship was a seaboard, and a corner of the ship work and were all that in the stockade, and a shipper of the ship was blows in his head. but while the ship was a state of his head that i had seen the ship was a ship and the fire out o
# ----- temperature: 0.5
# ----- Generating with seed: ", a
# boy--against five strong and active"
# , a
#
# to looks was being enough to his life i coundr, pines; and with the fire out and disclean so far an even with a musket to the corner of the first to stepped his sea side of our sea-choom, and not on the foligats, and as the which i
# ----- temperature: 1.0
# ----- Generating with seed: ", a
# boy--against five strong and active"
# , a
#
#
# log-house, and followed visio
# ----- temperature: 1.2
# ----- Generating with seed: ", a
# boy--against five strong and active"
# , a
#
#
#
#
#
# leastwa
# 1035/1035 [==============================] - 76s 73ms/step - loss: 1.1477
# Epoch 56/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.1454******************************************************
# ----- Generating text after Epoch: 55
# ----- temperature: 0.2
# ----- Generating with seed: "jim, what would you say but there'd be w"
# jim, what would you say but there'd be with the sure, and then the storess the stockade, and the stockade, and we could see the stockade, and the stockade, and we could do not the stockade, and the coracle the captain, and the stockade, and we could deter the stockade, and the stockade, and a course, and the stockade, and the doctor livesey and the stockade, and the stockade, and the sure enough, and the black dog's of the suren of the
# ----- temperature: 0.5
# ----- Generating with seed: "jim, what would you say but there'd be w"
#
#
#
# he island than the doctor musket and me. i felt men and the most brough
# ----- temperature: 1.0
# ----- Generating with seed: "jim, what would you say but there'd be w"
#
#
#
#
#
#
#
#
#
#
#
#
# w
# ----- temperature: 1.2
# ----- Generating with seed: "jim, what would you say but there'd be w"
#
#
#
#
#
# beit amoflewar succer. of good scump indos
#
# would ristle boy. he went behack into the worst. i with quidd... buck includon the produck nort
# 1035/1035 [==============================] - 75s 73ms/step - loss: 1.1453
# Epoch 57/60
# 1030/1035 [============================>.] - ETA: 0s - loss: 1.1449******************************************************
# ----- Generating text after Epoch: 56
# ----- temperature: 0.2
# ----- Generating with seed: "ch?"
#
# "amount, sir!" cried the squire."
# ch?"
#
#
#
# "the ship, man sir," said the captain. "the ship was a sound of this captain, which we could see the captain of the captain, and a ships of the ship, and a fee sail and the stockade and the stockade, and the stockade and help the stockade, and the stockade and set a bottle of the stockade, and the stockade and the stockade, and a good faces and like a ships, and the stores, and i seen the stoc
# ----- temperature: 0.5
# ----- Generating with seed: "ch?"
#
# "amount, sir!" cried the squire."
# ch?"
#
#
#
#
#
#
#
# ----- temperature: 1.0
# ----- Generating with seed: "ch?"
#
# "amount, sir!" cried the squire."
# ch?"
#
#
#
#
#
#
#
#
#
# bid know by his head if it drawing a man, were sun--for sime on the give me, i staring like paragrablive
# ----- temperature: 1.2
# ----- Generating with seed: "ch?"
#
# "amount, sir!" cried the squire."
# ch?"
#
#
#
#
#
#
#
#
#
# ha, rightiland into that boy, do veress, a pew oncevisition of discolor groping once, of the doctor t
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.1452
# Epoch 58/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.1431******************************************************
# ----- Generating text after Epoch: 57
# ----- temperature: 0.2
# ----- Generating with seed: " be ashamed to hear of. now, for instanc"
#  be ashamed to hear of. now, for instance, and the sure to the cook was a sound in the stockade, and the cook was the change of the captain sailor, and the cabin was the souths, and the captain said. the sure to the surering to the stockade, and the stockade, and the counciled from the stockade, and the stockade, and the body and the sure to give for the south, and the sure to the worst of the captain. and the sure to the safe far the p
# ----- temperature: 0.5
# ----- Generating with seed: " be ashamed to hear of. now, for instanc"
#
#
#
#
#
#
#
# started to the project gutenberg-tm long behind me to his side. the first shipmates, like the cook, we was still to the matter like a hundred that that i reckon as he
# ----- temperature: 1.0
# ----- Generating with seed: " be ashamed to hear of. now, for instanc"
#
#
#
#
#
# doot
# ----- temperature: 1.2
# ----- Generating with seed: " be ashamed to hear of. now, for instanc"
#
#
#
#
#
#
#
#
#
#
#
#
#  out usper raiing: with. e'me--sunge, like you c
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.1432
# Epoch 59/60
# 1028/1035 [============================>.] - ETA: 0s - loss: 1.1408******************************************************
# ----- Generating text after Epoch: 58
# ----- temperature: 0.2
# ----- Generating with seed: "ath or till john threw his handkerchief "
# ath or till john threw his handkerchief of the chances of the captain. and the ship's shoulder, and we'll let the morning, and were to the ship, and the sea side the blow unong the starg and the cheer of the ship, and the ship was a sound of the captain, and the souther same friends of the stores, and the ship was a sound of the changing of the captain. i was a sound in a man with the woods, and the blow unon had a sea about the stockad
# ----- temperature: 0.5
# ----- Generating with seed: "ath or till john threw his handkerchief "
#
#
# up, and a feess crosses and doctor li
# ----- temperature: 1.0
# ----- Generating with seed: "ath or till john threw his handkerchief "
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: "ath or till john threw his handkerchief "
#
#
#
#
#
#
#
#
#
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.1411
# Epoch 60/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1377******************************************************
# ----- Generating text after Epoch: 59
# ----- temperature: 0.2
# ----- Generating with seed: "s my service. why, there you all
# are to"
# s my service. why, there you all
#
#
#
#
# "well, i'll have to see the blackness, that's
# ----- temperature: 0.5
# ----- Generating with seed: "s my service. why, there you all
# are to"
# s my service. why, there you all
#
# story, they had a sound and matie of the captain. the captain was the three whom. "they were to take a batter of you," said you. "you would be sing the sure in the room, and they were the sea. and they wereped to the part of this pair to his shipmate and looked of a feeth of the ship was a lower and t
# ----- temperature: 1.0
# ----- Generating with seed: "s my service. why, there you all
# are to"
# s my service. why, there you all
#
#
#
#
#
#  hollowly for the first, and firely fro. even all thaturation of wineing to my stern insurro
# ----- temperature: 1.2
# ----- Generating with seed: "s my service. why, there you all
# are to"
# s my service. why, there you all
#
#
#
#
#
#
#
#
#
#
#
#
# crewuh, you
# 1035/1035 [==============================] - 77s 75ms/step - loss: 1.1377
